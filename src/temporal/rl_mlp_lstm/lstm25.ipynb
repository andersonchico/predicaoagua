# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Dropout

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Dados completo.
data = trainingd.iloc[:,:].values
#treino (70%)
train = trainingd.iloc[0:174,:].values  
#teste (30%)
test = trainingd.iloc[174:,:].values 

print('Completo:',len(data))
print('treino:',len(train))
print('teste:',len(test))
data.shape
# Out:
# Completo: 248
# treino: 174
# teste: 74
# (248, 1)

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
sc = MinMaxScaler()
train = sc.fit_transform(train)
test = sc.fit_transform(test)

# %%
#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

# %%
lags = 43 # Equivalente à 25% dos dados de treino.
#Prepara os dados de treinamento
train_X, train_y = prepara_dados(train, lags)

train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))

#Prepara os dados de teste
entradas = trainingd[len(trainingd) - len(test) - lags:].values
entradas = entradas.reshape(-1, 1)
entradas = sc.fit_transform(entradas)

test_X = []
for i in range(lags, lags+len(test)):
    test_X.append(entradas[i-lags:i, 0])
test_X = np.array(test_X)
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

#Cria o modelo

model = Sequential()
model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
model.add(Dense(10, activation = 'linear'))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

#Treina o modelo
model.fit(train_X, train_y, batch_size = 32, epochs = 100)
#score = model.score(train_X,train_y)
#print(score)

#Dados de teste
previsoes = model.predict(test_X)
previsoes = previsoes.reshape(-1,1)
previsoes = sc.inverse_transform(previsoes)

#Dados de treino
previsoes_treino = model.predict(train_X)
previsoes_treino = previsoes_treino.reshape(-1,1)
previsoes_treino = sc.inverse_transform(previsoes_treino)
# Out:
# Train on 131 samples
# Epoch 1/100
# 131/131 [==============================] - 2s 12ms/sample - loss: 0.5952 - mean_absolute_error: 0.5952
# Epoch 2/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.5067 - mean_absolute_error: 0.5067
# Epoch 3/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.4172 - mean_absolute_error: 0.4172
# Epoch 4/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.3394 - mean_absolute_error: 0.3394
# Epoch 5/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.2579 - mean_absolute_error: 0.2579
# Epoch 6/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1574 - mean_absolute_error: 0.1574
# Epoch 7/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1728 - mean_absolute_error: 0.1728
# Epoch 8/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1746 - mean_absolute_error: 0.1746
# Epoch 9/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1650 - mean_absolute_error: 0.1650
# Epoch 10/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1617 - mean_absolute_error: 0.1617
# Epoch 11/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1591 - mean_absolute_error: 0.1591
# Epoch 12/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1559 - mean_absolute_error: 0.1559
# Epoch 13/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1536 - mean_absolute_error: 0.1536
# Epoch 14/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1427 - mean_absolute_error: 0.1427
# Epoch 15/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1500 - mean_absolute_error: 0.1500
# Epoch 16/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1610 - mean_absolute_error: 0.1610
# Epoch 17/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1469 - mean_absolute_error: 0.1469
# Epoch 18/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1559 - mean_absolute_error: 0.1559
# Epoch 19/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1536 - mean_absolute_error: 0.1536
# Epoch 20/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1343 - mean_absolute_error: 0.1343
# Epoch 21/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1513 - mean_absolute_error: 0.1513
# Epoch 22/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1469 - mean_absolute_error: 0.1469
# Epoch 23/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1426 - mean_absolute_error: 0.1426
# Epoch 24/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1564 - mean_absolute_error: 0.1564
# Epoch 25/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1559 - mean_absolute_error: 0.1559
# Epoch 26/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1421 - mean_absolute_error: 0.1421
# Epoch 27/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1312 - mean_absolute_error: 0.1312
# Epoch 28/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1408 - mean_absolute_error: 0.1408
# Epoch 29/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1434 - mean_absolute_error: 0.1434
# Epoch 30/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1473 - mean_absolute_error: 0.1473
# Epoch 31/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1554 - mean_absolute_error: 0.1554
# Epoch 32/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1499 - mean_absolute_error: 0.1499
# Epoch 33/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1457 - mean_absolute_error: 0.1457
# Epoch 34/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 35/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1526 - mean_absolute_error: 0.1526
# Epoch 36/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1404 - mean_absolute_error: 0.1404
# Epoch 37/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1424 - mean_absolute_error: 0.1424
# Epoch 38/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1416 - mean_absolute_error: 0.1416
# Epoch 39/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1495 - mean_absolute_error: 0.1495
# Epoch 40/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1426 - mean_absolute_error: 0.1426
# Epoch 41/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1500 - mean_absolute_error: 0.1500
# Epoch 42/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1594 - mean_absolute_error: 0.1594
# Epoch 43/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1472 - mean_absolute_error: 0.1472
# Epoch 44/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 45/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1387 - mean_absolute_error: 0.1387
# Epoch 46/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1495 - mean_absolute_error: 0.1495
# Epoch 47/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1492 - mean_absolute_error: 0.1492
# Epoch 48/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1354 - mean_absolute_error: 0.1354
# Epoch 49/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1372 - mean_absolute_error: 0.1372
# Epoch 50/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1443 - mean_absolute_error: 0.1443
# Epoch 51/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1370 - mean_absolute_error: 0.1370
# Epoch 52/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1380 - mean_absolute_error: 0.1380
# Epoch 53/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1429 - mean_absolute_error: 0.1429
# Epoch 54/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1472 - mean_absolute_error: 0.1472
# Epoch 55/100
# 131/131 [==============================] - 0s 988us/sample - loss: 0.1420 - mean_absolute_error: 0.1420
# Epoch 56/100
# 131/131 [==============================] - 0s 984us/sample - loss: 0.1474 - mean_absolute_error: 0.1474
# Epoch 57/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1295 - mean_absolute_error: 0.1295
# Epoch 58/100
# 131/131 [==============================] - 0s 995us/sample - loss: 0.1288 - mean_absolute_error: 0.1288
# Epoch 59/100
# 131/131 [==============================] - 0s 992us/sample - loss: 0.1392 - mean_absolute_error: 0.1392
# Epoch 60/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1424 - mean_absolute_error: 0.1424
# Epoch 61/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1480 - mean_absolute_error: 0.1480
# Epoch 62/100
# 131/131 [==============================] - 0s 995us/sample - loss: 0.1449 - mean_absolute_error: 0.1449
# Epoch 63/100
# 131/131 [==============================] - 0s 924us/sample - loss: 0.1376 - mean_absolute_error: 0.1376
# Epoch 64/100
# 131/131 [==============================] - 0s 791us/sample - loss: 0.1459 - mean_absolute_error: 0.1459
# Epoch 65/100
# 131/131 [==============================] - 0s 988us/sample - loss: 0.1479 - mean_absolute_error: 0.1479
# Epoch 66/100
# 131/131 [==============================] - 0s 957us/sample - loss: 0.1477 - mean_absolute_error: 0.1477
# Epoch 67/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1318 - mean_absolute_error: 0.1318
# Epoch 68/100
# 131/131 [==============================] - 0s 973us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 69/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1450 - mean_absolute_error: 0.1450
# Epoch 70/100
# 131/131 [==============================] - 0s 818us/sample - loss: 0.1432 - mean_absolute_error: 0.1432
# Epoch 71/100
# 131/131 [==============================] - 0s 1ms/sample - loss: 0.1398 - mean_absolute_error: 0.1398
# Epoch 72/100
# 131/131 [==============================] - 0s 749us/sample - loss: 0.1380 - mean_absolute_error: 0.1380
# Epoch 73/100
# 131/131 [==============================] - 0s 777us/sample - loss: 0.1332 - mean_absolute_error: 0.1332
# Epoch 74/100
# 131/131 [==============================] - 0s 764us/sample - loss: 0.1399 - mean_absolute_error: 0.1399
# Epoch 75/100
# 131/131 [==============================] - 0s 764us/sample - loss: 0.1420 - mean_absolute_error: 0.1420
# Epoch 76/100
# 131/131 [==============================] - 0s 764us/sample - loss: 0.1398 - mean_absolute_error: 0.1398
# Epoch 77/100
# 131/131 [==============================] - 0s 761us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 78/100
# 131/131 [==============================] - 0s 799us/sample - loss: 0.1328 - mean_absolute_error: 0.1328
# Epoch 79/100
# 131/131 [==============================] - 0s 805us/sample - loss: 0.1397 - mean_absolute_error: 0.1397
# Epoch 80/100
# 131/131 [==============================] - 0s 767us/sample - loss: 0.1363 - mean_absolute_error: 0.1363
# Epoch 81/100
# 131/131 [==============================] - 0s 755us/sample - loss: 0.1457 - mean_absolute_error: 0.1457
# Epoch 82/100
# 131/131 [==============================] - 0s 762us/sample - loss: 0.1484 - mean_absolute_error: 0.1484
# Epoch 83/100
# 131/131 [==============================] - 0s 785us/sample - loss: 0.1404 - mean_absolute_error: 0.1404
# Epoch 84/100
# 131/131 [==============================] - 0s 803us/sample - loss: 0.1383 - mean_absolute_error: 0.1383
# Epoch 85/100
# 131/131 [==============================] - 0s 754us/sample - loss: 0.1405 - mean_absolute_error: 0.1405
# Epoch 86/100
# 131/131 [==============================] - 0s 771us/sample - loss: 0.1405 - mean_absolute_error: 0.1405
# Epoch 87/100
# 131/131 [==============================] - 0s 771us/sample - loss: 0.1391 - mean_absolute_error: 0.1391
# Epoch 88/100
# 131/131 [==============================] - 0s 780us/sample - loss: 0.1381 - mean_absolute_error: 0.1381
# Epoch 89/100
# 131/131 [==============================] - 0s 761us/sample - loss: 0.1413 - mean_absolute_error: 0.1413
# Epoch 90/100
# 131/131 [==============================] - 0s 769us/sample - loss: 0.1510 - mean_absolute_error: 0.1510
# Epoch 91/100
# 131/131 [==============================] - 0s 774us/sample - loss: 0.1372 - mean_absolute_error: 0.1372
# Epoch 92/100
# 131/131 [==============================] - 0s 767us/sample - loss: 0.1383 - mean_absolute_error: 0.1383
# Epoch 93/100
# 131/131 [==============================] - 0s 789us/sample - loss: 0.1323 - mean_absolute_error: 0.1323
# Epoch 94/100
# 131/131 [==============================] - 0s 806us/sample - loss: 0.1282 - mean_absolute_error: 0.1282
# Epoch 95/100
# 131/131 [==============================] - 0s 788us/sample - loss: 0.1402 - mean_absolute_error: 0.1402
# Epoch 96/100
# 131/131 [==============================] - 0s 807us/sample - loss: 0.1381 - mean_absolute_error: 0.1381
# Epoch 97/100
# 131/131 [==============================] - 0s 769us/sample - loss: 0.1364 - mean_absolute_error: 0.1364
# Epoch 98/100
# 131/131 [==============================] - 0s 779us/sample - loss: 0.1375 - mean_absolute_error: 0.1375
# Epoch 99/100
# 131/131 [==============================] - 0s 762us/sample - loss: 0.1367 - mean_absolute_error: 0.1367
# Epoch 100/100
# 131/131 [==============================] - 0s 793us/sample - loss: 0.1287 - mean_absolute_error: 0.1287

# %%
#Preparação para plotagem

train_predict_plot = np.empty_like(data)
train_predict_plot[:, :] = np.nan
train_predict_plot[lags: len(previsoes_treino) + lags, :] = previsoes_treino
train_predict_plot.shape
    
test_predict_plot = np.empty_like(data)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(previsoes_treino)+lags:len(data), :] = previsoes

#Plotagem do gráfico
plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(train_predict_plot, color = 'green', label = 'Previsão de treino')
plt.plot(test_predict_plot, color = '#ff0066', label = 'Previsão de teste')
plt.title('Predição do pH com lag = 25%')
plt.xlabel('Bimestre')
plt.ylabel('Valor pH')
plt.legend()
plt.grid()
plt.show()
    
#Calculo do erro da previsão
#mape(previsoes.mean(),test.mean())
test = sc.inverse_transform(test)
treino = sc.inverse_transform(train[lags: len(previsoes_treino) + lags, :])

print('Resultados com lag', lags)
print('\n')
print('MAPE TREINO:',round(mape(previsoes_treino,treino)[0],2),'%')
print('RMSE TREINO:',round(rmse(previsoes_treino,treino),2))
print('\n')
print('MAPE TESTE:',round(mape(previsoes,test)[0],2),'%')
print('RMSE TESTE:',round(rmse(previsoes,test),2))
print('\n')
# Out:
# Resultados com lag 43
#
#
# MAPE TREINO: 1.93 %
# RMSE TREINO: 0.14
#
#
# MAPE TESTE: 33.62 %
# RMSE TESTE: 6.04

# %%
# Out:
# (248, 1)

# %%
# Out:
# 174
