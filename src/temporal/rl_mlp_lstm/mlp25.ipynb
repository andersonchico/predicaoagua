# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Dados completo.
data = trainingd.iloc[:,:].values
#treino (70%)
train = trainingd.iloc[0:174,:].values  
#teste (30%)
test = trainingd.iloc[174:,:].values 

print('Completo:',len(data))
print('treino:',len(train))
print('teste:',len(test))
data.shape
# Out:
# Completo: 248
# treino: 174
# teste: 74
# (248, 1)

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (-1 a 1).
sc = MinMaxScaler()
train = sc.fit_transform(train)
test = sc.fit_transform(test)

# %%
#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

# %%
lags = 43 # Equivalente à 25% dos dados de treino.
#Prepara os dados de treinamento
train_X, train_y = prepara_dados(train, lags)
    
#Prepara os dados de teste
entradas = trainingd[len(trainingd) - len(test) - lags:].values
entradas = entradas.reshape(-1, 1)
entradas = sc.fit_transform(entradas)

test_X = []
for i in range(lags, lags+len(test)):
    test_X.append(entradas[i-lags:i, 0])
test_X = np.array(test_X)
    
#Cria o modelo

model = Sequential()
model.add(Dense(units = 10, activation = 'relu', input_dim = lags))
model.add(Dense(units = 21, activation = 'relu'))
model.add(Dense(units = 1, activation = 'linear'))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

#Treina o modelo
model.fit(train_X, train_y, batch_size = 32, epochs = 100)
#score = model.score(train_X,train_y)
#print(score)

#Dados de teste
previsoes = model.predict(test_X)
previsoes = previsoes.reshape(-1, 1)
previsoes = sc.inverse_transform(previsoes)

#Dados de treino
previsoes_treino = model.predict(train_X)
previsoes_treino = previsoes_treino.reshape(-1, 1)
previsoes_treino = sc.inverse_transform(previsoes_treino)
# Out:
# Train on 131 samples
# Epoch 1/100
# 131/131 [==============================] - 0s 2ms/sample - loss: 0.2410 - mean_absolute_error: 0.2410
# Epoch 2/100
# 131/131 [==============================] - 0s 148us/sample - loss: 0.1764 - mean_absolute_error: 0.1764
# Epoch 3/100
# 131/131 [==============================] - 0s 76us/sample - loss: 0.1635 - mean_absolute_error: 0.1635
# Epoch 4/100
# 131/131 [==============================] - 0s 92us/sample - loss: 0.1646 - mean_absolute_error: 0.1646
# Epoch 5/100
# 131/131 [==============================] - 0s 92us/sample - loss: 0.1586 - mean_absolute_error: 0.1586
# Epoch 6/100
# 131/131 [==============================] - 0s 89us/sample - loss: 0.1537 - mean_absolute_error: 0.1537
# Epoch 7/100
# 131/131 [==============================] - 0s 94us/sample - loss: 0.1521 - mean_absolute_error: 0.1521
# Epoch 8/100
# 131/131 [==============================] - 0s 98us/sample - loss: 0.1507 - mean_absolute_error: 0.1507
# Epoch 9/100
# 131/131 [==============================] - 0s 91us/sample - loss: 0.1495 - mean_absolute_error: 0.1495
# Epoch 10/100
# 131/131 [==============================] - 0s 91us/sample - loss: 0.1485 - mean_absolute_error: 0.1485
# Epoch 11/100
# 131/131 [==============================] - 0s 78us/sample - loss: 0.1482 - mean_absolute_error: 0.1482
# Epoch 12/100
# 131/131 [==============================] - 0s 117us/sample - loss: 0.1451 - mean_absolute_error: 0.1451
# Epoch 13/100
# 131/131 [==============================] - 0s 92us/sample - loss: 0.1419 - mean_absolute_error: 0.1419
# Epoch 14/100
# 131/131 [==============================] - 0s 102us/sample - loss: 0.1394 - mean_absolute_error: 0.1394
# Epoch 15/100
# 131/131 [==============================] - 0s 102us/sample - loss: 0.1366 - mean_absolute_error: 0.1366
# Epoch 16/100
# 131/131 [==============================] - 0s 106us/sample - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 17/100
# 131/131 [==============================] - 0s 103us/sample - loss: 0.1328 - mean_absolute_error: 0.1328
# Epoch 18/100
# 131/131 [==============================] - 0s 135us/sample - loss: 0.1373 - mean_absolute_error: 0.1373
# Epoch 19/100
# 131/131 [==============================] - 0s 86us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 20/100
# 131/131 [==============================] - 0s 115us/sample - loss: 0.1325 - mean_absolute_error: 0.1325
# Epoch 21/100
# 131/131 [==============================] - 0s 135us/sample - loss: 0.1307 - mean_absolute_error: 0.1307
# Epoch 22/100
# 131/131 [==============================] - 0s 116us/sample - loss: 0.1291 - mean_absolute_error: 0.1291
# Epoch 23/100
# 131/131 [==============================] - 0s 94us/sample - loss: 0.1254 - mean_absolute_error: 0.1254
# Epoch 24/100
# 131/131 [==============================] - 0s 116us/sample - loss: 0.1245 - mean_absolute_error: 0.1245
# Epoch 25/100
# 131/131 [==============================] - 0s 144us/sample - loss: 0.1259 - mean_absolute_error: 0.1259
# Epoch 26/100
# 131/131 [==============================] - 0s 76us/sample - loss: 0.1236 - mean_absolute_error: 0.1236
# Epoch 27/100
# 131/131 [==============================] - 0s 92us/sample - loss: 0.1230 - mean_absolute_error: 0.1230
# Epoch 28/100
# 131/131 [==============================] - 0s 91us/sample - loss: 0.1226 - mean_absolute_error: 0.1226
# Epoch 29/100
# 131/131 [==============================] - 0s 93us/sample - loss: 0.1228 - mean_absolute_error: 0.1228
# Epoch 30/100
# 131/131 [==============================] - 0s 97us/sample - loss: 0.1217 - mean_absolute_error: 0.1217
# Epoch 31/100
# 131/131 [==============================] - 0s 105us/sample - loss: 0.1211 - mean_absolute_error: 0.1211
# Epoch 32/100
# 131/131 [==============================] - 0s 94us/sample - loss: 0.1208 - mean_absolute_error: 0.1208
# Epoch 33/100
# 131/131 [==============================] - 0s 105us/sample - loss: 0.1193 - mean_absolute_error: 0.1193
# Epoch 34/100
# 131/131 [==============================] - 0s 99us/sample - loss: 0.1212 - mean_absolute_error: 0.1212
# Epoch 35/100
# 131/131 [==============================] - 0s 98us/sample - loss: 0.1209 - mean_absolute_error: 0.1209
# Epoch 36/100
# 131/131 [==============================] - 0s 105us/sample - loss: 0.1179 - mean_absolute_error: 0.1179
# Epoch 37/100
# 131/131 [==============================] - 0s 118us/sample - loss: 0.1195 - mean_absolute_error: 0.1195
# Epoch 38/100
# 131/131 [==============================] - 0s 106us/sample - loss: 0.1191 - mean_absolute_error: 0.1191
# Epoch 39/100
# 131/131 [==============================] - 0s 112us/sample - loss: 0.1169 - mean_absolute_error: 0.1169
# Epoch 40/100
# 131/131 [==============================] - 0s 101us/sample - loss: 0.1162 - mean_absolute_error: 0.1162
# Epoch 41/100
# 131/131 [==============================] - 0s 120us/sample - loss: 0.1171 - mean_absolute_error: 0.1171
# Epoch 42/100
# 131/131 [==============================] - 0s 100us/sample - loss: 0.1162 - mean_absolute_error: 0.1162
# Epoch 43/100
# 131/131 [==============================] - 0s 111us/sample - loss: 0.1155 - mean_absolute_error: 0.1155
# Epoch 44/100
# 131/131 [==============================] - 0s 107us/sample - loss: 0.1161 - mean_absolute_error: 0.1161
# Epoch 45/100
# 131/131 [==============================] - 0s 85us/sample - loss: 0.1154 - mean_absolute_error: 0.1154
# Epoch 46/100
# 131/131 [==============================] - 0s 93us/sample - loss: 0.1148 - mean_absolute_error: 0.1148
# Epoch 47/100
# 131/131 [==============================] - 0s 122us/sample - loss: 0.1163 - mean_absolute_error: 0.1163
# Epoch 48/100
# 131/131 [==============================] - 0s 106us/sample - loss: 0.1156 - mean_absolute_error: 0.1156
# Epoch 49/100
# 131/131 [==============================] - 0s 87us/sample - loss: 0.1142 - mean_absolute_error: 0.1142
# Epoch 50/100
# 131/131 [==============================] - 0s 134us/sample - loss: 0.1144 - mean_absolute_error: 0.1144
# Epoch 51/100
# 131/131 [==============================] - 0s 116us/sample - loss: 0.1131 - mean_absolute_error: 0.1131
# Epoch 52/100
# 131/131 [==============================] - 0s 97us/sample - loss: 0.1134 - mean_absolute_error: 0.1134
# Epoch 53/100
# 131/131 [==============================] - 0s 79us/sample - loss: 0.1131 - mean_absolute_error: 0.1131
# Epoch 54/100
# 131/131 [==============================] - 0s 86us/sample - loss: 0.1135 - mean_absolute_error: 0.1135
# Epoch 55/100
# 131/131 [==============================] - 0s 110us/sample - loss: 0.1124 - mean_absolute_error: 0.1124
# Epoch 56/100
# 131/131 [==============================] - 0s 112us/sample - loss: 0.1166 - mean_absolute_error: 0.1166
# Epoch 57/100
# 131/131 [==============================] - 0s 124us/sample - loss: 0.1137 - mean_absolute_error: 0.1137
# Epoch 58/100
# 131/131 [==============================] - 0s 70us/sample - loss: 0.1121 - mean_absolute_error: 0.1121
# Epoch 59/100
# 131/131 [==============================] - 0s 102us/sample - loss: 0.1118 - mean_absolute_error: 0.1118
# Epoch 60/100
# 131/131 [==============================] - 0s 82us/sample - loss: 0.1112 - mean_absolute_error: 0.1112
# Epoch 61/100
# 131/131 [==============================] - 0s 95us/sample - loss: 0.1110 - mean_absolute_error: 0.1110
# Epoch 62/100
# 131/131 [==============================] - 0s 89us/sample - loss: 0.1122 - mean_absolute_error: 0.1122
# Epoch 63/100
# 131/131 [==============================] - 0s 108us/sample - loss: 0.1109 - mean_absolute_error: 0.1109
# Epoch 64/100
# 131/131 [==============================] - 0s 118us/sample - loss: 0.1107 - mean_absolute_error: 0.1107
# Epoch 65/100
# 131/131 [==============================] - 0s 81us/sample - loss: 0.1121 - mean_absolute_error: 0.1121
# Epoch 66/100
# 131/131 [==============================] - 0s 118us/sample - loss: 0.1094 - mean_absolute_error: 0.1094
# Epoch 67/100
# 131/131 [==============================] - 0s 114us/sample - loss: 0.1115 - mean_absolute_error: 0.1115
# Epoch 68/100
# 131/131 [==============================] - 0s 64us/sample - loss: 0.1103 - mean_absolute_error: 0.1103
# Epoch 69/100
# 131/131 [==============================] - 0s 97us/sample - loss: 0.1089 - mean_absolute_error: 0.1089
# Epoch 70/100
# 131/131 [==============================] - 0s 131us/sample - loss: 0.1091 - mean_absolute_error: 0.1091
# Epoch 71/100
# 131/131 [==============================] - 0s 94us/sample - loss: 0.1087 - mean_absolute_error: 0.1087
# Epoch 72/100
# 131/131 [==============================] - 0s 75us/sample - loss: 0.1089 - mean_absolute_error: 0.1089
# Epoch 73/100
# 131/131 [==============================] - 0s 97us/sample - loss: 0.1095 - mean_absolute_error: 0.1095
# Epoch 74/100
# 131/131 [==============================] - 0s 131us/sample - loss: 0.1079 - mean_absolute_error: 0.1079
# Epoch 75/100
# 131/131 [==============================] - 0s 91us/sample - loss: 0.1088 - mean_absolute_error: 0.1088
# Epoch 76/100
# 131/131 [==============================] - 0s 119us/sample - loss: 0.1069 - mean_absolute_error: 0.1069
# Epoch 77/100
# 131/131 [==============================] - 0s 87us/sample - loss: 0.1073 - mean_absolute_error: 0.1073
# Epoch 78/100
# 131/131 [==============================] - 0s 152us/sample - loss: 0.1069 - mean_absolute_error: 0.1069
# Epoch 79/100
# 131/131 [==============================] - 0s 111us/sample - loss: 0.1061 - mean_absolute_error: 0.1061
# Epoch 80/100
# 131/131 [==============================] - 0s 130us/sample - loss: 0.1092 - mean_absolute_error: 0.1092
# Epoch 81/100
# 131/131 [==============================] - 0s 112us/sample - loss: 0.1075 - mean_absolute_error: 0.1075
# Epoch 82/100
# 131/131 [==============================] - 0s 94us/sample - loss: 0.1092 - mean_absolute_error: 0.1092
# Epoch 83/100
# 131/131 [==============================] - 0s 103us/sample - loss: 0.1064 - mean_absolute_error: 0.1064
# Epoch 84/100
# 131/131 [==============================] - 0s 109us/sample - loss: 0.1097 - mean_absolute_error: 0.1097
# Epoch 85/100
# 131/131 [==============================] - 0s 87us/sample - loss: 0.1068 - mean_absolute_error: 0.1068
# Epoch 86/100
# 131/131 [==============================] - 0s 120us/sample - loss: 0.1071 - mean_absolute_error: 0.1071
# Epoch 87/100
# 131/131 [==============================] - 0s 106us/sample - loss: 0.1083 - mean_absolute_error: 0.1083
# Epoch 88/100
# 131/131 [==============================] - 0s 118us/sample - loss: 0.1072 - mean_absolute_error: 0.1072
# Epoch 89/100
# 131/131 [==============================] - 0s 111us/sample - loss: 0.1047 - mean_absolute_error: 0.1047
# Epoch 90/100
# 131/131 [==============================] - 0s 101us/sample - loss: 0.1042 - mean_absolute_error: 0.1042
# Epoch 91/100
# 131/131 [==============================] - 0s 107us/sample - loss: 0.1036 - mean_absolute_error: 0.1036
# Epoch 92/100
# 131/131 [==============================] - 0s 129us/sample - loss: 0.1035 - mean_absolute_error: 0.1035
# Epoch 93/100
# 131/131 [==============================] - 0s 117us/sample - loss: 0.1034 - mean_absolute_error: 0.1034
# Epoch 94/100
# 131/131 [==============================] - 0s 94us/sample - loss: 0.1031 - mean_absolute_error: 0.1031
# Epoch 95/100
# 131/131 [==============================] - 0s 107us/sample - loss: 0.1033 - mean_absolute_error: 0.1033
# Epoch 96/100
# 131/131 [==============================] - 0s 88us/sample - loss: 0.1022 - mean_absolute_error: 0.1022
# Epoch 97/100
# 131/131 [==============================] - 0s 98us/sample - loss: 0.1043 - mean_absolute_error: 0.1043
# Epoch 98/100
# 131/131 [==============================] - 0s 51us/sample - loss: 0.1034 - mean_absolute_error: 0.1034
# Epoch 99/100
# 131/131 [==============================] - 0s 117us/sample - loss: 0.1051 - mean_absolute_error: 0.1051
# Epoch 100/100
# 131/131 [==============================] - 0s 127us/sample - loss: 0.1039 - mean_absolute_error: 0.1039

# %%
#Preparação para plotagem
train_predict_plot = np.empty_like(data)
train_predict_plot[:, :] = np.nan
train_predict_plot[lags: len(previsoes_treino) + lags, :] = previsoes_treino
train_predict_plot.shape
    
test_predict_plot = np.empty_like(data)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(previsoes_treino)+lags:len(data), :] = previsoes

#Plotagem do gráfico
plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(train_predict_plot, color = 'green', label = 'Previsão de treino')
plt.plot(test_predict_plot, color = '#ff0066', label = 'Previsão de teste')
plt.title('Predição do pH com lag = 25%')
plt.xlabel('Bimestre')
plt.ylabel('Valor pH')
plt.legend()
plt.grid()
plt.show()
    
#Calculo do erro da previsão
#mape(previsoes.mean(),test.mean())
test = sc.inverse_transform(test)
treino = sc.inverse_transform(train[lags: len(previsoes_treino) + lags, :])

print('Resultados com lag', lags)
print('\n')
print('MAPE TREINO:',round(mape(previsoes_treino,treino)[0],2),'%')
print('RMSE TREINO:',round(rmse(previsoes_treino,treino),2))
print('\n')
print('MAPE TESTE:',round(mape(previsoes,test)[0],2),'%')
print('RMSE TESTE:',round(rmse(previsoes,test),2))
print('\n')
# Out:
# Resultados com lag 43
#
#
# MAPE TREINO: 1.72 %
# RMSE TREINO: 0.13
#
#
# MAPE TESTE: 33.48 %
# RMSE TESTE: 6.01

# %%
# Out:
# (248, 1)

# %%
# Out:
# 174
