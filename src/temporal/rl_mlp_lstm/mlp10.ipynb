# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Dados completo.
data = trainingd.iloc[:,:].values
#treino (70%)
train = trainingd.iloc[0:174,:].values  
#teste (30%)
test = trainingd.iloc[174:,:].values 

print('Completo:',len(data))
print('treino:',len(train))
print('teste:',len(test))
data.shape
# Out:
# Completo: 248
# treino: 174
# teste: 74
# (248, 1)

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (-1 a 1).
sc = MinMaxScaler()
train = sc.fit_transform(train)
test = sc.fit_transform(test)

# %%
#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

# %%
lags = 17 # Equivalente à 10% dos dados de treino.
#Prepara os dados de treinamento
train_X, train_y = prepara_dados(train, lags)
    
#Prepara os dados de teste
entradas = trainingd[len(trainingd) - len(test) - lags:].values
entradas = entradas.reshape(-1, 1)
entradas = sc.fit_transform(entradas)

test_X = []
for i in range(lags, lags+len(test)):
    test_X.append(entradas[i-lags:i, 0])
test_X = np.array(test_X)
    
#Cria o modelo

model = Sequential()
model.add(Dense(units = 10, activation = 'relu', input_dim = lags))
model.add(Dense(units = 21, activation = 'relu'))
model.add(Dense(units = 1, activation = 'linear'))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

#Treina o modelo
model.fit(train_X, train_y, batch_size = 32, epochs = 100)
#score = model.score(train_X,train_y)
#print(score)

#Dados de teste
previsoes = model.predict(test_X)
previsoes = previsoes.reshape(-1, 1)
previsoes = sc.inverse_transform(previsoes)

#Dados de treino
previsoes_treino = model.predict(train_X)
previsoes_treino = previsoes_treino.reshape(-1, 1)
previsoes_treino = sc.inverse_transform(previsoes_treino)
# Out:
# Train on 157 samples
# Epoch 1/100
# 157/157 [==============================] - 0s 2ms/sample - loss: 0.4332 - mean_absolute_error: 0.4332
# Epoch 2/100
# 157/157 [==============================] - 0s 64us/sample - loss: 0.3401 - mean_absolute_error: 0.3401
# Epoch 3/100
# 157/157 [==============================] - 0s 85us/sample - loss: 0.2540 - mean_absolute_error: 0.2540
# Epoch 4/100
# 157/157 [==============================] - 0s 70us/sample - loss: 0.1784 - mean_absolute_error: 0.1784
# Epoch 5/100
# 157/157 [==============================] - 0s 74us/sample - loss: 0.1322 - mean_absolute_error: 0.1322
# Epoch 6/100
# 157/157 [==============================] - 0s 75us/sample - loss: 0.1330 - mean_absolute_error: 0.1330
# Epoch 7/100
# 157/157 [==============================] - 0s 96us/sample - loss: 0.1414 - mean_absolute_error: 0.1414
# Epoch 8/100
# 157/157 [==============================] - 0s 98us/sample - loss: 0.1340 - mean_absolute_error: 0.1340
# Epoch 9/100
# 157/157 [==============================] - 0s 85us/sample - loss: 0.1263 - mean_absolute_error: 0.1263
# Epoch 10/100
# 157/157 [==============================] - 0s 104us/sample - loss: 0.1249 - mean_absolute_error: 0.1249
# Epoch 11/100
# 157/157 [==============================] - 0s 70us/sample - loss: 0.1254 - mean_absolute_error: 0.1254
# Epoch 12/100
# 157/157 [==============================] - 0s 83us/sample - loss: 0.1245 - mean_absolute_error: 0.1245
# Epoch 13/100
# 157/157 [==============================] - 0s 75us/sample - loss: 0.1234 - mean_absolute_error: 0.1234
# Epoch 14/100
# 157/157 [==============================] - 0s 91us/sample - loss: 0.1235 - mean_absolute_error: 0.1235
# Epoch 15/100
# 157/157 [==============================] - 0s 97us/sample - loss: 0.1232 - mean_absolute_error: 0.1232
# Epoch 16/100
# 157/157 [==============================] - 0s 94us/sample - loss: 0.1227 - mean_absolute_error: 0.1227
# Epoch 17/100
# 157/157 [==============================] - 0s 98us/sample - loss: 0.1226 - mean_absolute_error: 0.1226
# Epoch 18/100
# 157/157 [==============================] - 0s 123us/sample - loss: 0.1223 - mean_absolute_error: 0.1223
# Epoch 19/100
# 157/157 [==============================] - 0s 92us/sample - loss: 0.1222 - mean_absolute_error: 0.1222
# Epoch 20/100
# 157/157 [==============================] - 0s 105us/sample - loss: 0.1218 - mean_absolute_error: 0.1218
# Epoch 21/100
# 157/157 [==============================] - 0s 91us/sample - loss: 0.1217 - mean_absolute_error: 0.1217
# Epoch 22/100
# 157/157 [==============================] - 0s 88us/sample - loss: 0.1214 - mean_absolute_error: 0.1214
# Epoch 23/100
# 157/157 [==============================] - 0s 85us/sample - loss: 0.1211 - mean_absolute_error: 0.1211
# Epoch 24/100
# 157/157 [==============================] - 0s 77us/sample - loss: 0.1213 - mean_absolute_error: 0.1213
# Epoch 25/100
# 157/157 [==============================] - 0s 86us/sample - loss: 0.1207 - mean_absolute_error: 0.1207
# Epoch 26/100
# 157/157 [==============================] - 0s 92us/sample - loss: 0.1205 - mean_absolute_error: 0.1205
# Epoch 27/100
# 157/157 [==============================] - 0s 89us/sample - loss: 0.1206 - mean_absolute_error: 0.1206
# Epoch 28/100
# 157/157 [==============================] - 0s 93us/sample - loss: 0.1201 - mean_absolute_error: 0.1201
# Epoch 29/100
# 157/157 [==============================] - 0s 66us/sample - loss: 0.1197 - mean_absolute_error: 0.1197
# Epoch 30/100
# 157/157 [==============================] - 0s 86us/sample - loss: 0.1195 - mean_absolute_error: 0.1195
# Epoch 31/100
# 157/157 [==============================] - 0s 100us/sample - loss: 0.1194 - mean_absolute_error: 0.1194
# Epoch 32/100
# 157/157 [==============================] - 0s 93us/sample - loss: 0.1191 - mean_absolute_error: 0.1191
# Epoch 33/100
# 157/157 [==============================] - 0s 89us/sample - loss: 0.1189 - mean_absolute_error: 0.1189
# Epoch 34/100
# 157/157 [==============================] - 0s 73us/sample - loss: 0.1187 - mean_absolute_error: 0.1187
# Epoch 35/100
# 157/157 [==============================] - 0s 74us/sample - loss: 0.1183 - mean_absolute_error: 0.1183
# Epoch 36/100
# 157/157 [==============================] - 0s 94us/sample - loss: 0.1184 - mean_absolute_error: 0.1184
# Epoch 37/100
# 157/157 [==============================] - 0s 78us/sample - loss: 0.1178 - mean_absolute_error: 0.1178
# Epoch 38/100
# 157/157 [==============================] - 0s 82us/sample - loss: 0.1176 - mean_absolute_error: 0.1176
# Epoch 39/100
# 157/157 [==============================] - 0s 89us/sample - loss: 0.1177 - mean_absolute_error: 0.1177
# Epoch 40/100
# 157/157 [==============================] - 0s 89us/sample - loss: 0.1174 - mean_absolute_error: 0.1174
# Epoch 41/100
# 157/157 [==============================] - 0s 105us/sample - loss: 0.1173 - mean_absolute_error: 0.1173
# Epoch 42/100
# 157/157 [==============================] - 0s 104us/sample - loss: 0.1168 - mean_absolute_error: 0.1168
# Epoch 43/100
# 157/157 [==============================] - ETA: 0s - loss: 0.0872 - mean_absolute_error: 0.087 - 0s 89us/sample - loss: 0.1166 - mean_absolute_error: 0.1166
# Epoch 44/100
# 157/157 [==============================] - 0s 95us/sample - loss: 0.1163 - mean_absolute_error: 0.1163
# Epoch 45/100
# 157/157 [==============================] - ETA: 0s - loss: 0.1459 - mean_absolute_error: 0.145 - 0s 97us/sample - loss: 0.1162 - mean_absolute_error: 0.1162
# Epoch 46/100
# 157/157 [==============================] - 0s 97us/sample - loss: 0.1160 - mean_absolute_error: 0.1160
# Epoch 47/100
# 157/157 [==============================] - 0s 71us/sample - loss: 0.1161 - mean_absolute_error: 0.1161
# Epoch 48/100
# 157/157 [==============================] - 0s 84us/sample - loss: 0.1158 - mean_absolute_error: 0.1158
# Epoch 49/100
# 157/157 [==============================] - 0s 79us/sample - loss: 0.1158 - mean_absolute_error: 0.1158
# Epoch 50/100
# 157/157 [==============================] - 0s 102us/sample - loss: 0.1156 - mean_absolute_error: 0.1156
# Epoch 51/100
# 157/157 [==============================] - 0s 91us/sample - loss: 0.1149 - mean_absolute_error: 0.1149
# Epoch 52/100
# 157/157 [==============================] - 0s 60us/sample - loss: 0.1145 - mean_absolute_error: 0.1145
# Epoch 53/100
# 157/157 [==============================] - 0s 104us/sample - loss: 0.1143 - mean_absolute_error: 0.1143
# Epoch 54/100
# 157/157 [==============================] - 0s 100us/sample - loss: 0.1142 - mean_absolute_error: 0.1142
# Epoch 55/100
# 157/157 [==============================] - 0s 74us/sample - loss: 0.1139 - mean_absolute_error: 0.1139
# Epoch 56/100
# 157/157 [==============================] - 0s 85us/sample - loss: 0.1135 - mean_absolute_error: 0.1135
# Epoch 57/100
# 157/157 [==============================] - ETA: 0s - loss: 0.1341 - mean_absolute_error: 0.134 - 0s 80us/sample - loss: 0.1135 - mean_absolute_error: 0.1135
# Epoch 58/100
# 157/157 [==============================] - 0s 94us/sample - loss: 0.1130 - mean_absolute_error: 0.1130
# Epoch 59/100
# 157/157 [==============================] - 0s 66us/sample - loss: 0.1129 - mean_absolute_error: 0.1129
# Epoch 60/100
# 157/157 [==============================] - 0s 102us/sample - loss: 0.1128 - mean_absolute_error: 0.1128
# Epoch 61/100
# 157/157 [==============================] - 0s 69us/sample - loss: 0.1125 - mean_absolute_error: 0.1125
# Epoch 62/100
# 157/157 [==============================] - 0s 101us/sample - loss: 0.1124 - mean_absolute_error: 0.1124
# Epoch 63/100
# 157/157 [==============================] - 0s 95us/sample - loss: 0.1120 - mean_absolute_error: 0.1120
# Epoch 64/100
# 157/157 [==============================] - 0s 93us/sample - loss: 0.1119 - mean_absolute_error: 0.1119
# Epoch 65/100
# 157/157 [==============================] - 0s 102us/sample - loss: 0.1116 - mean_absolute_error: 0.1116
# Epoch 66/100
# 157/157 [==============================] - 0s 81us/sample - loss: 0.1117 - mean_absolute_error: 0.1117
# Epoch 67/100
# 157/157 [==============================] - 0s 62us/sample - loss: 0.1116 - mean_absolute_error: 0.1116
# Epoch 68/100
# 157/157 [==============================] - 0s 113us/sample - loss: 0.1113 - mean_absolute_error: 0.1113
# Epoch 69/100
# 157/157 [==============================] - 0s 82us/sample - loss: 0.1116 - mean_absolute_error: 0.1116
# Epoch 70/100
# 157/157 [==============================] - 0s 92us/sample - loss: 0.1107 - mean_absolute_error: 0.1107
# Epoch 71/100
# 157/157 [==============================] - 0s 59us/sample - loss: 0.1113 - mean_absolute_error: 0.1113
# Epoch 72/100
# 157/157 [==============================] - 0s 54us/sample - loss: 0.1105 - mean_absolute_error: 0.1105
# Epoch 73/100
# 157/157 [==============================] - 0s 77us/sample - loss: 0.1109 - mean_absolute_error: 0.1109
# Epoch 74/100
# 157/157 [==============================] - 0s 68us/sample - loss: 0.1100 - mean_absolute_error: 0.1100
# Epoch 75/100
# 157/157 [==============================] - 0s 89us/sample - loss: 0.1102 - mean_absolute_error: 0.1102
# Epoch 76/100
# 157/157 [==============================] - 0s 95us/sample - loss: 0.1096 - mean_absolute_error: 0.1096
# Epoch 77/100
# 157/157 [==============================] - 0s 101us/sample - loss: 0.1096 - mean_absolute_error: 0.1096
# Epoch 78/100
# 157/157 [==============================] - 0s 80us/sample - loss: 0.1096 - mean_absolute_error: 0.1096
# Epoch 79/100
# 157/157 [==============================] - 0s 73us/sample - loss: 0.1092 - mean_absolute_error: 0.1092
# Epoch 80/100
# 157/157 [==============================] - 0s 91us/sample - loss: 0.1091 - mean_absolute_error: 0.1091
# Epoch 81/100
# 157/157 [==============================] - 0s 109us/sample - loss: 0.1090 - mean_absolute_error: 0.1090
# Epoch 82/100
# 157/157 [==============================] - 0s 81us/sample - loss: 0.1087 - mean_absolute_error: 0.1087
# Epoch 83/100
# 157/157 [==============================] - 0s 71us/sample - loss: 0.1085 - mean_absolute_error: 0.1085
# Epoch 84/100
# 157/157 [==============================] - 0s 83us/sample - loss: 0.1080 - mean_absolute_error: 0.1080
# Epoch 85/100
# 157/157 [==============================] - 0s 84us/sample - loss: 0.1080 - mean_absolute_error: 0.1080
# Epoch 86/100
# 157/157 [==============================] - 0s 96us/sample - loss: 0.1078 - mean_absolute_error: 0.1078
# Epoch 87/100
# 157/157 [==============================] - 0s 105us/sample - loss: 0.1073 - mean_absolute_error: 0.1073
# Epoch 88/100
# 157/157 [==============================] - 0s 117us/sample - loss: 0.1072 - mean_absolute_error: 0.1072
# Epoch 89/100
# 157/157 [==============================] - 0s 107us/sample - loss: 0.1075 - mean_absolute_error: 0.1075
# Epoch 90/100
# 157/157 [==============================] - 0s 77us/sample - loss: 0.1068 - mean_absolute_error: 0.1068
# Epoch 91/100
# 157/157 [==============================] - 0s 94us/sample - loss: 0.1069 - mean_absolute_error: 0.1069
# Epoch 92/100
# 157/157 [==============================] - 0s 82us/sample - loss: 0.1068 - mean_absolute_error: 0.1068
# Epoch 93/100
# 157/157 [==============================] - 0s 68us/sample - loss: 0.1060 - mean_absolute_error: 0.1060
# Epoch 94/100
# 157/157 [==============================] - 0s 87us/sample - loss: 0.1062 - mean_absolute_error: 0.1062
# Epoch 95/100
# 157/157 [==============================] - 0s 84us/sample - loss: 0.1058 - mean_absolute_error: 0.1058
# Epoch 96/100
# 157/157 [==============================] - 0s 91us/sample - loss: 0.1056 - mean_absolute_error: 0.1056
# Epoch 97/100
# 157/157 [==============================] - 0s 127us/sample - loss: 0.1057 - mean_absolute_error: 0.1057
# Epoch 98/100
# 157/157 [==============================] - 0s 84us/sample - loss: 0.1059 - mean_absolute_error: 0.1059
# Epoch 99/100
# 157/157 [==============================] - 0s 73us/sample - loss: 0.1051 - mean_absolute_error: 0.1051
# Epoch 100/100
# 157/157 [==============================] - 0s 125us/sample - loss: 0.1052 - mean_absolute_error: 0.1052

# %%
#Preparação para plotagem
train_predict_plot = np.empty_like(data)
train_predict_plot[:, :] = np.nan
train_predict_plot[lags: len(previsoes_treino) + lags, :] = previsoes_treino
train_predict_plot.shape
    
test_predict_plot = np.empty_like(data)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(previsoes_treino)+lags:len(data), :] = previsoes

#Plotagem do gráfico
plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(train_predict_plot, color = 'green', label = 'Previsão de treino')
plt.plot(test_predict_plot, color = '#ff0066', label = 'Previsão de teste')
plt.title('Predição do pH com lag = 10%')
plt.xlabel('Bimestre')
plt.ylabel('Valor pH')
plt.legend()
plt.grid()
plt.show()
    
#Calculo do erro da previsão
#mape(previsoes.mean(),test.mean())
test = sc.inverse_transform(test)
treino = sc.inverse_transform(train[lags: len(previsoes_treino) + lags, :])

print('Resultados com lag', lags)
print('\n')
print('MAPE TREINO:',round(mape(previsoes_treino,treino)[0],2),'%')
print('RMSE TREINO:',round(rmse(previsoes_treino,treino),2))
print('\n')
print('MAPE TESTE:',round(mape(previsoes,test)[0],2),'%')
print('RMSE TESTE:',round(rmse(previsoes,test),2))
print('\n')
# Out:
# Resultados com lag 17
#
#
# MAPE TREINO: 1.98 %
# RMSE TREINO: 0.13
#
#
# MAPE TESTE: 1.41 %
# RMSE TESTE: 0.17

# %%
# Out:
# (248, 1)

# %%
# Out:
# 174
