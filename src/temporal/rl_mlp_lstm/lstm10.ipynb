# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Dropout

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Dados completo.
data = trainingd.iloc[:,:].values
#treino (70%)
train = trainingd.iloc[0:174,:].values  
#teste (30%)
test = trainingd.iloc[174:,:].values 

print('Completo:',len(data))
print('treino:',len(train))
print('teste:',len(test))
data.shape
# Out:
# Completo: 248
# treino: 174
# teste: 74
# (248, 1)

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
sc = MinMaxScaler()
train = sc.fit_transform(train)
test = sc.fit_transform(test)

# %%
#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

# %%
lags = 17 # Equivalente à 10% dos dados de treino.
#Prepara os dados de treinamento
train_X, train_y = prepara_dados(train, lags)

train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))

#Prepara os dados de teste
entradas = trainingd[len(trainingd) - len(test) - lags:].values
entradas = entradas.reshape(-1, 1)
entradas = sc.fit_transform(entradas)

test_X = []
for i in range(lags, lags+len(test)):
    test_X.append(entradas[i-lags:i, 0])
test_X = np.array(test_X)
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

#Cria o modelo

model = Sequential()
model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
model.add(Dense(10, activation = 'linear'))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

#Treina o modelo
model.fit(train_X, train_y, batch_size = 32, epochs = 100)
#score = model.score(train_X,train_y)
#print(score)

#Dados de teste
previsoes = model.predict(test_X)
previsoes = previsoes.reshape(-1,1)
previsoes = sc.inverse_transform(previsoes)

#Dados de treino
previsoes_treino = model.predict(train_X)
previsoes_treino = previsoes_treino.reshape(-1,1)
previsoes_treino = sc.inverse_transform(previsoes_treino)
# Out:
# Train on 157 samples
# Epoch 1/100
# 157/157 [==============================] - 1s 9ms/sample - loss: 0.4121 - mean_absolute_error: 0.4121
# Epoch 2/100
# 157/157 [==============================] - 0s 452us/sample - loss: 0.3234 - mean_absolute_error: 0.3234
# Epoch 3/100
# 157/157 [==============================] - 0s 457us/sample - loss: 0.2411 - mean_absolute_error: 0.2411
# Epoch 4/100
# 157/157 [==============================] - 0s 479us/sample - loss: 0.1861 - mean_absolute_error: 0.1861
# Epoch 5/100
# 157/157 [==============================] - 0s 463us/sample - loss: 0.1822 - mean_absolute_error: 0.1822
# Epoch 6/100
# 157/157 [==============================] - 0s 480us/sample - loss: 0.1810 - mean_absolute_error: 0.1810
# Epoch 7/100
# 157/157 [==============================] - 0s 484us/sample - loss: 0.1794 - mean_absolute_error: 0.1794
# Epoch 8/100
# 157/157 [==============================] - 0s 475us/sample - loss: 0.1646 - mean_absolute_error: 0.1646
# Epoch 9/100
# 157/157 [==============================] - 0s 473us/sample - loss: 0.1448 - mean_absolute_error: 0.1448
# Epoch 10/100
# 157/157 [==============================] - 0s 471us/sample - loss: 0.1612 - mean_absolute_error: 0.1612
# Epoch 11/100
# 157/157 [==============================] - 0s 440us/sample - loss: 0.1608 - mean_absolute_error: 0.1608
# Epoch 12/100
# 157/157 [==============================] - 0s 456us/sample - loss: 0.1621 - mean_absolute_error: 0.1621
# Epoch 13/100
# 157/157 [==============================] - 0s 462us/sample - loss: 0.1572 - mean_absolute_error: 0.1572
# Epoch 14/100
# 157/157 [==============================] - 0s 439us/sample - loss: 0.1579 - mean_absolute_error: 0.1579
# Epoch 15/100
# 157/157 [==============================] - 0s 480us/sample - loss: 0.1492 - mean_absolute_error: 0.1492
# Epoch 16/100
# 157/157 [==============================] - 0s 452us/sample - loss: 0.1489 - mean_absolute_error: 0.1489
# Epoch 17/100
# 157/157 [==============================] - 0s 460us/sample - loss: 0.1473 - mean_absolute_error: 0.1473
# Epoch 18/100
# 157/157 [==============================] - 0s 480us/sample - loss: 0.1545 - mean_absolute_error: 0.1545
# Epoch 19/100
# 157/157 [==============================] - 0s 452us/sample - loss: 0.1410 - mean_absolute_error: 0.1410
# Epoch 20/100
# 157/157 [==============================] - 0s 489us/sample - loss: 0.1436 - mean_absolute_error: 0.1436
# Epoch 21/100
# 157/157 [==============================] - 0s 453us/sample - loss: 0.1286 - mean_absolute_error: 0.1286
# Epoch 22/100
# 157/157 [==============================] - 0s 459us/sample - loss: 0.1589 - mean_absolute_error: 0.1589
# Epoch 23/100
# 157/157 [==============================] - 0s 477us/sample - loss: 0.1478 - mean_absolute_error: 0.1478
# Epoch 24/100
# 157/157 [==============================] - 0s 479us/sample - loss: 0.1397 - mean_absolute_error: 0.1397
# Epoch 25/100
# 157/157 [==============================] - 0s 453us/sample - loss: 0.1383 - mean_absolute_error: 0.1383
# Epoch 26/100
# 157/157 [==============================] - 0s 463us/sample - loss: 0.1524 - mean_absolute_error: 0.1524
# Epoch 27/100
# 157/157 [==============================] - 0s 477us/sample - loss: 0.1389 - mean_absolute_error: 0.1389
# Epoch 28/100
# 157/157 [==============================] - 0s 447us/sample - loss: 0.1462 - mean_absolute_error: 0.1462
# Epoch 29/100
# 157/157 [==============================] - 0s 456us/sample - loss: 0.1436 - mean_absolute_error: 0.1436
# Epoch 30/100
# 157/157 [==============================] - 0s 458us/sample - loss: 0.1403 - mean_absolute_error: 0.1403
# Epoch 31/100
# 157/157 [==============================] - 0s 471us/sample - loss: 0.1505 - mean_absolute_error: 0.1505
# Epoch 32/100
# 157/157 [==============================] - 0s 482us/sample - loss: 0.1369 - mean_absolute_error: 0.1369
# Epoch 33/100
# 157/157 [==============================] - 0s 450us/sample - loss: 0.1416 - mean_absolute_error: 0.1416
# Epoch 34/100
# 157/157 [==============================] - 0s 519us/sample - loss: 0.1376 - mean_absolute_error: 0.1376
# Epoch 35/100
# 157/157 [==============================] - 0s 476us/sample - loss: 0.1455 - mean_absolute_error: 0.1455
# Epoch 36/100
# 157/157 [==============================] - 0s 465us/sample - loss: 0.1428 - mean_absolute_error: 0.1428
# Epoch 37/100
# 157/157 [==============================] - 0s 464us/sample - loss: 0.1435 - mean_absolute_error: 0.1435
# Epoch 38/100
# 157/157 [==============================] - 0s 459us/sample - loss: 0.1296 - mean_absolute_error: 0.1296
# Epoch 39/100
# 157/157 [==============================] - 0s 611us/sample - loss: 0.1463 - mean_absolute_error: 0.1463
# Epoch 40/100
# 157/157 [==============================] - 0s 470us/sample - loss: 0.1417 - mean_absolute_error: 0.1417
# Epoch 41/100
# 157/157 [==============================] - 0s 480us/sample - loss: 0.1416 - mean_absolute_error: 0.1416
# Epoch 42/100
# 157/157 [==============================] - 0s 466us/sample - loss: 0.1474 - mean_absolute_error: 0.1474
# Epoch 43/100
# 157/157 [==============================] - 0s 474us/sample - loss: 0.1373 - mean_absolute_error: 0.1373
# Epoch 44/100
# 157/157 [==============================] - 0s 450us/sample - loss: 0.1480 - mean_absolute_error: 0.1480
# Epoch 45/100
# 157/157 [==============================] - 0s 481us/sample - loss: 0.1402 - mean_absolute_error: 0.1402
# Epoch 46/100
# 157/157 [==============================] - 0s 526us/sample - loss: 0.1351 - mean_absolute_error: 0.1351
# Epoch 47/100
# 157/157 [==============================] - 0s 490us/sample - loss: 0.1372 - mean_absolute_error: 0.1372
# Epoch 48/100
# 157/157 [==============================] - 0s 455us/sample - loss: 0.1380 - mean_absolute_error: 0.1380
# Epoch 49/100
# 157/157 [==============================] - 0s 462us/sample - loss: 0.1458 - mean_absolute_error: 0.1458
# Epoch 50/100
# 157/157 [==============================] - 0s 461us/sample - loss: 0.1364 - mean_absolute_error: 0.1364
# Epoch 51/100
# 157/157 [==============================] - 0s 484us/sample - loss: 0.1463 - mean_absolute_error: 0.1463
# Epoch 52/100
# 157/157 [==============================] - 0s 607us/sample - loss: 0.1419 - mean_absolute_error: 0.1419
# Epoch 53/100
# 157/157 [==============================] - 0s 469us/sample - loss: 0.1344 - mean_absolute_error: 0.1344
# Epoch 54/100
# 157/157 [==============================] - 0s 469us/sample - loss: 0.1325 - mean_absolute_error: 0.1325
# Epoch 55/100
# 157/157 [==============================] - 0s 477us/sample - loss: 0.1419 - mean_absolute_error: 0.1419
# Epoch 56/100
# 157/157 [==============================] - 0s 460us/sample - loss: 0.1310 - mean_absolute_error: 0.1310
# Epoch 57/100
# 157/157 [==============================] - 0s 476us/sample - loss: 0.1371 - mean_absolute_error: 0.1371
# Epoch 58/100
# 157/157 [==============================] - 0s 369us/sample - loss: 0.1308 - mean_absolute_error: 0.1308
# Epoch 59/100
# 157/157 [==============================] - 0s 361us/sample - loss: 0.1362 - mean_absolute_error: 0.1362
# Epoch 60/100
# 157/157 [==============================] - 0s 486us/sample - loss: 0.1409 - mean_absolute_error: 0.1409
# Epoch 61/100
# 157/157 [==============================] - 0s 416us/sample - loss: 0.1355 - mean_absolute_error: 0.1355
# Epoch 62/100
# 157/157 [==============================] - 0s 441us/sample - loss: 0.1381 - mean_absolute_error: 0.1381
# Epoch 63/100
# 157/157 [==============================] - 0s 484us/sample - loss: 0.1437 - mean_absolute_error: 0.1437
# Epoch 64/100
# 157/157 [==============================] - 0s 400us/sample - loss: 0.1346 - mean_absolute_error: 0.1346
# Epoch 65/100
# 157/157 [==============================] - 0s 483us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 66/100
# 157/157 [==============================] - 0s 393us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 67/100
# 157/157 [==============================] - 0s 461us/sample - loss: 0.1371 - mean_absolute_error: 0.1371
# Epoch 68/100
# 157/157 [==============================] - 0s 469us/sample - loss: 0.1330 - mean_absolute_error: 0.1330
# Epoch 69/100
# 157/157 [==============================] - 0s 386us/sample - loss: 0.1404 - mean_absolute_error: 0.1404
# Epoch 70/100
# 157/157 [==============================] - 0s 424us/sample - loss: 0.1428 - mean_absolute_error: 0.1428
# Epoch 71/100
# 157/157 [==============================] - 0s 437us/sample - loss: 0.1448 - mean_absolute_error: 0.1448
# Epoch 72/100
# 157/157 [==============================] - 0s 314us/sample - loss: 0.1310 - mean_absolute_error: 0.1310
# Epoch 73/100
# 157/157 [==============================] - 0s 367us/sample - loss: 0.1425 - mean_absolute_error: 0.1425
# Epoch 74/100
# 157/157 [==============================] - 0s 400us/sample - loss: 0.1341 - mean_absolute_error: 0.1341
# Epoch 75/100
# 157/157 [==============================] - 0s 310us/sample - loss: 0.1332 - mean_absolute_error: 0.1332
# Epoch 76/100
# 157/157 [==============================] - 0s 308us/sample - loss: 0.1457 - mean_absolute_error: 0.1457
# Epoch 77/100
# 157/157 [==============================] - 0s 349us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 78/100
# 157/157 [==============================] - 0s 360us/sample - loss: 0.1345 - mean_absolute_error: 0.1345
# Epoch 79/100
# 157/157 [==============================] - 0s 346us/sample - loss: 0.1286 - mean_absolute_error: 0.1286
# Epoch 80/100
# 157/157 [==============================] - 0s 344us/sample - loss: 0.1351 - mean_absolute_error: 0.1351
# Epoch 81/100
# 157/157 [==============================] - 0s 346us/sample - loss: 0.1340 - mean_absolute_error: 0.1340
# Epoch 82/100
# 157/157 [==============================] - 0s 311us/sample - loss: 0.1368 - mean_absolute_error: 0.1368
# Epoch 83/100
# 157/157 [==============================] - 0s 314us/sample - loss: 0.1429 - mean_absolute_error: 0.1429
# Epoch 84/100
# 157/157 [==============================] - 0s 350us/sample - loss: 0.1307 - mean_absolute_error: 0.1307
# Epoch 85/100
# 157/157 [==============================] - 0s 366us/sample - loss: 0.1395 - mean_absolute_error: 0.1395
# Epoch 86/100
# 157/157 [==============================] - 0s 366us/sample - loss: 0.1337 - mean_absolute_error: 0.1337
# Epoch 87/100
# 157/157 [==============================] - 0s 325us/sample - loss: 0.1369 - mean_absolute_error: 0.1369
# Epoch 88/100
# 157/157 [==============================] - 0s 357us/sample - loss: 0.1382 - mean_absolute_error: 0.1382
# Epoch 89/100
# 157/157 [==============================] - 0s 312us/sample - loss: 0.1273 - mean_absolute_error: 0.1273
# Epoch 90/100
# 157/157 [==============================] - 0s 312us/sample - loss: 0.1357 - mean_absolute_error: 0.1357
# Epoch 91/100
# 157/157 [==============================] - 0s 369us/sample - loss: 0.1275 - mean_absolute_error: 0.1275
# Epoch 92/100
# 157/157 [==============================] - 0s 321us/sample - loss: 0.1411 - mean_absolute_error: 0.1411
# Epoch 93/100
# 157/157 [==============================] - 0s 351us/sample - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 94/100
# 157/157 [==============================] - 0s 351us/sample - loss: 0.1360 - mean_absolute_error: 0.1360
# Epoch 95/100
# 157/157 [==============================] - 0s 352us/sample - loss: 0.1281 - mean_absolute_error: 0.1281
# Epoch 96/100
# 157/157 [==============================] - 0s 319us/sample - loss: 0.1330 - mean_absolute_error: 0.1330
# Epoch 97/100
# 157/157 [==============================] - 0s 358us/sample - loss: 0.1268 - mean_absolute_error: 0.1268
# Epoch 98/100
# 157/157 [==============================] - 0s 351us/sample - loss: 0.1346 - mean_absolute_error: 0.1346
# Epoch 99/100
# 157/157 [==============================] - 0s 351us/sample - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 100/100
# 157/157 [==============================] - 0s 316us/sample - loss: 0.1298 - mean_absolute_error: 0.1298

# %%
#Preparação para plotagem

train_predict_plot = np.empty_like(data)
train_predict_plot[:, :] = np.nan
train_predict_plot[lags: len(previsoes_treino) + lags, :] = previsoes_treino
train_predict_plot.shape
    
test_predict_plot = np.empty_like(data)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(previsoes_treino)+lags:len(data), :] = previsoes

#Plotagem do gráfico
plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(train_predict_plot, color = 'green', label = 'Previsão de treino')
plt.plot(test_predict_plot, color = '#ff0066', label = 'Previsão de teste')
plt.title('Predição do pH com lag = 10%')
plt.xlabel('Bimestre')
plt.ylabel('Valor pH')
plt.legend()
plt.grid()
plt.show()
    
#Calculo do erro da previsão
#mape(previsoes.mean(),test.mean())
test = sc.inverse_transform(test)
treino = sc.inverse_transform(train[lags: len(previsoes_treino) + lags, :])

print('Resultados com lag', lags)
print('\n')
print('MAPE TREINO:',round(mape(previsoes_treino,treino)[0],2),'%')
print('RMSE TREINO:',round(rmse(previsoes_treino,treino),2))
print('\n')
print('MAPE TESTE:',round(mape(previsoes,test)[0],2),'%')
print('RMSE TESTE:',round(rmse(previsoes,test),2))
print('\n')
# Out:
# Resultados com lag 17
#
#
# MAPE TREINO: 2.26 %
# RMSE TREINO: 0.14
#
#
# MAPE TESTE: 1.34 %
# RMSE TESTE: 0.17

# %%
# Out:
# (248, 1)

# %%
# Out:
# 174
