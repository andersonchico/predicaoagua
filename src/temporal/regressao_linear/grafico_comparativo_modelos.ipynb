# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (8,6)

# %%
#Comparação entre os modelos de regressão linear com 10%, 25% e 50% dos dados de treinamento como janela de visualização.
#Metrica MAPE
labels = ['RL1', 'RL2', 'RL3'] #Modelos RL - Regressão Linear
men_means = [2.18, 1.66, 0.00] # Treinamento
women_means = [1.33, 1.51, 10.62] # Teste

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Treinamento')
rects2 = ax.bar(x + width/2, women_means, width, label='Teste')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylim(0, 11)
ax.set_ylabel('% Erro (MAPE)')
ax.set_xlabel('Modelos')
#ax.set_title('RMSE Médio por modelo e parâmetro')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


#autolabel(rects1)
#autolabel(rects2)

fig.tight_layout()
#ax.legend(plt.legend(loc='upper left', bbox_to_anchor=(0.1, -0.4), shadow=True, ncol=8))
plt.show()

# %%
#Comparação entre os modelos de regressão linear com 10%, 25% e 50% dos dados de treinamento como janela de visualização.
#Metrica RMSE
labels = ['RL1', 'RL2', 'RL3'] #Modelos RL - Regressão Linear
men_means = [0.13, 0.12, 0.00] # Treinamento
women_means = [0.16, 0.18, 1.23] # Teste

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Treinamento')
rects2 = ax.bar(x + width/2, women_means, width, label='Teste')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylim(0, 1.3)
ax.set_ylabel('Erro (RMSE)')
ax.set_xlabel('Modelos')
#ax.set_title('RMSE Médio por modelo e parâmetro')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


#autolabel(rects1)
#autolabel(rects2)

fig.tight_layout()
#ax.legend(plt.legend(loc='upper left', bbox_to_anchor=(0.1, -0.4), shadow=True, ncol=8))
plt.show()
