# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# C:\Users\Anderson\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

ugrhi10 = trainingd

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
ugrhi10
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '06 - ALTO TIÊTE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [251 rows x 1 columns]

# %%
for field in trainingd.columns:
    print(field, 'NaN:', trainingd[field].isnull().sum())
# Out:
# valor NaN: 2

# %%
trainingd = trainingd.dropna(axis=0,how='any')

# %%
for field in trainingd.columns:
    print(field, 'NaN:', trainingd[field].isnull().sum())
trainingd
# Out:
# valor NaN: 0
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [249 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < inferior.valor)]

outlier
# Out:
# primeiro_quartil: valor    6.583333
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.002667
# Name: 0.75, dtype: float64
# fig: valor    0.419333
# dtype: float64
# Inferior: valor    5.954333
# dtype: float64
# Superior: valor    7.631667
# dtype: float64
# C:\Users\Anderson\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                 valor
# data_coleta
# 1979-11-30   5.916667
# 1985-03-31   5.883333

# %%
trainingd
# Out:
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [249 rows x 1 columns]

# %%
#Remove a última linha do dataframe
trainingd = trainingd.drop(trainingd[trainingd.index == '2019-09-30'].index)

# %%
trainingd.describe()
# Out:
#             valor
# count  248.000000
# mean     6.793328
# std      0.294764
# min      5.883333
# 25%      6.581944
# 50%      6.838095
# 75%      7.001821
# max      7.405000

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingds.valor < inferior.valor] = 6.79

ugrhi06 = trainingd

outlier = trainingd[(trainingd.valor < inferior.valor)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
X = ugrhi10
y = ugrhi06

assert X.shape == (len(X),1)
assert y.shape == (len(y),1)

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
sc = MinMaxScaler()
X = sc.fit_transform(X)
y = sc.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3)

#y_train

# %%
regression = MLPRegressor(hidden_layer_sizes=(10,21),max_iter=5000,tol=0.0001,verbose=True)
regression.fit(X_train,y_train)

y_pred = regression.predict(X_test)
y_pred = y_pred.reshape(-1,1)
y_pred = sc.inverse_transform(y_pred)

y_pred

#X_test = sc.inverse_transform(X_test)
#y_test = sc.inverse_transform(y_test)
# Out:
# Iteration 1, loss = 0.84363832
# Iteration 2, loss = 0.81853754
# Iteration 3, loss = 0.79359727
# Iteration 4, loss = 0.76883088
# Iteration 5, loss = 0.74424624
# Iteration 6, loss = 0.71985073
# Iteration 7, loss = 0.69567186
# Iteration 8, loss = 0.67165793
# Iteration 9, loss = 0.64784338
# Iteration 10, loss = 0.62425044
# Iteration 11, loss = 0.60095027
# Iteration 12, loss = 0.57800240
# Iteration 13, loss = 0.55540476
# Iteration 14, loss = 0.53317126
# Iteration 15, loss = 0.51127447
# Iteration 16, loss = 0.48977750
# Iteration 17, loss = 0.46861232
# Iteration 18, loss = 0.44777407
# Iteration 19, loss = 0.42724117
# Iteration 20, loss = 0.40714089
# Iteration 21, loss = 0.38756005
# Iteration 22, loss = 0.36851425
# Iteration 23, loss = 0.34999774
# Iteration 24, loss = 0.33203937
# Iteration 25, loss = 0.31470236
# Iteration 26, loss = 0.29807355
# Iteration 27, loss = 0.28197569
# Iteration 28, loss = 0.26632865
# Iteration 29, loss = 0.25111897
# Iteration 30, loss = 0.23636734
# Iteration 31, loss = 0.22207604
# Iteration 32, loss = 0.20823214
# Iteration 33, loss = 0.19482107
# Iteration 34, loss = 0.18186085
# Iteration 35, loss = 0.16939776
# Iteration 36, loss = 0.15742152
# Iteration 37, loss = 0.14592389
# Iteration 38, loss = 0.13492976
# Iteration 39, loss = 0.12445282
# Iteration 40, loss = 0.11445033
# Iteration 41, loss = 0.10491028
# Iteration 42, loss = 0.09592372
# Iteration 43, loss = 0.08746189
# Iteration 44, loss = 0.07951184
# Iteration 45, loss = 0.07209715
# Iteration 46, loss = 0.06522834
# Iteration 47, loss = 0.05892701
# Iteration 48, loss = 0.05315963
# Iteration 49, loss = 0.04790416
# Iteration 50, loss = 0.04315747
# Iteration 51, loss = 0.03891115
# Iteration 52, loss = 0.03513769
# Iteration 53, loss = 0.03180616
# Iteration 54, loss = 0.02888220
# Iteration 55, loss = 0.02635126
# Iteration 56, loss = 0.02418188
# Iteration 57, loss = 0.02234684
# Iteration 58, loss = 0.02082203
# Iteration 59, loss = 0.01957902
# Iteration 60, loss = 0.01859084
# Iteration 61, loss = 0.01782716
# Iteration 62, loss = 0.01726274
# Iteration 63, loss = 0.01686984
# Iteration 64, loss = 0.01662190
# Iteration 65, loss = 0.01649302
# Iteration 66, loss = 0.01645969
# Iteration 67, loss = 0.01649885
# Iteration 68, loss = 0.01658978
# Iteration 69, loss = 0.01671598
# Iteration 70, loss = 0.01686156
# Iteration 71, loss = 0.01701360
# Iteration 72, loss = 0.01716145
# Iteration 73, loss = 0.01729695
# Iteration 74, loss = 0.01741356
# Iteration 75, loss = 0.01750714
# Iteration 76, loss = 0.01757537
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# C:\Users\Anderson\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:1321: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[25.3778081 ],
#        [24.64219974],
#        [25.27749786],
#        [25.59514693],
#        [24.77594671],
#        [24.87625694],
#        [24.8428202 ],
#        [25.57842856],
#        [25.23291554],
#        [25.28752889],
#        [24.21588126],
#        [25.92951436],
#        [25.45582716],
#        [25.1353917 ],
#        [24.92641206],
#        [24.09049347],
#        [25.34437135],
#        [24.67563648],
#        [25.13037619],
#        [25.04344066],
#        [24.74529636],
#        [25.46595951],
#        [24.29947312],
#        [24.8985481 ],
#        [23.97346487],
#        [25.84257883],
#        [25.22495441],
#        [24.38306498],
#        [24.55024869],
#        [25.54499181],
#        [25.59514693],
#        [25.09359578],
#        [24.8428202 ],
#        [25.01000392],
#        [25.09359578],
#        [25.51489874],
#        [25.37112075],
#        [24.90969369],
#        [25.54499181],
#        [25.51155507],
#        [24.94313043],
#        [25.67873879],
#        [25.87935925],
#        [25.38616728],
#        [25.36108972],
#        [25.03090188],
#        [24.47501602],
#        [24.82610183],
#        [25.63276327],
#        [24.10721184],
#        [24.55024869],
#        [24.59204462],
#        [24.8428202 ],
#        [25.15330425],
#        [25.13159207],
#        [25.07019005],
#        [24.4248609 ],
#        [25.71217553],
#        [24.90969369],
#        [24.74250997],
#        [25.67873879],
#        [25.39452647],
#        [24.59204462],
#        [25.31093461],
#        [25.19390601],
#        [25.01000392],
#        [25.0338873 ],
#        [24.98910595],
#        [25.37223531],
#        [25.1980856 ],
#        [25.57842856],
#        [24.99328554],
#        [24.46665683],
#        [24.71743241],
#        [25.34437135]])

# %%
plt.scatter(X_test,y_test,color='red', label='Dados teste')
#plt.scatter(X_train,y_train,color='yellow', label='Dados treino')
plt.plot(X_test,y_pred,color='blue',label='Dados previsto')
plt.xlabel('UGRHI10')
plt.ylabel('UGRHI06')
plt.legend()
plt.title('Predição UGRHI 10 Vs UGRHI06')
plt.show()

# %%
def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_test,y_pred)
    return rscore

# %%
print('\n')
print('MAPE TESTE:',round(mape(y_pred,y_test)[0],2),'%')
print('RMSE TESTE:',round(rmse(y_pred,y_test),2))
print('R TESTE:',round(r2(y_pred,y_test),2))
print('\n')
# Out:
# MAPE TESTE: 1.87 %
# RMSE TESTE: 0.22
# R TESTE: 0.32
