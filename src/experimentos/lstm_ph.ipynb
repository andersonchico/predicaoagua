# %% [markdown]
# Modelo LSTM para prever o parâmetro pH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping
import math
import matplotlib.pyplot as plt
plt.rcParams['xtick.labelsize']=18
plt.rcParams['ytick.labelsize']=18
plt.rcParams.update({'font.size':18})

# %%
str_files = ''

#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.csv',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)

# %%
#df.head()

# %%
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']
#z.info()

# %%
z = z.dropna(axis=1,how='any')
#for field in z.columns:
    #print(field,'NaN',z[field].isnull().sum())
#print(len(z))

# %%
trainingd = z.resample('3M').mean()
trainingd = trainingd.iloc[:,1:2].values
print(len(trainingd))
# Out:
# 166

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training_set_scaled = sc.fit_transform(trainingd)
#training_set_scaled

# %%
x_train = []
y_train = []
timestamp = 33
length = len(trainingd)
for i in range(timestamp, length):
    x_train.append(training_set_scaled[i-timestamp:i, 0])
    y_train.append(training_set_scaled[i, 0])

x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
print (x_train[0])
print ('\n')
print (y_train[0])
# Out:
# [0.53333333 0.06666667 0.20808081 0.12323232 0.29292929 0.49090909
#  0.34949495 0.05252525 0.06666667 0.19393939 0.08080808 0.32121212
#  0.36363636 0.22222222 0.29292929 0.10909091 0.         0.05252525
#  0.04309764 0.26936027 0.25757576 0.19393939 0.19393939 0.26464646
#  0.43636364 0.32828283 0.28727273 0.54040404 0.56868687 0.0030303
#  0.33181818 0.37777778 0.53333333]
#
#
# 0.16565656565656628

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (133, 33, 1)

# %%
test_set = df.loc[df['UGRHI'] == '06 - ALTO TIÊTE']
test_set = test_set.dropna(axis=1,how='any')
#for field in test_set.columns:
    #print(field,'NaN',test_set[field].isnull().sum())
    
test_set = test_set.resample('3M').mean()
y_test = test_set.iloc[timestamp:,1:2].values


valor = test_set.iloc[:,1:2].values
valor_scaled = sc.transform(valor)

x_test = []
length = len(test_set)

for i in range(timestamp, length):
    x_test.append(valor_scaled[i-timestamp:i,0])
    
x_test = np.array(x_test)
x_test.shape

x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1],1))
x_test.shape
# Out:
# (135, 33, 1)

# %%
test_x = []
test_y = []

length = len(test_set)
for i in range(timestamp, length):
    test_x.append(valor_scaled[i-timestamp:i, 0])
    test_y.append(valor_scaled[i, 0])

test_x = np.array(test_x)
test_y = np.array(test_y)

test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], 1))
test_x.shape
# Out:
# (135, 33, 1)

# %%
#neuronios = [16,60,120]
resultado_mse = []
qtde_neuronios =[]

print("Rede Neural LSTM com 10 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 10, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 10, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

#es = EarlyStopping(monitor='val_loss',mode='auto',verbose = 1,patience=5)

h10 = model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_data=(test_x,test_y))

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual',marker='o')
plt.plot(predicted_valor, color='red', linewidth = 3,label='Valor Previsto')
plt.title('10 neurônios')
plt.xlabel('Trimestre')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(10)
# Out:
# Rede Neural LSTM com 10 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples, validate on 135 samples
# Epoch 1/100
# 133/133 [==============================] - 20s 151ms/sample - loss: 0.1555 - val_loss: 0.0253
# Epoch 2/100
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0537 - val_loss: 0.0290
# Epoch 3/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0473 - val_loss: 0.0287
# Epoch 4/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0459 - val_loss: 0.0204
# Epoch 5/100
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0457 - val_loss: 0.0199
# Epoch 6/100
# 133/133 [==============================] - 2s 15ms/sample - loss: 0.0451 - val_loss: 0.0243
# Epoch 7/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0450 - val_loss: 0.0207
# Epoch 8/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0451 - val_loss: 0.0190
# Epoch 9/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0431 - val_loss: 0.0192
# Epoch 10/100
# 133/133 [==============================] - 2s 11ms/sample - loss: 0.0330 - val_loss: 0.0213
# Epoch 11/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0408 - val_loss: 0.0182
# Epoch 12/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0355 - val_loss: 0.0176
# Epoch 13/100
# 133/133 [==============================] - 2s 11ms/sample - loss: 0.0368 - val_loss: 0.0178
# Epoch 14/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0357 - val_loss: 0.0184
# Epoch 15/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0392 - val_loss: 0.0182
# Epoch 16/100
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0334 - val_loss: 0.0172
# Epoch 17/100
print(train_score10)
print('Pontuação de Treino: {:.2f} MSE ({:.2f} RMSE)'.format(train_score10, math.sqrt(train_score10)))
test_score10 = model.evaluate(test_x, test_y, verbose=0)
print('Pontuação de teste: {:.2f} MSE ({:.2f} RMSE)'.format(test_score10, math.sqrt(test_score10)))
# Out:
# 0.021430094439284245
# Pontuação de Treino: 0.02 MSE (0.15 RMSE)
# Pontuação de teste: 0.02 MSE (0.13 RMSE)

# %%
plt.ylim(0,0.4)
plt.plot(h10.history['loss'],'blue',linewidth = 3,label='Treino')
plt.plot(h10.history['val_loss'],'red',linewidth = 3,label='Teste')
plt.title('10 neurônios')
plt.ylabel('Taxa de perda')
plt.xlabel('épocas')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("Rede Neural LSTM com 25 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 25, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 25, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 25, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

#es = EarlyStopping(monitor='val_loss',mode='min',verbose = 1)

h25 = model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_data=(test_x,test_y))

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual',marker='o')
plt.plot(predicted_valor, color='red',linewidth = 3, label='Valor Previsto')
plt.title('25 neurônios')
plt.xlabel('Trimestre')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(25)
# Out:
# Rede Neural LSTM com 25 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples, validate on 135 samples
# Epoch 1/100
# 133/133 [==============================] - 20s 149ms/sample - loss: 0.2896 - val_loss: 0.0628
# Epoch 2/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.1016 - val_loss: 0.0236
# Epoch 3/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0517 - val_loss: 0.0621
# Epoch 4/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0513 - val_loss: 0.0252
# Epoch 5/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0355 - val_loss: 0.0211
# Epoch 6/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0366 - val_loss: 0.0220
# Epoch 7/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0327 - val_loss: 0.0292
# Epoch 8/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0392 - val_loss: 0.0326
# Epoch 9/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0295 - val_loss: 0.0227
# Epoch 10/100
# Epoch 95/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0252 - val_loss: 0.0178
# Epoch 96/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0259 - val_loss: 0.0172
# Epoch 97/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0261 - val_loss: 0.0170
# Epoch 98/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0290 - val_loss: 0.0182
# Epoch 99/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0272 - val_loss: 0.0182
# Epoch 100/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0282 - val_loss: 0.0170

# %%
train_score25 = model.evaluate(x_train, y_train, verbose=0)
print(train_score25)
print('Pontuação de Treino: {:.2f} MSE ({:.2f} RMSE)'.format(train_score25, math.sqrt(train_score25)))
test_score25 = model.evaluate(test_x, test_y, verbose=0)
print('Pontuação de teste: {:.2f} MSE ({:.2f} RMSE)'.format(test_score25, math.sqrt(test_score25)))
# Out:
# 0.023079360618179005
# Pontuação de Treino: 0.02 MSE (0.15 RMSE)
# Pontuação de teste: 0.02 MSE (0.13 RMSE)

# %%
plt.ylim(0,0.4)
plt.plot(h25.history['loss'],'blue',linewidth = 3,label='Treino')
plt.plot(h25.history['val_loss'],'red',linewidth = 3,label='Teste')
plt.title('25 neurônios')
plt.ylabel('Taxa de perda')
plt.xlabel('épocas')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("Rede Neural LSTM com 50 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

#es = EarlyStopping(monitor='val_loss',mode='auto',verbose = 1)

h50 = model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_data=(test_x,test_y))

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual',marker='o')
plt.plot(predicted_valor, color='red',linewidth = 3,label='Valor Previsto')
plt.title('50 neurônios')
plt.xlabel('Trimestre')
plt.ylabel('Valor do pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(50)
# Out:
# Rede Neural LSTM com 50 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples, validate on 135 samples
# Epoch 1/100
# 133/133 [==============================] - 18s 139ms/sample - loss: 0.2044 - val_loss: 0.0190
# Epoch 2/100
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0427 - val_loss: 0.0263
# Epoch 3/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0354 - val_loss: 0.0223
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0239 - val_loss: 0.0178
# Epoch 89/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0252 - val_loss: 0.0170
# Epoch 90/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0260 - val_loss: 0.0175
# Epoch 91/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0265 - val_loss: 0.0214
# Epoch 92/100
# 133/133 [==============================] - 2s 11ms/sample - loss: 0.0293 - val_loss: 0.0171
# Epoch 93/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0245 - val_loss: 0.0176
# Epoch 94/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0271 - val_loss: 0.0186
# Epoch 95/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0247 - val_loss: 0.0173
# Epoch 96/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0248 - val_loss: 0.0171
# Epoch 97/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0240 - val_loss: 0.0199
# Epoch 98/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0268 - val_loss: 0.0189
# Epoch 99/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0285 - val_loss: 0.0173
# Epoch 100/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0239 - val_loss: 0.0203
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8724523bfc50> in <module>
#      29 #print("MSE:", round(mse,2))
#      30
# ---> 31 resultado_mse.append(mse)
#      32 qtde_neuronios.append(50)
#
# NameError: name 'resultado_mse' is not defined

# %%
train_score50 = model.evaluate(x_train, y_train, verbose=0)
print(train_score50)
print('Pontuação de Treino: {:.2f} MSE ({:.2f} RMSE)'.format(train_score50, math.sqrt(train_score50)))
test_score50 = model.evaluate(test_x, test_y, verbose=0)
print('Pontuação de teste: {:.2f} MSE ({:.2f} RMSE)'.format(test_score50, math.sqrt(test_score50)))
# Out:
# 0.022469188737914078
# Pontuação de Treino: 0.02 MSE (0.15 RMSE)
# Pontuação de teste: 0.02 MSE (0.14 RMSE)

# %%
plt.ylim(0,0.4)
plt.plot(h50.history['loss'],'blue',linewidth = 3,label='Treino')
plt.plot(h50.history['val_loss'],'red',linewidth = 3,label='Teste')
plt.title('50 neurônios')
plt.ylabel('Taxa de perda')
plt.xlabel('épocas')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
str_files = ''

#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.csv',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)

# %%
test_set = df.loc[df['UGRHI'] == '07 - BAIXADA SANTISTA']
test_set = test_set.dropna(axis=1,how='any')
#for field in test_set.columns:
    #print(field,'NaN',test_set[field].isnull().sum())
    
test_set = test_set.resample('3M').mean()
y_test = test_set.iloc[timestamp:,1:2].values


valor = test_set.iloc[:,1:2].values
valor_scaled = sc.transform(valor)

x_test = []
length = len(test_set)

for i in range(timestamp, length):
    x_test.append(valor_scaled[i-timestamp:i,0])
    
x_test = np.array(x_test)
x_test.shape

x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1],1))
x_test.shape
# Out:
# (22, 33, 1)

# %%
test_x = []
test_y = []

length = len(test_set)
for i in range(timestamp, length):
    test_x.append(valor_scaled[i-timestamp:i, 0])
    test_y.append(valor_scaled[i, 0])

test_x = np.array(test_x)
test_y = np.array(test_y)

test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], 1))
test_x.shape
# Out:
# (44, 33, 1)

# %%
resultado_mse2 = []

print("Rede Neural LSTM com 10 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 10, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 10, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

h10 = model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_data=(test_x,test_y))

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual',marker='o')
plt.plot(predicted_valor, color='red', linewidth = 3,label='Valor Previsto')
plt.title('10 neurônios')
plt.xlabel('Trimestre')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse2.append(mse)
#qtde_neuronios.append(10)
# Out:
# Rede Neural LSTM com 10 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples, validate on 44 samples
# Epoch 1/100
# 133/133 [==============================] - 19s 145ms/sample - loss: 0.3856 - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 2/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.3199 - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 3/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.2632 - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 4/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.2125 - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 5/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.1396 - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 6/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0750 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 7/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0484 - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0297 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 85/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0291 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 86/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0309 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 87/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0336 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 88/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0312 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 89/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0311 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 90/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0319 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 91/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0293 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 92/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0297 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 93/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0313 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 94/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0295 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 95/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0266 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 96/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0281 - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 97/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 0.0278 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 98/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 0.0336 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 99/100
# 133/133 [==============================] - 4s 32ms/sample - loss: 0.0247 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 100/100
# 133/133 [==============================] - 18s 137ms/sample - loss: 0.0279 - accuracy: 0.0075 - val_loss: nan - val_accuracy: 0.0000e+00

# %%
real_m = []
previsto_m = []
mse_m = []

for i in range(len(y_test)):
    real_m.append(round(y_test[i][0],2))
    #print("Real:",round(y_test[i][0],2))

for i in range(len(predicted_valor)):
    previsto_m.append(round(predicted_valor[i][0],2))
    #print("Previsto",round(predicted_valor[i][0],2))
    
for i in range(len(predicted_valor)):
    mse = np.square(np.subtract(y_test[i][0],predicted_valor[i][0])).mean()
    mse_m.append(mse)

# %%
print("Rede Neural LSTM com 40 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 40, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 40, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 40, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 40, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(40)
# Out:
# Rede Neural LSTM com 40 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 20s 151ms/sample - loss: 0.2149 - accuracy: 0.0000e+00
# Epoch 2/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0565 - accuracy: 0.0075
# Epoch 3/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0306 - accuracy: 0.0075
# Epoch 4/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0366 - accuracy: 0.0000e+00
# Epoch 5/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0267 - accuracy: 0.0075
# Epoch 6/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0293 - accuracy: 0.0075
# Epoch 7/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0307 - accuracy: 0.0075
# Epoch 8/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0286 - accuracy: 0.0075
# Epoch 9/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0283 - accuracy: 0.0075
# Epoch 10/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0289 - accuracy: 0.0075
# Epoch 11/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 12/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 13/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0313 - accuracy: 0.0075
# Epoch 14/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0270 - accuracy: 0.0075
# Epoch 15/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0268 - accuracy: 0.0075
# Epoch 16/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0264 - accuracy: 0.0075
# Epoch 17/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0284 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0240 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0261 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0289 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0268 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0259 - accuracy: 0.0075

# %%
print("Rede Neural LSTM com 60 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 60, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 60, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 60, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 60, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(60)
# Out:
# Rede Neural LSTM com 60 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 21s 155ms/sample - loss: 0.2194 - accuracy: 0.0000e+00
# Epoch 2/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0649 - accuracy: 0.0075
# Epoch 3/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0493 - accuracy: 0.0075
# Epoch 4/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0304 - accuracy: 0.0075
# Epoch 5/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0344 - accuracy: 0.0075
# Epoch 6/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0327 - accuracy: 0.0075
# Epoch 7/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0326 - accuracy: 0.0075
# Epoch 8/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0298 - accuracy: 0.0075
# Epoch 9/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0288 - accuracy: 0.0075
# Epoch 10/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0281 - accuracy: 0.0075
# Epoch 11/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0224 - accuracy: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0233 - accuracy: 0.0075
# Epoch 41/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0261 - accuracy: 0.0075
# Epoch 42/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 43/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0264 - accuracy: 0.0075
# Epoch 44/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0281 - accuracy: 0.0075
# Epoch 45/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0266 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0283 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0254 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0255 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0241 - accuracy: 0.0075

# %%
print("Rede Neural LSTM com 81 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 81, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 81, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 81, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 81, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(81)
# Out:
# Rede Neural LSTM com 81 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 21s 155ms/sample - loss: 0.1978 - accuracy: 0.0075
# Epoch 2/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0559 - accuracy: 0.0075
# Epoch 3/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0434 - accuracy: 0.0075
# Epoch 4/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0355 - accuracy: 0.0075
# Epoch 5/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 34/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 35/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0251 - accuracy: 0.0075
# Epoch 36/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0250 - accuracy: 0.0075
# Epoch 37/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0243 - accuracy: 0.0075
# Epoch 38/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0259 - accuracy: 0.0075
# Epoch 39/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0247 - accuracy: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0229 - accuracy: 0.0075
# Epoch 41/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0233 - accuracy: 0.0075
# Epoch 42/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0282 - accuracy: 0.0075
# Epoch 43/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0245 - accuracy: 0.0075
# Epoch 44/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0251 - accuracy: 0.0075
# Epoch 45/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0239 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0260 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0286 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0365 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0262 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0302 - accuracy: 0.0075

# %%
print("Rede Neural LSTM com 120 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 120, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 120, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 120, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 120, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(120)
# Out:
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0237 - accuracy: 0.0075
# Epoch 29/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0258 - accuracy: 0.0075
# Epoch 30/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0238 - accuracy: 0.0075
# Epoch 31/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0227 - accuracy: 0.0075
# Epoch 32/50
# 133/133 [==============================] - 2s 15ms/sample - loss: 0.0238 - accuracy: 0.0075
# Epoch 33/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0269 - accuracy: 0.0075
# Epoch 34/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0253 - accuracy: 0.0075
# Epoch 35/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0252 - accuracy: 0.0075
# Epoch 36/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0245 - accuracy: 0.0075
# Epoch 37/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0271 - accuracy: 0.0075
# Epoch 38/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0281 - accuracy: 0.0075
# Epoch 39/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0295 - accuracy: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0299 - accuracy: 0.0075
# Epoch 41/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0229 - accuracy: 0.0075
# Epoch 42/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0257 - accuracy: 0.0075
# Epoch 43/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0238 - accuracy: 0.0075
# Epoch 44/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0265 - accuracy: 0.0075
# Epoch 45/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0266 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0260 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0233 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0225 - accuracy: 0.0075

# %%
print("Rede Neural LSTM com 163 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 163, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 163, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 163, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 163, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(163)
# Out:
# Rede Neural LSTM com 163 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 22s 169ms/sample - loss: 0.1741 - accuracy: 0.0075
# Epoch 2/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0991 - accuracy: 0.0000e+00
# Epoch 3/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0381 - accuracy: 0.0075
# Epoch 4/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0337 - accuracy: 0.0075
# Epoch 5/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0297 - accuracy: 0.0075
# Epoch 6/50
# 133/133 [==============================] - 2s 18ms/sample - loss: 0.0267 - accuracy: 0.0075
# Epoch 7/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0283 - accuracy: 0.0075
# Epoch 8/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0253 - accuracy: 0.0075
# Epoch 9/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0256 - accuracy: 0.0075
# Epoch 10/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0256 - accuracy: 0.0075
# Epoch 11/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0235 - accuracy: 0.0075
# Epoch 12/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0252 - accuracy: 0.0075
# Epoch 13/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0232 - accuracy: 0.0075
# Epoch 14/50
# 133/133 [==============================] - 2s 18ms/sample - loss: 0.0248 - accuracy: 0.0075
# Epoch 15/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0243 - accuracy: 0.0075
# Epoch 16/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0259 - accuracy: 0.0075
# Epoch 17/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0248 - accuracy: 0.0075
# Epoch 18/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0250 - accuracy: 0.0075
# Epoch 19/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0251 - accuracy: 0.0075
# Epoch 20/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0270 - accuracy: 0.0075
# Epoch 21/50
# 133/133 [==============================] - 2s 19ms/sample - loss: 0.0248 - accuracy: 0.0075
# Epoch 22/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0237 - accuracy: 0.0075
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ef41d5b6f2dc> in <module>
#      29 #print("MSE:", round(mse,2))
#      30
# ---> 31 resultado_mse.append(mse)
#      32 qtde_neuronios.append(163)
#
# NameError: name 'resultado_mse' is not defined

# %%
real_p = []
previsto_p = []
mse_p = []

for i in range(len(y_test)):
    real_p.append(round(y_test[i][0],2))
    #print("Real:",round(y_test[i][0],2))

for i in range(len(predicted_valor)):
    previsto_p.append(round(predicted_valor[i][0],2))
    #print("Previsto",round(predicted_valor[i][0],2))
    
for i in range(len(predicted_valor)):
    mse = np.square(np.subtract(y_test[i][0],predicted_valor[i][0])).mean()
    mse_p.append(mse)

# %%
resultado_mse_ph = [0.029216,0.023934,0.023685]
resultado_mse_od=[1.953787,1.931592,1.204403]
qtde_neuronios = [10,25,50]

d = {'N_neuronios':qtde_neuronios,
     'MSE_PH':resultado_mse_ph,
     'MSE_OD':resultado_mse_od}

tabela = pd.DataFrame(d)
tabela = tabela.sort_values(by=['N_neuronios'])
tabela
# Out:
#    N_neuronios       MSE      MSE2
# 0           10  0.029216  1.953787
# 1           25  0.023934  1.931592
# 2           50  0.023685  1.204403

# %%
plt.plot(tabela.N_neuronios.values,tabela.MSE2.values, color='red', label='Desempenho',marker='o')
plt.plot(tabela.N_neuronios.values,tabela.MSE.values, color='blue', label='Desempenho',marker='o')
plt.ylim(0.01,2)
plt.title('Rede LSTM: Nº Neurônios x MSE')
plt.xlabel('Nº Neurônios')
plt.ylabel('Erro Quadrático Médio- MSE')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(12,7))
plt.subplot(221)
plt.title('Parâmetro pH')
plt.plot(tabela.N_neuronios.values,tabela.MSE.values, color='blue', label='Desempenho',marker='o')
plt.xlabel('Nº Neurônios')
plt.ylabel('MSE')
plt.ylim(0.023,0.0296)
plt.legend()
plt.grid()

plt.subplot(222)
plt.title('Parâmetro OD')
plt.plot(tabela.N_neuronios.values,tabela.MSE2.values, color='red', label='Desempenho',marker='o')
plt.xlabel('Nº Neurônios')
#plt.ylabel('MSE')
plt.ylim(1,2.5)
plt.legend()
plt.grid()
plt.show()

# %%
test_set.resample('3M').mean()
# Out:
#              cod_interaguas     valor    Altitude
# data_coleta
# 1978-01-31       121.400000  6.680000  713.000000
# 1978-04-30       121.400000  6.566667  713.000000
# 1978-07-31       121.400000  6.553333  713.000000
# 1978-10-31       121.400000  6.193333  713.000000
# 1979-01-31       122.214286  6.221429  710.357143
# ...                     ...       ...         ...
# 2018-10-31       802.461538  7.260769  724.923077
# 2019-01-31       868.370370  7.049259  725.962963
# 2019-04-30      1781.000000  7.390000  720.200000
# 2019-07-31      1858.400000  7.352000  725.700000
# 2019-10-31      1505.000000  7.336667  716.666667
#
# [168 rows x 3 columns]

# %%
    
data = {'real50':real_m,
        'previsto50':previsto_m,
        'mse50':mse_m}

tabela = pd.DataFrame(data)
tabela.head(10)

r = tabela['real50'].mean()
p = tabela['previsto50'].mean()

dif_media = round(p-r,2)
dif_media
# Out:
# 0.01
