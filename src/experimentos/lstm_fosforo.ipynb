# %% [markdown]
# Modelo LSTM para prever o parâmetro pH
# Experimento:01

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import math
import matplotlib.pyplot as plt
plt.rcParams['xtick.labelsize']=18
plt.rcParams['ytick.labelsize']=18
plt.rcParams.update({'font.size':18})

# %%
str_files = ''

#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'Fosforo.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)

# %%
#df.head()

# %%
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']
#z.info()

# %%
z = z.dropna(axis=1,how='any')
#for field in z.columns:
    #print(field,'NaN',z[field].isnull().sum())
#print(len(z))

# %%
trainingd = z.resample('3M').mean()
trainingd = trainingd.iloc[:,1:2].values
print(len(trainingd))
# Out:
# 166

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training_set_scaled = sc.fit_transform(trainingd)
#training_set_scaled

# %%
x_train = []
y_train = []
timestamp = 33
length = len(trainingd)
for i in range(timestamp, length):
    x_train.append(training_set_scaled[i-timestamp:i, 0])
    y_train.append(training_set_scaled[i, 0])

x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
print (x_train[0])
print ('\n')
print (y_train[0])
# Out:
# [1.02204765e-03 1.91417398e-03 6.95079014e-04 9.93898029e-04
#  1.00000000e+00 3.03149726e-05 3.24803277e-04 3.68110381e-05
#  0.00000000e+00 1.37066983e-03 6.38779779e-04 7.77795582e-04
#  3.59448960e-04 3.07480436e-04 1.03720513e-03 9.63583057e-04
#  9.83071253e-04 1.74527628e-03 1.16640466e-03 3.78215372e-04
#  1.75772707e-03 4.15098589e-03 4.08602523e-03 9.90000390e-03
#  5.18880969e-03 3.53385966e-03 8.73807431e-03 7.95334959e-03
#  6.74399872e-03 2.16860322e-03 7.00654803e-03 1.38842574e-02
#  8.16771975e-03]
#
#
# 0.0023862214118981935

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (133, 33, 1)

# %%
test_set = df.loc[df['UGRHI'] == '06 - ALTO TIÊTE']
test_set = test_set.dropna(axis=1,how='any')
#for field in test_set.columns:
    #print(field,'NaN',test_set[field].isnull().sum())
    
test_set = test_set.resample('3M').mean()
y_test = test_set.iloc[timestamp:,1:2].values


valor = test_set.iloc[:,1:2].values
valor_scaled = sc.transform(valor)

x_test = []
length = len(test_set)

for i in range(timestamp, length):
    x_test.append(valor_scaled[i-timestamp:i,0])
    
x_test = np.array(x_test)
x_test.shape

x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1],1))
x_test.shape
# Out:
# (135, 33, 1)

# %%
test_x = []
test_y = []

length = len(test_set)
for i in range(timestamp, length):
    test_x.append(valor_scaled[i-timestamp:i, 0])
    test_y.append(valor_scaled[i, 0])

test_x = np.array(test_x)
test_y = np.array(test_y)

test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], 1))
test_x.shape
# Out:
# (135, 33, 1)

# %%
#neuronios = [16,60,120]
resultado_mse = []
qtde_neuronios =[]

print("Rede Neural LSTM com 10 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 10, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 10, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 10, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

h10 = model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_data=(test_x,test_y))

y_pred = model.predict(x_test)
predicted_valor10 = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual',marker='o')
plt.plot(predicted_valor10, color='red', linewidth = 3,label='Valor Previsto')
plt.title('10 neurônios')
plt.xlabel('Trimestre')
plt.ylabel('Valor do parâmetro Fósforo')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(10)
# Out:
# Rede Neural LSTM com 10 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples, validate on 135 samples
# Epoch 1/100
# 133/133 [==============================] - 18s 135ms/sample - loss: 9.7243e-05 - val_loss: 6.8828e-05
# Epoch 2/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 6.4059e-05 - val_loss: 8.1332e-05
# Epoch 3/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 6.1494e-05 - val_loss: 5.8212e-05
# Epoch 4/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 5.2100e-05 - val_loss: 5.4095e-05
# Epoch 5/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.5448e-05 - val_loss: 6.1639e-05
# Epoch 6/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.8713e-05 - val_loss: 6.1981e-05
# Epoch 7/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 4.4807e-05 - val_loss: 5.1120e-05
# Epoch 8/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 4.4555e-05 - val_loss: 5.0963e-05
# Epoch 9/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.3822e-05 - val_loss: 5.9314e-05
# Epoch 10/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.8239e-05 - val_loss: 5.3788e-05
# Epoch 11/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.3260e-05 - val_loss: 5.0981e-05
# Epoch 12/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.2091e-05 - val_loss: 5.5081e-05
# Epoch 13/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.5970e-05 - val_loss: 5.4193e-05
# Epoch 14/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.1737e-05 - val_loss: 5.1824e-05
# Epoch 15/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.2682e-05 - val_loss: 5.3115e-05
# Epoch 16/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.2997e-05 - val_loss: 5.1312e-05
# Epoch 17/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.1875e-05 - val_loss: 5.4006e-05
# Epoch 18/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.1003e-05 - val_loss: 5.1728e-05
# Epoch 19/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.3473e-05 - val_loss: 5.2588e-05
# Epoch 20/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1542e-05 - val_loss: 5.0744e-05
# Epoch 21/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.2641e-05 - val_loss: 5.0317e-05
# Epoch 22/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.0566e-05 - val_loss: 5.0878e-05
# Epoch 23/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.2219e-05 - val_loss: 5.0167e-05
# Epoch 24/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 4.0859e-05 - val_loss: 5.2724e-05
# Epoch 25/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 4.1552e-05 - val_loss: 4.9898e-05
# Epoch 26/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.9016e-05 - val_loss: 5.2968e-05
# Epoch 27/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1773e-05 - val_loss: 5.4897e-05
# Epoch 28/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.8811e-05 - val_loss: 4.9584e-05
# Epoch 29/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.0838e-05 - val_loss: 5.2800e-05
# Epoch 30/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0183e-05 - val_loss: 5.1733e-05
# Epoch 31/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7871e-05 - val_loss: 4.9858e-05
# Epoch 32/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.5855e-05 - val_loss: 4.9234e-05
# Epoch 33/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1516e-05 - val_loss: 5.8654e-05
# Epoch 34/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.0122e-05 - val_loss: 4.9160e-05
# Epoch 35/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.9534e-05 - val_loss: 5.0490e-05
# Epoch 36/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9286e-05 - val_loss: 6.5126e-05
# Epoch 37/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.3081e-05 - val_loss: 4.9128e-05
# Epoch 38/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1616e-05 - val_loss: 5.0597e-05
# Epoch 39/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.4862e-05 - val_loss: 6.3872e-05
# Epoch 40/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 4.3407e-05 - val_loss: 4.9009e-05
# Epoch 41/100
# 133/133 [==============================] - 2s 14ms/sample - loss: 3.7749e-05 - val_loss: 4.9410e-05
# Epoch 42/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.8958e-05 - val_loss: 4.9976e-05
# Epoch 43/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.5750e-05 - val_loss: 4.8789e-05
# Epoch 44/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.7571e-05 - val_loss: 7.2507e-05
# Epoch 45/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.4268e-05 - val_loss: 4.9217e-05
# Epoch 46/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 5.4484e-05 - val_loss: 4.9130e-05
# Epoch 47/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.8177e-05 - val_loss: 7.2209e-05
# Epoch 48/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.6473e-05 - val_loss: 4.9288e-05
# Epoch 49/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0412e-05 - val_loss: 4.9215e-05
# Epoch 50/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.4888e-05 - val_loss: 6.1355e-05
# Epoch 51/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.2876e-05 - val_loss: 4.9164e-05
# Epoch 52/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.8406e-05 - val_loss: 5.1634e-05
# Epoch 53/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.4298e-05 - val_loss: 6.1807e-05
# Epoch 54/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.6873e-05 - val_loss: 5.5782e-05
# Epoch 55/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.8495e-05 - val_loss: 4.9149e-05
# Epoch 56/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.3077e-05 - val_loss: 4.9108e-05
# Epoch 57/100
# 133/133 [==============================] - 2s 11ms/sample - loss: 3.9970e-05 - val_loss: 5.7155e-05
# Epoch 58/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 4.1488e-05 - val_loss: 5.1458e-05
# Epoch 59/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.8908e-05 - val_loss: 4.9318e-05
# Epoch 60/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7994e-05 - val_loss: 5.7651e-05
# Epoch 61/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1584e-05 - val_loss: 5.5457e-05
# Epoch 62/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.8073e-05 - val_loss: 4.9152e-05
# Epoch 63/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.7706e-05 - val_loss: 4.8491e-05
# Epoch 64/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.7291e-05 - val_loss: 5.1534e-05
# Epoch 65/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7896e-05 - val_loss: 4.8884e-05
# Epoch 66/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9528e-05 - val_loss: 4.8021e-05
# Epoch 67/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6917e-05 - val_loss: 5.4415e-05
# Epoch 68/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.9903e-05 - val_loss: 5.1135e-05
# Epoch 69/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7065e-05 - val_loss: 4.7490e-05
# Epoch 70/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7637e-05 - val_loss: 4.9089e-05
# Epoch 71/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.8170e-05 - val_loss: 5.1452e-05
# Epoch 72/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7132e-05 - val_loss: 4.7422e-05
# Epoch 73/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.5848e-05 - val_loss: 4.6479e-05
# Epoch 74/100
# 133/133 [==============================] - 1s 11ms/sample - loss: 3.7670e-05 - val_loss: 4.7105e-05
# Epoch 75/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.7537e-05 - val_loss: 4.7033e-05
# Epoch 76/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.3108e-05 - val_loss: 4.8655e-05
# Epoch 77/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.8663e-05 - val_loss: 5.3579e-05
# Epoch 78/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.4816e-05 - val_loss: 5.3263e-05
# Epoch 79/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.9014e-05 - val_loss: 4.8349e-05
# Epoch 80/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.5808e-05 - val_loss: 4.5353e-05
# Epoch 81/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6701e-05 - val_loss: 5.0280e-05
# Epoch 82/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6820e-05 - val_loss: 4.8414e-05
# Epoch 83/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.5466e-05 - val_loss: 4.5104e-05
# Epoch 84/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.5462e-05 - val_loss: 4.6540e-05
# Epoch 85/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.4515e-05 - val_loss: 4.5967e-05
# Epoch 86/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.5630e-05 - val_loss: 4.4733e-05
# Epoch 87/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.3060e-05 - val_loss: 4.9008e-05
# Epoch 88/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6065e-05 - val_loss: 4.4384e-05
# Epoch 89/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6161e-05 - val_loss: 4.4637e-05
# Epoch 90/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.4181e-05 - val_loss: 4.4431e-05
# Epoch 91/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.7722e-05 - val_loss: 4.6032e-05
# Epoch 92/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.9068e-05 - val_loss: 5.3779e-05
# Epoch 93/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 3.8626e-05 - val_loss: 4.7566e-05
# Epoch 94/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 4.1441e-05 - val_loss: 4.7485e-05
# Epoch 95/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.9156e-05 - val_loss: 5.2822e-05
# Epoch 96/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6415e-05 - val_loss: 4.5162e-05
# Epoch 97/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6873e-05 - val_loss: 4.5416e-05
# Epoch 98/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.3744e-05 - val_loss: 4.5954e-05
# Epoch 99/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.4227e-05 - val_loss: 4.7149e-05
# Epoch 100/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.4486e-05 - val_loss: 4.5691e-05
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d39b42296b85> in <module>
#      28 plt.show()
#      29
# ---> 30 mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#      31 #print("MSE:", round(mse,2))
#      32
#
# NameError: name 'predicted_valor' is not defined

# %%
train_score10 = model.evaluate(x_train, y_train, verbose=0)
print(train_score10)
print('Pontuação de Treino: {:.2f} MSE ({:.2f} RMSE)'.format(train_score10, math.sqrt(train_score10)))
test_score10 = model.evaluate(test_x, test_y, verbose=0)
print('Pontuação de teste: {:.2f} MSE ({:.2f} RMSE)'.format(test_score10, math.sqrt(test_score10)))
# Out:
# 3.338845228317677e-05
# Pontuação de Treino: 0.00 MSE (0.01 RMSE)
# Pontuação de teste: 0.00 MSE (0.01 RMSE)

# %%
plt.ylim(0,0.4)
plt.plot(h10.history['loss'],'blue',linewidth = 3,label='Treino')
plt.plot(h10.history['val_loss'],'red',linewidth = 3,label='Teste')
plt.title('10 neurônios')
plt.ylabel('Taxa de perda')
plt.xlabel('épocas')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("Rede Neural LSTM com 25 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 25, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 25, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 25, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

h25 = model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_data=(test_x,test_y))

y_pred = model.predict(x_test)
predicted_valor25 = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual',marker='o')
plt.plot(predicted_valor25, color='red',linewidth = 3, label='Valor Previsto')
plt.title('25 neurônios')
plt.xlabel('Trimestre')
plt.ylabel('Valor do parâmetro OD')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(25)
# Out:
# Rede Neural LSTM com 25 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples, validate on 135 samples
# Epoch 1/100
# 133/133 [==============================] - 18s 137ms/sample - loss: 1.4295e-04 - val_loss: 7.2486e-05
# Epoch 2/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 5.7277e-05 - val_loss: 5.3641e-05
# Epoch 3/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.6596e-05 - val_loss: 5.7858e-05
# Epoch 4/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.9429e-05 - val_loss: 5.6755e-05
# Epoch 5/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.5514e-05 - val_loss: 5.0580e-05
# Epoch 6/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1289e-05 - val_loss: 6.0990e-05
# Epoch 7/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.2424e-05 - val_loss: 5.0846e-05
# Epoch 8/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.2669e-05 - val_loss: 6.5483e-05
# Epoch 9/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 7.0259e-05 - val_loss: 5.2058e-05
# Epoch 10/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 6.2783e-05 - val_loss: 5.3632e-05
# Epoch 11/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 5.3187e-05 - val_loss: 8.5130e-05
# Epoch 12/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.6975e-05 - val_loss: 5.2867e-05
# Epoch 13/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 5.7270e-05 - val_loss: 5.2210e-05
# Epoch 14/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.6126e-05 - val_loss: 6.6258e-05
# Epoch 15/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.7042e-05 - val_loss: 5.0974e-05
# Epoch 16/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.8355e-05 - val_loss: 5.6795e-05
# Epoch 17/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0415e-05 - val_loss: 5.1116e-05
# Epoch 18/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1094e-05 - val_loss: 5.1188e-05
# Epoch 19/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9892e-05 - val_loss: 5.3268e-05
# Epoch 20/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9236e-05 - val_loss: 4.8524e-05
# Epoch 21/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.3660e-05 - val_loss: 4.8460e-05
# Epoch 22/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.4528e-05 - val_loss: 6.0501e-05
# Epoch 23/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0260e-05 - val_loss: 4.7907e-05
# Epoch 24/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.2281e-05 - val_loss: 4.7746e-05
# Epoch 25/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9603e-05 - val_loss: 5.5819e-05
# Epoch 26/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0295e-05 - val_loss: 4.7994e-05
# Epoch 27/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9549e-05 - val_loss: 5.0741e-05
# Epoch 28/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.4708e-05 - val_loss: 5.0140e-05
# Epoch 29/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.2009e-05 - val_loss: 4.8793e-05
# Epoch 30/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0204e-05 - val_loss: 5.8557e-05
# Epoch 31/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.0185e-05 - val_loss: 4.6600e-05
# Epoch 32/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.3243e-05 - val_loss: 4.7958e-05
# Epoch 33/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7793e-05 - val_loss: 5.9598e-05
# Epoch 34/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1604e-05 - val_loss: 4.6959e-05
# Epoch 35/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.6889e-05 - val_loss: 4.8690e-05
# Epoch 36/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7311e-05 - val_loss: 4.6286e-05
# Epoch 37/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7966e-05 - val_loss: 4.8364e-05
# Epoch 38/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7345e-05 - val_loss: 5.0554e-05
# Epoch 39/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.7682e-05 - val_loss: 4.5033e-05
# Epoch 40/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0742e-05 - val_loss: 5.1974e-05
# Epoch 41/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.5033e-05 - val_loss: 5.0004e-05
# Epoch 42/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.9074e-05 - val_loss: 5.5824e-05
# Epoch 43/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.7299e-05 - val_loss: 4.4490e-05
# Epoch 44/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0079e-05 - val_loss: 4.6172e-05
# Epoch 45/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9035e-05 - val_loss: 4.8399e-05
# Epoch 46/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7413e-05 - val_loss: 4.4876e-05
# Epoch 47/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.8180e-05 - val_loss: 4.4829e-05
# Epoch 48/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7519e-05 - val_loss: 4.5063e-05
# Epoch 49/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.8585e-05 - val_loss: 4.3928e-05
# Epoch 50/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1625e-05 - val_loss: 5.6432e-05
# Epoch 51/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.7652e-05 - val_loss: 4.5003e-05
# Epoch 52/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0367e-05 - val_loss: 4.9394e-05
# Epoch 53/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.6300e-05 - val_loss: 4.4884e-05
# Epoch 54/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1023e-05 - val_loss: 5.0515e-05
# Epoch 55/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9678e-05 - val_loss: 4.4306e-05
# Epoch 56/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.1515e-05 - val_loss: 4.3956e-05
# Epoch 57/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.4799e-05 - val_loss: 4.9557e-05
# Epoch 58/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.6283e-05 - val_loss: 4.3485e-05
# Epoch 59/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.4632e-05 - val_loss: 5.3329e-05
# Epoch 60/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.9923e-05 - val_loss: 4.3279e-05
# Epoch 61/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.5729e-05 - val_loss: 5.2880e-05
# Epoch 62/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1074e-05 - val_loss: 4.4526e-05
# Epoch 63/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.4563e-05 - val_loss: 4.3369e-05
# Epoch 64/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.5316e-05 - val_loss: 4.3293e-05
# Epoch 65/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9766e-05 - val_loss: 4.3884e-05
# Epoch 66/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7587e-05 - val_loss: 4.4364e-05
# Epoch 67/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.3480e-05 - val_loss: 4.2778e-05
# Epoch 68/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9992e-05 - val_loss: 4.8285e-05
# Epoch 69/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.4452e-05 - val_loss: 4.2846e-05
# Epoch 70/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.4696e-05 - val_loss: 4.2645e-05
# Epoch 71/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.4145e-05 - val_loss: 4.3097e-05
# Epoch 72/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.6701e-05 - val_loss: 5.0476e-05
# Epoch 73/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.7197e-05 - val_loss: 4.3215e-05
# Epoch 74/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6030e-05 - val_loss: 4.5038e-05
# Epoch 75/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.4578e-05 - val_loss: 4.3282e-05
# Epoch 76/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.4115e-05 - val_loss: 4.3336e-05
# Epoch 77/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6730e-05 - val_loss: 4.3864e-05
# Epoch 78/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.6844e-05 - val_loss: 4.4838e-05
# Epoch 79/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.3758e-05 - val_loss: 4.5251e-05
# Epoch 80/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.0751e-05 - val_loss: 4.4387e-05
# Epoch 81/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.5337e-05 - val_loss: 5.0711e-05
# Epoch 82/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.6865e-05 - val_loss: 4.5415e-05
# Epoch 83/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.1595e-05 - val_loss: 4.4749e-05
# Epoch 84/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6054e-05 - val_loss: 5.4086e-05
# Epoch 85/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.6339e-05 - val_loss: 4.4388e-05
# Epoch 86/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.0043e-05 - val_loss: 4.8492e-05
# Epoch 87/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.9063e-05 - val_loss: 4.5581e-05
# Epoch 88/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.2681e-05 - val_loss: 4.4736e-05
# Epoch 89/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.5026e-05 - val_loss: 4.4618e-05
# Epoch 90/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.3501e-05 - val_loss: 4.4555e-05
# Epoch 91/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.5948e-05 - val_loss: 4.4515e-05
# Epoch 92/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7750e-05 - val_loss: 4.2418e-05
# Epoch 93/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.7260e-05 - val_loss: 4.4109e-05
# Epoch 94/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.3188e-05 - val_loss: 4.4336e-05
# Epoch 95/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 5.0849e-05 - val_loss: 4.7981e-05
# Epoch 96/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.6785e-05 - val_loss: 4.8386e-05
# Epoch 97/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.3120e-05 - val_loss: 4.8089e-05
# Epoch 98/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.9500e-05 - val_loss: 5.3547e-05
# Epoch 99/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 4.3112e-05 - val_loss: 4.6027e-05
# Epoch 100/100
# 133/133 [==============================] - 1s 6ms/sample - loss: 3.8223e-05 - val_loss: 4.4743e-05
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-52081a71c7f0> in <module>
#      24 plt.show()
#      25
# ---> 26 mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#      27 #print("MSE:", round(mse,2))
#      28
#
# NameError: name 'predicted_valor' is not defined

# %%
train_score25 = model.evaluate(x_train, y_train, verbose=0)
print('Pontuação de Treino: {:.2f} MSE ({:.2f} RMSE)'.format(train_score25, math.sqrt(train_score25)))
test_score25 = model.evaluate(test_x, test_y, verbose=0)
print('Pontuação de teste: {:.2f} MSE ({:.2f} RMSE)'.format(test_score25, math.sqrt(test_score25)))
# Out:
# Pontuação de Treino: 0.00 MSE (0.01 RMSE)
# Pontuação de teste: 0.00 MSE (0.01 RMSE)

# %%
plt.ylim(0,0.4)
plt.plot(h25.history['loss'],'blue',linewidth = 3,label='Treino')
plt.plot(h25.history['val_loss'],'red',linewidth = 3,label='Teste')
plt.title('25 neurônios')
plt.ylabel('Taxa de perda')
plt.xlabel('épocas')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("Rede Neural LSTM com 50 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

h50 = model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_data=(test_x,test_y))

y_pred = model.predict(x_test)
predicted_valor50 = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual',marker='o')
plt.plot(predicted_valor50, color='red',linewidth = 3,label='Valor Previsto')
plt.title('50 neurônios')
plt.xlabel('Trimestre')
plt.ylabel('Valor do Fósforo')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor50)).mean()

rmse_treino = sqrt(mean_squared_error(y_train,x_train))
print('Treino RMSE: %.3f'%rmse_treino)
rmse_teste = sqrt(mean_squared_error(y_test,predicted_valor50))
print('Teste RMSE: %.3f'%rmse_teste)
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(50)
# Out:
# Rede Neural LSTM com 50 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples, validate on 135 samples
# Epoch 1/100
# 133/133 [==============================] - 18s 137ms/sample - loss: 9.7111e-05 - val_loss: 7.8453e-05
# Epoch 2/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 5.5281e-05 - val_loss: 5.2521e-05
# Epoch 3/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.2631e-05 - val_loss: 5.1761e-05
# Epoch 4/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.5490e-05 - val_loss: 5.2140e-05
# Epoch 5/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.5924e-05 - val_loss: 5.0869e-05
# Epoch 6/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.7602e-05 - val_loss: 5.1835e-05
# Epoch 7/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.5349e-05 - val_loss: 5.3085e-05
# Epoch 8/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.7508e-05 - val_loss: 4.9851e-05
# Epoch 9/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.4076e-05 - val_loss: 6.2485e-05
# Epoch 10/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.0604e-05 - val_loss: 5.0713e-05
# Epoch 11/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 5.2134e-05 - val_loss: 4.9560e-05
# Epoch 12/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.1952e-05 - val_loss: 6.1618e-05
# Epoch 13/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.0858e-05 - val_loss: 4.9940e-05
# Epoch 14/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.5636e-05 - val_loss: 6.0892e-05
# Epoch 15/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.2789e-05 - val_loss: 4.9518e-05
# Epoch 16/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.2856e-05 - val_loss: 6.9655e-05
# Epoch 17/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.6763e-05 - val_loss: 4.9149e-05
# Epoch 18/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 4.8193e-05 - val_loss: 5.4288e-05
# Epoch 19/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.3888e-05 - val_loss: 4.8954e-05
# Epoch 20/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.9355e-05 - val_loss: 4.8928e-05
# Epoch 21/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.4490e-05 - val_loss: 5.7492e-05
# Epoch 22/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.1008e-05 - val_loss: 4.8711e-05
# Epoch 23/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.0987e-05 - val_loss: 5.6099e-05
# Epoch 24/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.6221e-05 - val_loss: 4.8448e-05
# Epoch 25/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.8223e-05 - val_loss: 4.9258e-05
# Epoch 26/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 4.4274e-05 - val_loss: 5.0698e-05
# Epoch 27/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.0244e-05 - val_loss: 5.1421e-05
# Epoch 28/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.1302e-05 - val_loss: 5.1870e-05
# Epoch 29/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.4247e-05 - val_loss: 5.2471e-05
# Epoch 30/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.9098e-05 - val_loss: 5.2116e-05
# Epoch 31/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.7643e-05 - val_loss: 4.7733e-05
# Epoch 32/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.9011e-05 - val_loss: 5.7125e-05
# Epoch 33/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 4.2006e-05 - val_loss: 4.7784e-05
# Epoch 34/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 4.2274e-05 - val_loss: 5.4195e-05
# Epoch 35/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 4.3790e-05 - val_loss: 4.7199e-05
# Epoch 36/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.1769e-05 - val_loss: 5.9647e-05
# Epoch 37/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 5.3922e-05 - val_loss: 4.7410e-05
# Epoch 38/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.4224e-05 - val_loss: 4.7903e-05
# Epoch 39/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.1976e-05 - val_loss: 6.4141e-05
# Epoch 40/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.8224e-05 - val_loss: 4.8960e-05
# Epoch 41/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.4481e-05 - val_loss: 5.1911e-05
# Epoch 42/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.1187e-05 - val_loss: 5.3864e-05
# Epoch 43/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.8904e-05 - val_loss: 4.7627e-05
# Epoch 44/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 4.0872e-05 - val_loss: 4.8137e-05
# Epoch 45/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.0129e-05 - val_loss: 5.3236e-05
# Epoch 46/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.9297e-05 - val_loss: 4.6508e-05
# Epoch 47/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 3.6692e-05 - val_loss: 4.9006e-05
# Epoch 48/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.8326e-05 - val_loss: 4.6403e-05
# Epoch 49/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.8451e-05 - val_loss: 4.5056e-05
# Epoch 50/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.5557e-05 - val_loss: 4.4682e-05
# Epoch 51/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 3.5608e-05 - val_loss: 6.5017e-05
# Epoch 52/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.2444e-05 - val_loss: 4.4117e-05
# Epoch 53/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.6992e-05 - val_loss: 4.3737e-05
# Epoch 54/100
# 133/133 [==============================] - 2s 13ms/sample - loss: 3.7954e-05 - val_loss: 4.8134e-05
# Epoch 55/100
# 133/133 [==============================] - 2s 14ms/sample - loss: 4.3411e-05 - val_loss: 4.4340e-05
# Epoch 56/100
# 133/133 [==============================] - 2s 16ms/sample - loss: 3.8720e-05 - val_loss: 5.4451e-05
# Epoch 57/100
# 133/133 [==============================] - 2s 15ms/sample - loss: 4.2344e-05 - val_loss: 4.4866e-05
# Epoch 58/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 3.8055e-05 - val_loss: 5.0200e-05
# Epoch 59/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.5389e-05 - val_loss: 4.4146e-05
# Epoch 60/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.9114e-05 - val_loss: 4.4862e-05
# Epoch 61/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.9077e-05 - val_loss: 5.3165e-05
# Epoch 62/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 5.3405e-05 - val_loss: 4.4754e-05
# Epoch 63/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.6019e-05 - val_loss: 4.8768e-05
# Epoch 64/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 4.4268e-05 - val_loss: 5.7692e-05
# Epoch 65/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.6054e-05 - val_loss: 4.8222e-05
# Epoch 66/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 5.5875e-05 - val_loss: 4.8262e-05
# Epoch 67/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.2091e-05 - val_loss: 5.7827e-05
# Epoch 68/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.0167e-05 - val_loss: 4.6254e-05
# Epoch 69/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 4.2597e-05 - val_loss: 5.5693e-05
# Epoch 70/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 3.6947e-05 - val_loss: 4.4690e-05
# Epoch 71/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.9343e-05 - val_loss: 4.5422e-05
# Epoch 72/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 3.7116e-05 - val_loss: 4.4865e-05
# Epoch 73/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.5354e-05 - val_loss: 4.8751e-05
# Epoch 74/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.5910e-05 - val_loss: 4.2926e-05
# Epoch 75/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.6393e-05 - val_loss: 4.5081e-05
# Epoch 76/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.5496e-05 - val_loss: 4.3416e-05
# Epoch 77/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.5095e-05 - val_loss: 4.2628e-05
# Epoch 78/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 4.0078e-05 - val_loss: 4.2484e-05
# Epoch 79/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.4661e-05 - val_loss: 4.4589e-05
# Epoch 80/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.3806e-05 - val_loss: 4.2540e-05
# Epoch 81/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.5217e-05 - val_loss: 5.2537e-05
# Epoch 82/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.8367e-05 - val_loss: 4.2806e-05
# Epoch 83/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.5776e-05 - val_loss: 4.5607e-05
# Epoch 84/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.3659e-05 - val_loss: 4.3603e-05
# Epoch 85/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.6134e-05 - val_loss: 4.6921e-05
# Epoch 86/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.5486e-05 - val_loss: 4.2719e-05
# Epoch 87/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.6836e-05 - val_loss: 4.3312e-05
# Epoch 88/100
# 133/133 [==============================] - 1s 7ms/sample - loss: 3.6116e-05 - val_loss: 4.5137e-05
# Epoch 89/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.7750e-05 - val_loss: 4.2725e-05
# Epoch 90/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.5167e-05 - val_loss: 4.5752e-05
# Epoch 91/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 3.8041e-05 - val_loss: 4.2738e-05
# Epoch 92/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.9193e-05 - val_loss: 4.2382e-05
# Epoch 93/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 3.7306e-05 - val_loss: 4.3628e-05
# Epoch 94/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.5735e-05 - val_loss: 4.3722e-05
# Epoch 95/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.4845e-05 - val_loss: 4.5523e-05
# Epoch 96/100
# 133/133 [==============================] - 1s 9ms/sample - loss: 3.4554e-05 - val_loss: 4.3161e-05
# Epoch 97/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.2589e-05 - val_loss: 4.7511e-05
# Epoch 98/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.7367e-05 - val_loss: 4.2958e-05
# Epoch 99/100
# 133/133 [==============================] - 1s 8ms/sample - loss: 3.9952e-05 - val_loss: 5.5464e-05
# Epoch 100/100
# 133/133 [==============================] - 1s 10ms/sample - loss: 5.8683e-05 - val_loss: 4.3550e-05
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1a5c0f7ba53f> in <module>
#      26 mse = np.square(np.subtract(y_test,predicted_valor50)).mean()
#      27
# ---> 28 rmse_treino = sqrt(mean_squared_error(y_train,x_train))
#      29 print('Treino RMSE: %.3f'%rmse_treino)
#      30 rmse_teste = sqrt(mean_squared_error(y_test,predicted_valor50))
#
# NameError: name 'sqrt' is not defined

# %%
train_score50 = model.evaluate(x_train, y_train, verbose=0)
print('Pontuação de Treino: {:.2f} MSE ({:.2f} RMSE)'.format(train_score50, math.sqrt(train_score50)))
test_score50 = model.evaluate(test_x, test_y, verbose=0)
print('Pontuação de teste: {:.2f} MSE ({:.2f} RMSE)'.format(test_score50, math.sqrt(test_score50)))
# Out:
# Pontuação de Treino: 0.00 MSE (0.01 RMSE)
# Pontuação de teste: 0.00 MSE (0.01 RMSE)

# %%
plt.ylim(0,0.4)
plt.plot(h50.history['loss'],'blue',linewidth = 3,label='Treino')
plt.plot(h50.history['val_loss'],'red',linewidth = 3,label='Teste')
plt.title('50 neurônios')
plt.ylabel('Taxa de perda')
plt.xlabel('épocas')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
real_m = []
previsto_m = []
mse_m = []

for i in range(len(y_test)):
    real_m.append(round(y_test[i][0],2))
    #print("Real:",round(y_test[i][0],2))

for i in range(len(predicted_valor)):
    previsto_m.append(round(predicted_valor[i][0],2))
    #print("Previsto",round(predicted_valor[i][0],2))
    
for i in range(len(predicted_valor)):
    mse = np.square(np.subtract(y_test[i][0],predicted_valor[i][0])).mean()
    mse_m.append(mse)

# %%
print("Rede Neural LSTM com 40 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 40, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 40, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 40, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 40, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(40)
# Out:
# Rede Neural LSTM com 40 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 20s 151ms/sample - loss: 0.2149 - accuracy: 0.0000e+00
# Epoch 2/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0565 - accuracy: 0.0075
# Epoch 3/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0306 - accuracy: 0.0075
# Epoch 4/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0366 - accuracy: 0.0000e+00
# Epoch 5/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0267 - accuracy: 0.0075
# Epoch 6/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0293 - accuracy: 0.0075
# Epoch 7/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0307 - accuracy: 0.0075
# Epoch 8/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0286 - accuracy: 0.0075
# Epoch 9/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0283 - accuracy: 0.0075
# Epoch 10/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0289 - accuracy: 0.0075
# Epoch 11/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 12/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 13/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0313 - accuracy: 0.0075
# Epoch 14/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0270 - accuracy: 0.0075
# Epoch 15/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0268 - accuracy: 0.0075
# Epoch 16/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0264 - accuracy: 0.0075
# Epoch 17/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0276 - accuracy: 0.0075
# Epoch 18/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0261 - accuracy: 0.0075
# Epoch 19/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0287 - accuracy: 0.0075
# Epoch 20/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0264 - accuracy: 0.0075
# Epoch 21/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0279 - accuracy: 0.0075
# Epoch 22/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0272 - accuracy: 0.0075
# Epoch 23/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0303 - accuracy: 0.0075
# Epoch 24/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0309 - accuracy: 0.0075
# Epoch 25/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0283 - accuracy: 0.0075
# Epoch 26/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0267 - accuracy: 0.0075
# Epoch 27/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0279 - accuracy: 0.0075
# Epoch 28/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0260 - accuracy: 0.0075
# Epoch 29/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0314 - accuracy: 0.0075
# Epoch 30/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0305 - accuracy: 0.0075
# Epoch 31/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0265 - accuracy: 0.0075
# Epoch 32/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0287 - accuracy: 0.0075
# Epoch 33/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0274 - accuracy: 0.0075
# Epoch 34/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0285 - accuracy: 0.0075
# Epoch 35/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0283 - accuracy: 0.0075
# Epoch 36/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0261 - accuracy: 0.0075
# Epoch 37/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0245 - accuracy: 0.0075
# Epoch 38/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 39/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0306 - accuracy: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0266 - accuracy: 0.0075
# Epoch 41/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0259 - accuracy: 0.0075
# Epoch 42/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 43/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0284 - accuracy: 0.0075
# Epoch 44/50
# 133/133 [==============================] - 1s 8ms/sample - loss: 0.0263 - accuracy: 0.0075
# Epoch 45/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0284 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0240 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0261 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0289 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0268 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0259 - accuracy: 0.0075

# %%
print("Rede Neural LSTM com 60 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 60, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 60, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 60, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 60, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(60)
# Out:
# Rede Neural LSTM com 60 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 21s 155ms/sample - loss: 0.2194 - accuracy: 0.0000e+00
# Epoch 2/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0649 - accuracy: 0.0075
# Epoch 3/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0493 - accuracy: 0.0075
# Epoch 4/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0304 - accuracy: 0.0075
# Epoch 5/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0344 - accuracy: 0.0075
# Epoch 6/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0327 - accuracy: 0.0075
# Epoch 7/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0326 - accuracy: 0.0075
# Epoch 8/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0298 - accuracy: 0.0075
# Epoch 9/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0288 - accuracy: 0.0075
# Epoch 10/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0281 - accuracy: 0.0075
# Epoch 11/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0257 - accuracy: 0.0075
# Epoch 12/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0306 - accuracy: 0.0075
# Epoch 13/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0263 - accuracy: 0.0000e+00
# Epoch 14/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0252 - accuracy: 0.0075
# Epoch 15/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0260 - accuracy: 0.0075
# Epoch 16/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0274 - accuracy: 0.0075
# Epoch 17/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0282 - accuracy: 0.0075
# Epoch 18/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0263 - accuracy: 0.0075
# Epoch 19/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0272 - accuracy: 0.0075
# Epoch 20/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0268 - accuracy: 0.0075
# Epoch 21/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0249 - accuracy: 0.0075
# Epoch 22/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0259 - accuracy: 0.0075
# Epoch 23/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 24/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0249 - accuracy: 0.0075
# Epoch 25/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0252 - accuracy: 0.0075
# Epoch 26/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0247 - accuracy: 0.0075
# Epoch 27/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 28/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0241 - accuracy: 0.0075
# Epoch 29/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0238 - accuracy: 0.0075
# Epoch 30/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0267 - accuracy: 0.0075
# Epoch 31/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0263 - accuracy: 0.0075
# Epoch 32/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0280 - accuracy: 0.0075
# Epoch 33/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0263 - accuracy: 0.0075
# Epoch 34/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0264 - accuracy: 0.0075
# Epoch 35/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0248 - accuracy: 0.0075
# Epoch 36/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0261 - accuracy: 0.0075
# Epoch 37/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 38/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0266 - accuracy: 0.0075
# Epoch 39/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0224 - accuracy: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0233 - accuracy: 0.0075
# Epoch 41/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0261 - accuracy: 0.0075
# Epoch 42/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 43/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0264 - accuracy: 0.0075
# Epoch 44/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0281 - accuracy: 0.0075
# Epoch 45/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0266 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0283 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0254 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0255 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 1s 9ms/sample - loss: 0.0241 - accuracy: 0.0075

# %%
print("Rede Neural LSTM com 81 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 81, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 81, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 81, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 81, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(81)
# Out:
# Rede Neural LSTM com 81 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 21s 155ms/sample - loss: 0.1978 - accuracy: 0.0075
# Epoch 2/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0559 - accuracy: 0.0075
# Epoch 3/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0434 - accuracy: 0.0075
# Epoch 4/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0355 - accuracy: 0.0075
# Epoch 5/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 6/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0292 - accuracy: 0.0075
# Epoch 7/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0233 - accuracy: 0.0075
# Epoch 8/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0275 - accuracy: 0.0075
# Epoch 9/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0272 - accuracy: 0.0075
# Epoch 10/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0285 - accuracy: 0.0075
# Epoch 11/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0277 - accuracy: 0.0075
# Epoch 12/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0300 - accuracy: 0.0075
# Epoch 13/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0256 - accuracy: 0.0075
# Epoch 14/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0258 - accuracy: 0.0075
# Epoch 15/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0264 - accuracy: 0.0075
# Epoch 16/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0255 - accuracy: 0.0075
# Epoch 17/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0265 - accuracy: 0.0075
# Epoch 18/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0248 - accuracy: 0.0075
# Epoch 19/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 20/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0230 - accuracy: 0.0075
# Epoch 21/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0242 - accuracy: 0.0075
# Epoch 22/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0245 - accuracy: 0.0075
# Epoch 23/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0256 - accuracy: 0.0075
# Epoch 24/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0271 - accuracy: 0.0075
# Epoch 25/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0278 - accuracy: 0.0075
# Epoch 26/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0259 - accuracy: 0.0075
# Epoch 27/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0260 - accuracy: 0.0075
# Epoch 28/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0281 - accuracy: 0.0075
# Epoch 29/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0317 - accuracy: 0.0075
# Epoch 30/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0289 - accuracy: 0.0075
# Epoch 31/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0254 - accuracy: 0.0075
# Epoch 32/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 33/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0254 - accuracy: 0.0075
# Epoch 34/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 35/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0251 - accuracy: 0.0075
# Epoch 36/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0250 - accuracy: 0.0075
# Epoch 37/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0243 - accuracy: 0.0075
# Epoch 38/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0259 - accuracy: 0.0075
# Epoch 39/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0247 - accuracy: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0229 - accuracy: 0.0075
# Epoch 41/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0233 - accuracy: 0.0075
# Epoch 42/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0282 - accuracy: 0.0075
# Epoch 43/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0245 - accuracy: 0.0075
# Epoch 44/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0251 - accuracy: 0.0075
# Epoch 45/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0239 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0260 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0286 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 1s 10ms/sample - loss: 0.0365 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0262 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 1s 11ms/sample - loss: 0.0302 - accuracy: 0.0075

# %%
print("Rede Neural LSTM com 120 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 120, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 120, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 120, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 120, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(120)
# Out:
# Rede Neural LSTM com 120 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 21s 155ms/sample - loss: 0.2037 - accuracy: 0.0000e+00
# Epoch 2/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0714 - accuracy: 0.0000e+00
# Epoch 3/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0436 - accuracy: 0.0000e+00
# Epoch 4/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0384 - accuracy: 0.0075
# Epoch 5/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0317 - accuracy: 0.0075
# Epoch 6/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0234 - accuracy: 0.0075
# Epoch 7/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0325 - accuracy: 0.0075
# Epoch 8/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0272 - accuracy: 0.0075
# Epoch 9/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0262 - accuracy: 0.0075
# Epoch 10/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 11/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0267 - accuracy: 0.0075
# Epoch 12/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0239 - accuracy: 0.0075
# Epoch 13/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0243 - accuracy: 0.0075
# Epoch 14/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0251 - accuracy: 0.0075
# Epoch 15/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0226 - accuracy: 0.0075
# Epoch 16/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0275 - accuracy: 0.0075
# Epoch 17/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0234 - accuracy: 0.0075
# Epoch 18/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0261 - accuracy: 0.0075
# Epoch 19/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0239 - accuracy: 0.0075
# Epoch 20/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0241 - accuracy: 0.0075
# Epoch 21/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0229 - accuracy: 0.0075
# Epoch 22/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0228 - accuracy: 0.0075
# Epoch 23/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0245 - accuracy: 0.0075
# Epoch 24/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0229 - accuracy: 0.0075
# Epoch 25/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0236 - accuracy: 0.0075
# Epoch 26/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0280 - accuracy: 0.0075
# Epoch 27/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0271 - accuracy: 0.0075
# Epoch 28/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0237 - accuracy: 0.0075
# Epoch 29/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0258 - accuracy: 0.0075
# Epoch 30/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0238 - accuracy: 0.0075
# Epoch 31/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0227 - accuracy: 0.0075
# Epoch 32/50
# 133/133 [==============================] - 2s 15ms/sample - loss: 0.0238 - accuracy: 0.0075
# Epoch 33/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0269 - accuracy: 0.0075
# Epoch 34/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0253 - accuracy: 0.0075
# Epoch 35/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0252 - accuracy: 0.0075
# Epoch 36/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0245 - accuracy: 0.0075
# Epoch 37/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0271 - accuracy: 0.0075
# Epoch 38/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0281 - accuracy: 0.0075
# Epoch 39/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0295 - accuracy: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0299 - accuracy: 0.0075
# Epoch 41/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0229 - accuracy: 0.0075
# Epoch 42/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0257 - accuracy: 0.0075
# Epoch 43/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0238 - accuracy: 0.0075
# Epoch 44/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0265 - accuracy: 0.0075
# Epoch 45/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0266 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0260 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0233 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.0246 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 2s 14ms/sample - loss: 0.0225 - accuracy: 0.0075

# %%
print("Rede Neural LSTM com 163 neuronios nas camadas de entrada e oculta - epocas:100")
model = Sequential() 

model.add(LSTM(units = 163, return_sequences = True, input_shape = (x_train.shape[1], 1))) 
model.add(Dropout(0.2))
model.add(LSTM(units = 163, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 163, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 163, return_sequences = False)) 
model.add(Dropout(0.2))
model.add(Dense(units = 1)) 
model.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(x_train, y_train, epochs = 50, batch_size = 32)

y_pred = model.predict(x_test)
predicted_valor = sc.inverse_transform(y_pred)

plt.plot(y_test, color='blue', label='Valor Atual do parâmetro pH',marker='o')
plt.plot(predicted_valor, color='red', label='Valor Previsto do parâmetro pH')
plt.title('Previsão do parâmetro pH na UGRHI 06 - ALTO TIÊTE')
plt.xlabel('Tempo')
plt.ylabel('Valor do parâmetro pH')
plt.legend()
plt.show()

mse = np.square(np.subtract(y_test,predicted_valor)).mean()
#print("MSE:", round(mse,2))
    
resultado_mse.append(mse)
qtde_neuronios.append(163)
# Out:
# Rede Neural LSTM com 163 neuronios nas camadas de entrada e oculta - epocas:100
# Train on 133 samples
# Epoch 1/50
# 133/133 [==============================] - 22s 169ms/sample - loss: 0.1741 - accuracy: 0.0075
# Epoch 2/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0991 - accuracy: 0.0000e+00
# Epoch 3/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0381 - accuracy: 0.0075
# Epoch 4/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0337 - accuracy: 0.0075
# Epoch 5/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0297 - accuracy: 0.0075
# Epoch 6/50
# 133/133 [==============================] - 2s 18ms/sample - loss: 0.0267 - accuracy: 0.0075
# Epoch 7/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0283 - accuracy: 0.0075
# Epoch 8/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0253 - accuracy: 0.0075
# Epoch 9/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0256 - accuracy: 0.0075
# Epoch 10/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0256 - accuracy: 0.0075
# Epoch 11/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0235 - accuracy: 0.0075
# Epoch 12/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0252 - accuracy: 0.0075
# Epoch 13/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0232 - accuracy: 0.0075
# Epoch 14/50
# 133/133 [==============================] - 2s 18ms/sample - loss: 0.0248 - accuracy: 0.0075
# Epoch 15/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0243 - accuracy: 0.0075
# Epoch 16/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0259 - accuracy: 0.0075
# Epoch 17/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0248 - accuracy: 0.0075
# Epoch 18/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0250 - accuracy: 0.0075
# Epoch 19/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0251 - accuracy: 0.0075
# Epoch 20/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0270 - accuracy: 0.0075
# Epoch 21/50
# 133/133 [==============================] - 2s 19ms/sample - loss: 0.0248 - accuracy: 0.0075
# Epoch 22/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0237 - accuracy: 0.0075
# Epoch 23/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0259 - accuracy: 0.0075
# Epoch 24/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 25/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0271 - accuracy: 0.0075
# Epoch 26/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0254 - accuracy: 0.0075
# Epoch 27/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0235 - accuracy: 0.0075
# Epoch 28/50
# 133/133 [==============================] - 2s 18ms/sample - loss: 0.0279 - accuracy: 0.0075
# Epoch 29/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0273 - accuracy: 0.0075
# Epoch 30/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0280 - accuracy: 0.0075
# Epoch 31/50
# 133/133 [==============================] - 2s 18ms/sample - loss: 0.0305 - accuracy: 0.0075
# Epoch 32/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0274 - accuracy: 0.0075
# Epoch 33/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0254 - accuracy: 0.0075
# Epoch 34/50
# 133/133 [==============================] - 3s 23ms/sample - loss: 0.0275 - accuracy: 0.0075
# Epoch 35/50
# 133/133 [==============================] - 2s 19ms/sample - loss: 0.0242 - accuracy: 0.0075
# Epoch 36/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0217 - accuracy: 0.0075
# Epoch 37/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0252 - accuracy: 0.0075
# Epoch 38/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0244 - accuracy: 0.0075
# Epoch 39/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0231 - accuracy: 0.0075
# Epoch 40/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0224 - accuracy: 0.0075
# Epoch 41/50
# 133/133 [==============================] - 2s 19ms/sample - loss: 0.0316 - accuracy: 0.0075
# Epoch 42/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0347 - accuracy: 0.0075
# Epoch 43/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0337 - accuracy: 0.0075
# Epoch 44/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0264 - accuracy: 0.0075
# Epoch 45/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0256 - accuracy: 0.0075
# Epoch 46/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0232 - accuracy: 0.0075
# Epoch 47/50
# 133/133 [==============================] - 2s 16ms/sample - loss: 0.0268 - accuracy: 0.0075
# Epoch 48/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0254 - accuracy: 0.0075
# Epoch 49/50
# 133/133 [==============================] - 2s 18ms/sample - loss: 0.0231 - accuracy: 0.0075
# Epoch 50/50
# 133/133 [==============================] - 2s 17ms/sample - loss: 0.0246 - accuracy: 0.0075
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ef41d5b6f2dc> in <module>
#      29 #print("MSE:", round(mse,2))
#      30
# ---> 31 resultado_mse.append(mse)
#      32 qtde_neuronios.append(163)
#
# NameError: name 'resultado_mse' is not defined

# %%
real_p = []
previsto_p = []
mse_p = []

for i in range(len(y_test)):
    real_p.append(round(y_test[i][0],2))
    #print("Real:",round(y_test[i][0],2))

for i in range(len(predicted_valor)):
    previsto_p.append(round(predicted_valor[i][0],2))
    #print("Previsto",round(predicted_valor[i][0],2))
    
for i in range(len(predicted_valor)):
    mse = np.square(np.subtract(y_test[i][0],predicted_valor[i][0])).mean()
    mse_p.append(mse)

# %%
d = {'N_neuronios':qtde_neuronios,
     'MSE':resultado_mse}

tabela = pd.DataFrame(d)
tabela = tabela.sort_values(by=['N_neuronios'])
tabela
# Out:
#    N_neuronios       MSE
# 0           10  0.259802
# 1           25  0.261638
# 2           50  0.257290

# %%
plt.plot(tabela.N_neuronios.values,tabela.MSE.values, color='blue', label='Desempenho',marker='o')
plt.title('Rede LSTM: Nº Neurônios x MSE')
plt.xlabel('Nº Neurônios')
plt.ylabel('Erro Quadrático Médio- MSE')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-632db9b469aa> in <module>
# ----> 1 plt.plot(tabela.N_neuronios.values,tabela.MSE.values, color='blue', label='Desempenho',marker='o')
#       2 plt.title('Rede LSTM: Nº Neurônios x MSE')
#       3 plt.xlabel('Nº Neurônios')
#       4 plt.ylabel('Erro Quadrático Médio- MSE')
#       5 plt.legend()
#
# NameError: name 'tabela' is not defined

# %%
test_set.resample('3M').mean()
# Out:
#              cod_interaguas     valor    Altitude
# data_coleta
# 1978-01-31       121.400000  6.680000  713.000000
# 1978-04-30       121.400000  6.566667  713.000000
# 1978-07-31       121.400000  6.553333  713.000000
# 1978-10-31       121.400000  6.193333  713.000000
# 1979-01-31       122.214286  6.221429  710.357143
# ...                     ...       ...         ...
# 2018-10-31       802.461538  7.260769  724.923077
# 2019-01-31       868.370370  7.049259  725.962963
# 2019-04-30      1781.000000  7.390000  720.200000
# 2019-07-31      1858.400000  7.352000  725.700000
# 2019-10-31      1505.000000  7.336667  716.666667
#
# [168 rows x 3 columns]

# %%
    
data = {'real28':real_m,
        'previsto28':previsto_m,
        'mse28':mse_m,
        'real163':real_p,
        'mse163':mse_p,
        'previsto163':previsto_p}

tabela = pd.DataFrame(data)
tabela.head(10)
# Out:
#    real28  previsto28     mse28  real163    mse163  previsto163
# 0    6.15        6.65  0.246195     6.15  0.185976         6.58
# 1    6.65        6.65  0.000012     6.65  0.003076         6.59
# 2    6.87        6.66  0.042528     6.87  0.067948         6.61
# 3    6.55        6.67  0.013688     6.55  0.004411         6.62
# 4    6.53        6.67  0.019916     6.53  0.008843         6.63
# 5    6.42        6.68  0.070051     6.42  0.048699         6.64
# 6    6.17        6.69  0.270947     6.17  0.229419         6.65
# 7    6.38        6.69  0.095362     6.38  0.071937         6.65
# 8    6.19        6.70  0.253568     6.19  0.213523         6.65
# 9    6.35        6.70  0.119659     6.35  0.090832         6.65
