# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import r2_score
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Dropout
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (12,10)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
ugrhi06 = pd.read_csv(str_files + "cetesb_concatenado06semoutlier.csv",encoding='utf-8',sep=',')

#Carrega os dados do arquivo .csv
ugrhi10 = pd.read_csv(str_files + "cetesb_concatenado10semoutlier.csv",encoding='utf-8',sep=',')

# %%
print('---- Tamanho dos conjuntos originais ----')
print('X:',len(ugrhi06))
print('y:',len(ugrhi10))

def seleciona_colunas(trainingd):
    fdbo     = trainingd.iloc[:,1:2].values
    ffosforo = trainingd.iloc[:,2:3].values
    fph      = trainingd.iloc[:,4:5].values
    fsolido  = trainingd.iloc[:,5:6].values
    
    frame_completo = pd.DataFrame(list(zip(fdbo, ffosforo,fsolido,fph)), 
               columns =['dbo', 'fosforo','solido','ph']) 
    
    return frame_completo

df_ugrhi06 = seleciona_colunas(ugrhi06)

#Seleciona os dados equivalente ao tamanho da URGHI10
X = df_ugrhi06.iloc[0:398]
#Remove a coluna ph, pois os seus valores serão preditos na UGRHI10
X = X.drop(['ph'],axis = 1).values
#Seleciona os valores da coluna ph da URGHI06, na qual será utilizado para a normalização dos dados quando apresentar o gráfico
train_previsao = ugrhi06['ph'].values
#Seleciona os valores da coluna ph da URGHI10.
y = ugrhi10['ph'].values

X = X.reshape(len(X),3)
y = y.reshape(len(y),1)
train_previsao = train_previsao.reshape(len(train_previsao),1)


assert X.shape == (len(X),3)
assert y.shape == (len(y),1)

print('---- Conjunto de dados y igualado ao tamanho de dados do conjunto X ----')
print('X:',len(X))
print('y:',len(y))
# Out:
# ---- Tamanho dos conjuntos originais ----
# X: 420
# y: 398
# ---- Conjunto de dados y igualado ao tamanho de dados do conjunto X ----
# X: 398
# y: 398

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
sc = MinMaxScaler()
X = sc.fit_transform(X)
y = sc.fit_transform(y)

#Normalização dos dados de previsão para teste
normalizador_previsao = MinMaxScaler()
normalizador_previsao.fit_transform(train_previsao)
# Out:
# array([[0.72444444],
#        [0.72539683],
#        [0.66787879],
#        [0.63555556],
#        [0.53333333],
#        [0.94      ],
#        [0.63666667],
#        [0.08571429],
#        [0.53333333],
#        [0.66533333],
#        [0.13333333],
#        [0.13333333],
#        [0.7       ],
#        [0.26666667],
#        [0.48086389],
#        [0.88666667],
#        [0.24444444],
#        [0.6       ],
#        [0.56666667],
#        [0.445     ],
#        [0.48086389],
#        [0.93333333],
#        [0.        ],
#        [0.22222222],
#        [0.78333333],
#        [0.44833333],
#        [0.2       ],
#        [0.77333333],
#        [0.49213755],
#        [0.5       ],
#        [0.525     ],
#        [0.8       ],
#        [0.26666667],
#        [0.4       ],
#        [0.13333333],
#        [0.46666667],
#        [0.21666667],
#        [0.41666667],
#        [0.64444444],
#        [0.26666667],
#        [0.33333333],
#        [0.3       ],
#        [0.76666667],
#        [0.56666667],
#        [0.37333333],
#        [0.72666667],
#        [0.44074074],
#        [0.63333333],
#        [0.73333333],
#        [0.22222222],
#        [0.27333333],
#        [0.74      ],
#        [0.57333333],
#        [0.40666667],
#        [0.2       ],
#        [0.45666667],
#        [0.4552381 ],
#        [0.56333333],
#        [0.60916667],
#        [0.47466667],
#        [0.44166667],
#        [0.6       ],
#        [0.42222222],
#        [0.26666667],
#        [0.26666667],
#        [0.46666667],
#        [0.35555556],
#        [0.35555556],
#        [0.64      ],
#        [0.59666667],
#        [0.55066667],
#        [0.47      ],
#        [0.49238095],
#        [0.51416667],
#        [0.13333333],
#        [0.41555556],
#        [0.73333333],
#        [0.46666667],
#        [0.58666667],
#        [0.412     ],
#        [0.58      ],
#        [0.73333333],
#        [0.33333333],
#        [0.55555556],
#        [0.53555556],
#        [0.5       ],
#        [0.61666667],
#        [0.42      ],
#        [0.54      ],
#        [0.37      ],
#        [0.57777778],
#        [0.588     ],
#        [0.48333333],
#        [0.55555556],
#        [0.        ],
#        [0.53333333],
#        [0.64444444],
#        [0.05      ],
#        [0.53333333],
#        [0.36666667],
#        [0.33333333],
#        [0.4       ],
#        [0.44444444],
#        [0.57777778],
#        [0.23333333],
#        [0.37333333],
#        [0.38333333],
#        [0.26666667],
#        [0.46666667],
#        [0.48888889],
#        [0.03333333],
#        [0.66666667],
#        [0.36666667],
#        [0.53333333],
#        [0.53333333],
#        [0.53333333],
#        [0.16666667],
#        [0.2       ],
#        [0.48086389],
#        [0.16666667],
#        [0.48086389],
#        [0.51111111],
#        [0.57777778],
#        [0.71111111],
#        [0.48888889],
#        [0.4       ],
#        [0.34666667],
#        [0.26666667],
#        [0.46666667],
#        [0.55555556],
#        [0.        ],
#        [0.45555556],
#        [0.53333333],
#        [0.53333333],
#        [0.49213755],
#        [0.48086389],
#        [0.48086389],
#        [0.1       ],
#        [0.33333333],
#        [0.51111111],
#        [0.6       ],
#        [0.4       ],
#        [0.55555556],
#        [0.6       ],
#        [0.16666667],
#        [0.55555556],
#        [0.06666667],
#        [0.13333333],
#        [0.37777778],
#        [0.4       ],
#        [0.06666667],
#        [0.71111111],
#        [0.48666667],
#        [0.50666667],
#        [0.53111111],
#        [0.51111111],
#        [0.33333333],
#        [0.31      ],
#        [0.384     ],
#        [0.37666667],
#        [0.28666667],
#        [0.13333333],
#        [0.37333333],
#        [0.55      ],
#        [0.52666667],
#        [0.51066667],
#        [0.54      ],
#        [0.24      ],
#        [0.28666667],
#        [0.48666667],
#        [0.65833333],
#        [0.32666667],
#        [0.69333333],
#        [0.69333333],
#        [0.44333333],
#        [0.36933333],
#        [0.49466667],
#        [0.40444444],
#        [0.21333333],
#        [0.45333333],
#        [0.32333333],
#        [0.67111111],
#        [0.52444444],
#        [0.66888889],
#        [0.56444444],
#        [0.48086389],
#        [0.03111111],
#        [0.13333333],
#        [0.14333333],
#        [0.02      ],
#        [0.56666667],
#        [0.02      ],
#        [0.48888889],
#        [0.79333333],
#        [0.26666667],
#        [0.25      ],
#        [0.01333333],
#        [0.18666667],
#        [0.55777778],
#        [0.78666667],
#        [0.38666667],
#        [0.45333333],
#        [0.09333333],
#        [0.56666667],
#        [0.17333333],
#        [0.47333333],
#        [0.68222222],
#        [0.19      ],
#        [0.66888889],
#        [0.09333333],
#        [0.55555556],
#        [0.10333333],
#        [0.81111111],
#        [0.44266667],
#        [0.23333333],
#        [0.50222222],
#        [0.35333333],
#        [0.56      ],
#        [0.34333333],
#        [0.70222222],
#        [0.43911111],
#        [0.41666667],
#        [0.72      ],
#        [0.66666667],
#        [0.6       ],
#        [0.6       ],
#        [0.66666667],
#        [0.73333333],
#        [0.73333333],
#        [0.66666667],
#        [0.86666667],
#        [0.46666667],
#        [0.23333333],
#        [0.7       ],
#        [0.6       ],
#        [0.73333333],
#        [0.6       ],
#        [0.45333333],
#        [0.64      ],
#        [0.2       ],
#        [0.68888889],
#        [0.53333333],
#        [0.64444444],
#        [0.5       ],
#        [0.43333333],
#        [0.29777778],
#        [0.2       ],
#        [0.74666667],
#        [0.6       ],
#        [0.46666667],
#        [0.32      ],
#        [0.06222222],
#        [0.6       ],
#        [0.62      ],
#        [0.33333333],
#        [0.6       ],
#        [0.6       ],
#        [0.33333333],
#        [0.43777778],
#        [0.83333333],
#        [0.53333333],
#        [0.7       ],
#        [0.7       ],
#        [0.6       ],
#        [0.46444444],
#        [0.7       ],
#        [0.73333333],
#        [0.30888889],
#        [0.86666667],
#        [0.60666667],
#        [0.66666667],
#        [0.73333333],
#        [0.43333333],
#        [0.7       ],
#        [0.        ],
#        [0.61166667],
#        [0.8       ],
#        [0.53333333],
#        [0.46111111],
#        [0.73333333],
#        [0.66666667],
#        [0.56666667],
#        [0.39111111],
#        [0.66666667],
#        [0.63333333],
#        [0.56      ],
#        [0.42666667],
#        [0.64444444],
#        [0.39555556],
#        [0.66666667],
#        [0.43333333],
#        [0.51111111],
#        [0.6       ],
#        [0.41444444],
#        [0.29777778],
#        [0.66666667],
#        [0.36666667],
#        [0.68888889],
#        [0.30444444],
#        [0.53333333],
#        [0.65      ],
#        [0.28      ],
#        [1.        ],
#        [0.51111111],
#        [0.22888889],
#        [0.73333333],
#        [0.22444444],
#        [0.68888889],
#        [0.73333333],
#        [0.61666667],
#        [0.30222222],
#        [0.44888889],
#        [0.66666667],
#        [0.37777778],
#        [0.39444444],
#        [0.24888889],
#        [0.68888889],
#        [0.32666667],
#        [0.71111111],
#        [0.6       ],
#        [0.29833333],
#        [0.12666667],
#        [0.61666667],
#        [0.73333333],
#        [0.54777778],
#        [0.34444444],
#        [0.8       ],
#        [0.4       ],
#        [0.66666667],
#        [0.52222222],
#        [0.48888889],
#        [0.73333333],
#        [0.73333333],
#        [0.28666667],
#        [0.66666667],
#        [0.29333333],
#        [0.48      ],
#        [0.68888889],
#        [0.6       ],
#        [0.7       ],
#        [0.22      ],
#        [0.57777778],
#        [0.57777778],
#        [0.25111111],
#        [0.46666667],
#        [0.73333333],
#        [0.51142857],
#        [0.68888889],
#        [0.37555556],
#        [0.6       ],
#        [0.54166667],
#        [0.56666667],
#        [0.73333333],
#        [0.32222222],
#        [0.73333333],
#        [0.57777778],
#        [0.65      ],
#        [0.7       ],
#        [0.2       ],
#        [0.46666667],
#        [0.43777778],
#        [0.9       ],
#        [0.68888889],
#        [0.46      ],
#        [0.8       ],
#        [0.64      ],
#        [0.56666667],
#        [0.46666667],
#        [0.7       ],
#        [0.73333333],
#        [0.73333333],
#        [0.73333333],
#        [0.62222222],
#        [0.86666667],
#        [0.59714286],
#        [0.28333333],
#        [0.51111111],
#        [0.31555556],
#        [0.73333333],
#        [0.6       ],
#        [0.8       ],
#        [0.42888889],
#        [0.66666667],
#        [0.75555556],
#        [0.42444444],
#        [0.66666667],
#        [0.6       ],
#        [0.45333333],
#        [0.36222222],
#        [0.53333333],
#        [0.8       ],
#        [0.54666667],
#        [0.32833333],
#        [0.64      ],
#        [0.46666667],
#        [0.51111111],
#        [0.66666667],
#        [0.58333333],
#        [0.68888889],
#        [0.68333333],
#        [0.73333333],
#        [0.6       ],
#        [0.58571429],
#        [0.51047619],
#        [0.42      ],
#        [0.46666667],
#        [0.56888889],
#        [0.52761905],
#        [0.58666667],
#        [0.50571429],
#        [0.56      ],
#        [0.6225    ],
#        [0.3475    ],
#        [0.50583333],
#        [0.536     ],
#        [0.56583333],
#        [0.62      ],
#        [0.6375    ],
#        [0.55166667],
#        [0.67      ]])

# %%
#Funções para cálculos das métricas de desempenho e ajuste da estrutura dos dados.
'''
def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape
'''

def mape(y_pred,y_true):
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_true,y_pred)
    return rscore

#Função para calcular o coeficiente de determinação entre os valores observados e preditos.
#Calcula-se a correlação entre os valores observados e preditos e eleva ao expoente 2.
def correlacao_determinacao(dtframe,tipo):
    
    if (tipo == 0): #Treino
        resultado = dtframe.corr().previsao_treino.values[1] ** 2 
        
    else: #teste
        resultado = dtframe.corr().previsao_teste.values[1] ** 2
            
    return resultado

def pegar_dados_coluna_test(trainingd,percent,index_coluna):
    data = trainingd.iloc[:,:].values
    train_previsao = trainingd.iloc[0:int(len(data)*percent),index_coluna:index_coluna+1].values
           
    return train_previsao

def ajusta_lista(array):
    lista = []
    
    for i in range(len(array)):
        lista.append(array[i][0])
            
    return lista

#Monta o Dataframe para calcular a correlação e coeficiente de determinação entre os valores observados e preditos.
def df_correlacao(previsoes_treino,treino,previsoes,observado_test):
    
    #print(ajusta_lista(treino))
    
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
      
    #Calcula o coeficiente de determinação
    
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_lista(treino)} 
        
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_lista(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino = round(correlacao_determinacao(df_corr_determinacao_treino,0),4)
    r_teste  = round(correlacao_determinacao(df_corr_determinacao_teste,1),4)
                
    return r_treino,r_teste

# %%
#Separação dos dados para treinamento(70%) e teste(30%)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3)

# %%
am = ['rl','rf','mlp','lstm']

for t in am:
    if t == 'rl':
        model = LinearRegression()
        
        #Treina o modelo
        model.fit(X_train,y_train)
        
        #Predição dos dados de teste
        y_pred = model.predict(X_test)

        y_pred_rl = sc.inverse_transform(y_pred)

        X_test_rl = sc.inverse_transform(X_test)
        y_test_rl = sc.inverse_transform(y_test)
        
        #Predição dos dados de treinamento
        y_predt = model.predict(X_train)
        y_predt_rl = sc.inverse_transform(y_predt)
        
        y_train_rl = sc.inverse_transform(y_train)
               
        plt.plot(y_test_rl,color='red', label='pH Observado')
        plt.plot(y_pred_rl,color='blue', label='pH predito')
        plt.xlabel('Semanas')
        plt.ylabel('Valor de pH')
        plt.legend()
        plt.title('Predição Regressão Linear')
        plt.show()
        
        mape_treino_rl       = round(mape(y_predt_rl,y_train_rl),4)
        rmse_treino_rl       = round(rmse(y_predt_rl,y_train_rl),4)
                
        mape_teste_rl        = round(mape(y_pred_rl,y_test_rl),4)
        rmse_teste_rl        = round(rmse(y_pred_rl,y_test_rl),4)
                
        r_treino_rl,r_teste_rl = df_correlacao(y_predt_rl,y_train_rl,y_pred_rl,y_test_rl)
                        
    elif t == 'rf':
        model = RandomForestRegressor()
        
        #Treina o modelo
        model.fit(X_train,y_train)

        #Predição dados de teste
        y_pred = model.predict(X_test)
                
        y_pred_rf = sc.inverse_transform(y_pred.reshape(-1, 1))
        
        X_test_rf = sc.inverse_transform(X_test)
        y_test_rf = sc.inverse_transform(y_test)
        
        #Predição dados de treinamento
        
        y_predt = model.predict(X_train)
        y_predt_rf = sc.inverse_transform(y_predt.reshape(-1, 1))
        
        y_train_rf = sc.inverse_transform(y_train)
                
        plt.plot(y_test_rf,color='red', label='pH Observado')
        plt.plot(y_pred_rf,color='blue', label='pH predito')
        plt.xlabel('Semanas')
        plt.ylabel('Valor de pH')
        plt.legend()
        plt.title('Predição Random Forest')
        plt.show()
        
        mape_treino_rf       = round(mape(y_predt_rf,y_train_rf),4)
        rmse_treino_rf       = round(rmse(y_predt_rf,y_train_rf),4)
        
        mape_teste_rf        = round(mape(y_pred_rf,y_test_rf),4)
        rmse_teste_rf        = round(rmse(y_pred_rf,y_test_rf),4)
                
        r_treino_rf,r_teste_rf = df_correlacao(y_predt_rf,y_train_rf,y_pred_rf,y_test_rf)
        
    elif t == 'mlp':
                               
        model = Sequential()
        model.add(Dense(units = 10, activation = 'relu'))
        model.add(Dense(units = 21, activation = 'relu'))
        model.add(Dense(units = 1, activation = 'linear'))
        model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

        #Treina o modelo
        model.fit(X_train,y_train, batch_size = 32, epochs = 100)
        
        #Predição com os dados de test
        y_pred = model.predict(X_test)
        y_pred_mlp = normalizador_previsao.inverse_transform(y_pred)

        X_test_mlp = sc.inverse_transform(X_test)
        y_test_mlp = sc.inverse_transform(y_test)
        
        #Predição com os dados de treinamento
        y_predt = model.predict(X_train)
        y_predt_mlp = normalizador_previsao.inverse_transform(y_predt)
        
        y_train_mlp = sc.inverse_transform(y_train)
        
        plt.plot(y_test_mlp,color='red', label='pH Observado')
        plt.plot(y_pred_mlp,color='blue', label='pH predito')
        plt.xlabel('Semanas')
        plt.ylabel('Valor de pH')
        plt.legend()
        plt.title('Predição MLP')
        plt.show()
        
        mape_treino_mlp       = round(mape(y_predt_mlp,y_train_mlp),4)
        rmse_treino_mlp       = round(rmse(y_predt_mlp,y_train_mlp),4)
        
        mape_teste_mlp        = round(mape(y_pred_mlp,y_test_mlp),4)
        rmse_teste_mlp        = round(rmse(y_pred_mlp,y_test_mlp),4)
        
        r_treino_mlp,r_teste_mlp = df_correlacao(y_predt_mlp,y_train_mlp,y_pred_mlp,y_test_mlp)
        
    else:
        
        X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
        X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
        
        model = Sequential()
        model.add(LSTM(units = 10, input_shape = (X_train.shape[1], 1)))
        model.add(Dense(10, activation = 'linear'))
        model.add(Dropout(0.2))
        model.add(Dense(1, activation = 'linear'))
        model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

        #Treina o modelo
        model.fit(X_train,y_train, batch_size = 32, epochs = 100)

        #Predição com dados de teste
        y_pred = model.predict(X_test)
        y_pred_lstm = sc.inverse_transform(y_pred)

        y_test_lstm = sc.inverse_transform(y_test)
        y_test_lstm.shape
        
        #Predição com dados de treinamento
        y_predt = model.predict(X_train)
        y_predt_lstm = sc.inverse_transform(y_predt)

        y_train_lstm = sc.inverse_transform(y_train)
        
        plt.plot(y_test_lstm,color='red', label='pH Observado')
        plt.plot(y_pred_lstm,color='blue', label='pH predito')
        plt.xlabel('Semanas')
        plt.ylabel('Valor de pH')
        plt.legend()
        plt.title('Predição LSTM')
        plt.show()
        
        mape_treino_lstm       = round(mape(y_predt_lstm,y_train_lstm),4)
        rmse_treino_lstm       = round(rmse(y_predt_lstm,y_train_lstm),4)
                
        mape_teste_lstm        = round(mape(y_pred_lstm,y_test_lstm),4)
        rmse_teste_lstm        = round(rmse(y_pred_lstm,y_test_lstm),4)
                
        r_treino_lstm,r_teste_lstm = df_correlacao(y_predt_lstm,y_train_lstm,y_pred_lstm,y_test_lstm)
        
        
# intialise data of lists.
data_treino = {'AM':['Regressão Linear','Random Forest','MLP','LSTM'],
        'MAPE':[mape_treino_rl, mape_treino_rf, mape_treino_mlp,mape_treino_lstm],
        'RMSE':[rmse_treino_rl, rmse_treino_rf, rmse_treino_mlp,rmse_treino_lstm],
        'R²':[r_treino_rl, r_treino_rf, r_treino_mlp,r_treino_lstm],
        'TIPO':['TREINO', 'TREINO', 'TREINO', 'TREINO']}

# intialise data of lists.
data_teste = {'AM':['Regressão Linear','Random Forest','MLP','LSTM'],
        'MAPE':[mape_teste_rl, mape_teste_rf, mape_teste_mlp,mape_teste_lstm],
        'RMSE':[rmse_teste_rl, rmse_teste_rf, rmse_teste_mlp,rmse_teste_lstm],
        'R²':[r_teste_rl, r_teste_rf, r_teste_mlp,r_teste_lstm],
        'TIPO':['TESTE', 'TESTE', 'TESTE', 'TESTE']}
 
# Create DataFrame
df_resultados_treino = pd.DataFrame(data_treino)
df_resultados_teste = pd.DataFrame(data_teste)
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Train on 278 samples
# Epoch 1/100
# 278/278 [==============================] - 3s 9ms/sample - loss: 0.9243 - mean_absolute_error: 0.9243
# Epoch 2/100
# 278/278 [==============================] - 0s 406us/sample - loss: 0.7823 - mean_absolute_error: 0.7823
# Epoch 3/100
# 278/278 [==============================] - 0s 409us/sample - loss: 0.6554 - mean_absolute_error: 0.6554
# Epoch 4/100
# 278/278 [==============================] - 0s 396us/sample - loss: 0.5384 - mean_absolute_error: 0.5384
# Epoch 5/100
# 278/278 [==============================] - 0s 398us/sample - loss: 0.4254 - mean_absolute_error: 0.4254
# Epoch 6/100
# 278/278 [==============================] - 0s 357us/sample - loss: 0.3219 - mean_absolute_error: 0.3219
# Epoch 7/100
# 278/278 [==============================] - 0s 370us/sample - loss: 0.2380 - mean_absolute_error: 0.2380
# Epoch 8/100
# 278/278 [==============================] - 0s 388us/sample - loss: 0.1953 - mean_absolute_error: 0.1953
# Epoch 9/100
# 278/278 [==============================] - 0s 434us/sample - loss: 0.1878 - mean_absolute_error: 0.1878
# Epoch 10/100
# 278/278 [==============================] - 0s 372us/sample - loss: 0.1874 - mean_absolute_error: 0.1874
# Epoch 11/100
# 278/278 [==============================] - 0s 335us/sample - loss: 0.1841 - mean_absolute_error: 0.1841
# Epoch 12/100
# 278/278 [==============================] - 0s 359us/sample - loss: 0.1807 - mean_absolute_error: 0.1807
# Epoch 13/100
# 278/278 [==============================] - 0s 327us/sample - loss: 0.1790 - mean_absolute_error: 0.1790
# Epoch 14/100
# 278/278 [==============================] - 0s 345us/sample - loss: 0.1774 - mean_absolute_error: 0.1774
# Epoch 15/100
# 278/278 [==============================] - 0s 391us/sample - loss: 0.1760 - mean_absolute_error: 0.1760
# Epoch 16/100
# 278/278 [==============================] - 0s 306us/sample - loss: 0.1750 - mean_absolute_error: 0.1750
# Epoch 17/100
# 278/278 [==============================] - 0s 337us/sample - loss: 0.1738 - mean_absolute_error: 0.1738
# Epoch 18/100
# 278/278 [==============================] - 0s 369us/sample - loss: 0.1727 - mean_absolute_error: 0.1727
# Epoch 19/100
# 278/278 [==============================] - 0s 280us/sample - loss: 0.1719 - mean_absolute_error: 0.1719
# Epoch 20/100
# 278/278 [==============================] - 0s 353us/sample - loss: 0.1711 - mean_absolute_error: 0.1711
# Epoch 21/100
# 278/278 [==============================] - 0s 327us/sample - loss: 0.1697 - mean_absolute_error: 0.1697
# Epoch 22/100
# 278/278 [==============================] - 0s 316us/sample - loss: 0.1687 - mean_absolute_error: 0.1687
# Epoch 23/100
# 278/278 [==============================] - 0s 260us/sample - loss: 0.1680 - mean_absolute_error: 0.1680
# Epoch 24/100
# 278/278 [==============================] - 0s 303us/sample - loss: 0.1678 - mean_absolute_error: 0.1678
# Epoch 25/100
# 278/278 [==============================] - ETA: 0s - loss: 0.1684 - mean_absolute_error: 0.168 - 0s 357us/sample - loss: 0.1666 - mean_absolute_error: 0.1666
# Epoch 26/100
# 278/278 [==============================] - ETA: 0s - loss: 0.1644 - mean_absolute_error: 0.164 - 0s 333us/sample - loss: 0.1659 - mean_absolute_error: 0.1659
# Epoch 27/100
# 278/278 [==============================] - 0s 318us/sample - loss: 0.1653 - mean_absolute_error: 0.1653
# Epoch 28/100
# 278/278 [==============================] - 0s 328us/sample - loss: 0.1648 - mean_absolute_error: 0.1648
# Epoch 29/100
# 278/278 [==============================] - 0s 297us/sample - loss: 0.1641 - mean_absolute_error: 0.1641
# Epoch 30/100
# 278/278 [==============================] - 0s 351us/sample - loss: 0.1638 - mean_absolute_error: 0.1638
# Epoch 31/100
# 278/278 [==============================] - 0s 382us/sample - loss: 0.1636 - mean_absolute_error: 0.1636
# Epoch 32/100
# 278/278 [==============================] - ETA: 0s - loss: 0.1636 - mean_absolute_error: 0.163 - 0s 279us/sample - loss: 0.1631 - mean_absolute_error: 0.1631
# Epoch 33/100
# 278/278 [==============================] - 0s 349us/sample - loss: 0.1627 - mean_absolute_error: 0.1627
# Epoch 34/100
# 278/278 [==============================] - 0s 317us/sample - loss: 0.1627 - mean_absolute_error: 0.1627
# Epoch 35/100
# 278/278 [==============================] - 0s 371us/sample - loss: 0.1625 - mean_absolute_error: 0.1625
# Epoch 36/100
# 278/278 [==============================] - 0s 304us/sample - loss: 0.1622 - mean_absolute_error: 0.1622
# Epoch 37/100
# 278/278 [==============================] - 0s 297us/sample - loss: 0.1628 - mean_absolute_error: 0.1628
# Epoch 38/100
# 278/278 [==============================] - 0s 398us/sample - loss: 0.1621 - mean_absolute_error: 0.1621
# Epoch 39/100
# 278/278 [==============================] - 0s 322us/sample - loss: 0.1621 - mean_absolute_error: 0.1621
# Epoch 40/100
# 278/278 [==============================] - 0s 325us/sample - loss: 0.1616 - mean_absolute_error: 0.1616
# Epoch 41/100
# 278/278 [==============================] - 0s 298us/sample - loss: 0.1614 - mean_absolute_error: 0.1614
# Epoch 42/100
# 278/278 [==============================] - 0s 325us/sample - loss: 0.1615 - mean_absolute_error: 0.1615
# Epoch 43/100
# 278/278 [==============================] - 0s 335us/sample - loss: 0.1614 - mean_absolute_error: 0.1614
# Epoch 44/100
# 278/278 [==============================] - 0s 325us/sample - loss: 0.1615 - mean_absolute_error: 0.1615
# Epoch 45/100
# 278/278 [==============================] - 0s 280us/sample - loss: 0.1614 - mean_absolute_error: 0.1614
# Epoch 46/100
# 278/278 [==============================] - 0s 367us/sample - loss: 0.1616 - mean_absolute_error: 0.1616
# Epoch 47/100
# 278/278 [==============================] - 0s 347us/sample - loss: 0.1614 - mean_absolute_error: 0.1614
# Epoch 48/100
# 278/278 [==============================] - 0s 308us/sample - loss: 0.1609 - mean_absolute_error: 0.1609
# Epoch 49/100
# 278/278 [==============================] - 0s 323us/sample - loss: 0.1610 - mean_absolute_error: 0.1610
# Epoch 50/100
# 278/278 [==============================] - 0s 287us/sample - loss: 0.1611 - mean_absolute_error: 0.1611
# Epoch 51/100
# 278/278 [==============================] - 0s 303us/sample - loss: 0.1610 - mean_absolute_error: 0.1610
# Epoch 52/100
# 278/278 [==============================] - 0s 267us/sample - loss: 0.1609 - mean_absolute_error: 0.1609
# Epoch 53/100
# 278/278 [==============================] - 0s 276us/sample - loss: 0.1606 - mean_absolute_error: 0.1606
# Epoch 54/100
# 278/278 [==============================] - 0s 272us/sample - loss: 0.1609 - mean_absolute_error: 0.1609
# Epoch 55/100
# 278/278 [==============================] - 0s 252us/sample - loss: 0.1608 - mean_absolute_error: 0.1608
# Epoch 56/100
# 278/278 [==============================] - 0s 273us/sample - loss: 0.1604 - mean_absolute_error: 0.1604
# Epoch 57/100
# 278/278 [==============================] - 0s 228us/sample - loss: 0.1607 - mean_absolute_error: 0.1607
# Epoch 58/100
# 278/278 [==============================] - 0s 251us/sample - loss: 0.1605 - mean_absolute_error: 0.1605
# Epoch 59/100
# 278/278 [==============================] - 0s 274us/sample - loss: 0.1606 - mean_absolute_error: 0.1606
# Epoch 60/100
# 278/278 [==============================] - 0s 247us/sample - loss: 0.1604 - mean_absolute_error: 0.1604
# Epoch 61/100
# 278/278 [==============================] - 0s 240us/sample - loss: 0.1605 - mean_absolute_error: 0.1605
# Epoch 62/100
# 278/278 [==============================] - 0s 263us/sample - loss: 0.1612 - mean_absolute_error: 0.1612
# Epoch 63/100
# 278/278 [==============================] - 0s 248us/sample - loss: 0.1606 - mean_absolute_error: 0.1606
# Epoch 64/100
# 278/278 [==============================] - 0s 231us/sample - loss: 0.1607 - mean_absolute_error: 0.1607
# Epoch 65/100
# 278/278 [==============================] - 0s 259us/sample - loss: 0.1603 - mean_absolute_error: 0.1603
# Epoch 66/100
# 278/278 [==============================] - 0s 222us/sample - loss: 0.1602 - mean_absolute_error: 0.1602
# Epoch 67/100
# 278/278 [==============================] - 0s 269us/sample - loss: 0.1602 - mean_absolute_error: 0.1602
# Epoch 68/100
# 278/278 [==============================] - 0s 222us/sample - loss: 0.1602 - mean_absolute_error: 0.1602
# Epoch 69/100
# 278/278 [==============================] - 0s 258us/sample - loss: 0.1602 - mean_absolute_error: 0.1602
# Epoch 70/100
# 278/278 [==============================] - 0s 232us/sample - loss: 0.1600 - mean_absolute_error: 0.1600
# Epoch 71/100
# 278/278 [==============================] - 0s 181us/sample - loss: 0.1604 - mean_absolute_error: 0.1604
# Epoch 72/100
# 278/278 [==============================] - 0s 234us/sample - loss: 0.1602 - mean_absolute_error: 0.1602
# Epoch 73/100
# 278/278 [==============================] - 0s 183us/sample - loss: 0.1600 - mean_absolute_error: 0.1600
# Epoch 74/100
# 278/278 [==============================] - 0s 193us/sample - loss: 0.1600 - mean_absolute_error: 0.1600
# Epoch 75/100
# 278/278 [==============================] - 0s 154us/sample - loss: 0.1599 - mean_absolute_error: 0.1599
# Epoch 76/100
# 278/278 [==============================] - 0s 211us/sample - loss: 0.1601 - mean_absolute_error: 0.1601
# Epoch 77/100
# 278/278 [==============================] - 0s 257us/sample - loss: 0.1597 - mean_absolute_error: 0.1597
# Epoch 78/100
# 278/278 [==============================] - 0s 202us/sample - loss: 0.1604 - mean_absolute_error: 0.1604
# Epoch 79/100
# 278/278 [==============================] - 0s 223us/sample - loss: 0.1605 - mean_absolute_error: 0.1605
# Epoch 80/100
# 278/278 [==============================] - 0s 239us/sample - loss: 0.1602 - mean_absolute_error: 0.1602
# Epoch 81/100
# 278/278 [==============================] - 0s 178us/sample - loss: 0.1605 - mean_absolute_error: 0.1605
# Epoch 82/100
# 278/278 [==============================] - 0s 219us/sample - loss: 0.1599 - mean_absolute_error: 0.1599
# Epoch 83/100
# 278/278 [==============================] - 0s 191us/sample - loss: 0.1598 - mean_absolute_error: 0.1598
# Epoch 84/100
# 278/278 [==============================] - 0s 257us/sample - loss: 0.1601 - mean_absolute_error: 0.1601
# Epoch 85/100
# 278/278 [==============================] - 0s 230us/sample - loss: 0.1598 - mean_absolute_error: 0.1598
# Epoch 86/100
# 278/278 [==============================] - 0s 174us/sample - loss: 0.1595 - mean_absolute_error: 0.1595
# Epoch 87/100
# 278/278 [==============================] - 0s 281us/sample - loss: 0.1613 - mean_absolute_error: 0.1613
# Epoch 88/100
# 278/278 [==============================] - 0s 220us/sample - loss: 0.1591 - mean_absolute_error: 0.1591
# Epoch 89/100
# 278/278 [==============================] - 0s 188us/sample - loss: 0.1596 - mean_absolute_error: 0.1596
# Epoch 90/100
# 278/278 [==============================] - 0s 246us/sample - loss: 0.1592 - mean_absolute_error: 0.1592
# Epoch 91/100
# 278/278 [==============================] - 0s 269us/sample - loss: 0.1598 - mean_absolute_error: 0.1598
# Epoch 92/100
# 278/278 [==============================] - 0s 259us/sample - loss: 0.1588 - mean_absolute_error: 0.1588
# Epoch 93/100
# 278/278 [==============================] - 0s 227us/sample - loss: 0.1601 - mean_absolute_error: 0.1601
# Epoch 94/100
# 278/278 [==============================] - 0s 258us/sample - loss: 0.1598 - mean_absolute_error: 0.1598
# Epoch 95/100
# 278/278 [==============================] - 0s 230us/sample - loss: 0.1592 - mean_absolute_error: 0.1592
# Epoch 96/100
# 278/278 [==============================] - 0s 198us/sample - loss: 0.1599 - mean_absolute_error: 0.1599
# Epoch 97/100
# 278/278 [==============================] - 0s 202us/sample - loss: 0.1590 - mean_absolute_error: 0.1590
# Epoch 98/100
# 278/278 [==============================] - 0s 172us/sample - loss: 0.1599 - mean_absolute_error: 0.1599
# Epoch 99/100
# 278/278 [==============================] - 0s 300us/sample - loss: 0.1598 - mean_absolute_error: 0.1598
# Epoch 100/100
# 278/278 [==============================] - 0s 272us/sample - loss: 0.1587 - mean_absolute_error: 0.1587
# Train on 278 samples
# Epoch 1/100
# 278/278 [==============================] - 11s 39ms/sample - loss: 0.4233 - mean_absolute_error: 0.4233
# Epoch 2/100
# 278/278 [==============================] - 0s 793us/sample - loss: 0.3503 - mean_absolute_error: 0.3503
# Epoch 3/100
# 278/278 [==============================] - 0s 808us/sample - loss: 0.2859 - mean_absolute_error: 0.2859
# Epoch 4/100
# 278/278 [==============================] - 0s 659us/sample - loss: 0.2318 - mean_absolute_error: 0.2318
# Epoch 5/100
# 278/278 [==============================] - 0s 573us/sample - loss: 0.2000 - mean_absolute_error: 0.2000
# Epoch 6/100
# 278/278 [==============================] - 0s 550us/sample - loss: 0.1959 - mean_absolute_error: 0.1959
# Epoch 7/100
# 278/278 [==============================] - 0s 672us/sample - loss: 0.1935 - mean_absolute_error: 0.1935
# Epoch 8/100
# 278/278 [==============================] - 0s 576us/sample - loss: 0.1970 - mean_absolute_error: 0.1970
# Epoch 9/100
# 278/278 [==============================] - 0s 618us/sample - loss: 0.1911 - mean_absolute_error: 0.1911
# Epoch 10/100
# 278/278 [==============================] - 0s 951us/sample - loss: 0.1869 - mean_absolute_error: 0.1869
# Epoch 11/100
# 278/278 [==============================] - 0s 942us/sample - loss: 0.1905 - mean_absolute_error: 0.1905
# Epoch 12/100
# 278/278 [==============================] - 0s 1ms/sample - loss: 0.1933 - mean_absolute_error: 0.1933
# Epoch 13/100
# 278/278 [==============================] - 0s 1ms/sample - loss: 0.1827 - mean_absolute_error: 0.1827
# Epoch 14/100
# 278/278 [==============================] - 0s 786us/sample - loss: 0.1894 - mean_absolute_error: 0.1894
# Epoch 15/100
# 278/278 [==============================] - 0s 920us/sample - loss: 0.1789 - mean_absolute_error: 0.1789
# Epoch 16/100
# 278/278 [==============================] - 0s 997us/sample - loss: 0.1846 - mean_absolute_error: 0.1846
# Epoch 17/100
# 278/278 [==============================] - 0s 1ms/sample - loss: 0.1802 - mean_absolute_error: 0.1802
# Epoch 18/100
# 278/278 [==============================] - 0s 889us/sample - loss: 0.1843 - mean_absolute_error: 0.1843
# Epoch 19/100
# 278/278 [==============================] - 0s 903us/sample - loss: 0.1865 - mean_absolute_error: 0.1865
# Epoch 20/100
# 278/278 [==============================] - 0s 1ms/sample - loss: 0.1796 - mean_absolute_error: 0.1796
# Epoch 21/100
# 278/278 [==============================] - 0s 940us/sample - loss: 0.1874 - mean_absolute_error: 0.1874
# Epoch 22/100
# 278/278 [==============================] - 0s 839us/sample - loss: 0.1866 - mean_absolute_error: 0.1866
# Epoch 23/100
# 278/278 [==============================] - 0s 752us/sample - loss: 0.1772 - mean_absolute_error: 0.1772
# Epoch 24/100
# 278/278 [==============================] - 0s 740us/sample - loss: 0.1734 - mean_absolute_error: 0.1734
# Epoch 25/100
# 278/278 [==============================] - 0s 814us/sample - loss: 0.1743 - mean_absolute_error: 0.1743
# Epoch 26/100
# 278/278 [==============================] - 0s 815us/sample - loss: 0.1677 - mean_absolute_error: 0.1677
# Epoch 27/100
# 278/278 [==============================] - 0s 676us/sample - loss: 0.1786 - mean_absolute_error: 0.1786
# Epoch 28/100
# 278/278 [==============================] - 0s 725us/sample - loss: 0.1700 - mean_absolute_error: 0.1700
# Epoch 29/100
# 278/278 [==============================] - 0s 769us/sample - loss: 0.1778 - mean_absolute_error: 0.1778
# Epoch 30/100
# 278/278 [==============================] - 0s 901us/sample - loss: 0.1669 - mean_absolute_error: 0.1669
# Epoch 31/100
# 278/278 [==============================] - 0s 724us/sample - loss: 0.1736 - mean_absolute_error: 0.1736
# Epoch 32/100
# 278/278 [==============================] - 0s 740us/sample - loss: 0.1796 - mean_absolute_error: 0.1796
# Epoch 33/100
# 278/278 [==============================] - 0s 665us/sample - loss: 0.1770 - mean_absolute_error: 0.1770
# Epoch 34/100
# 278/278 [==============================] - 0s 795us/sample - loss: 0.1734 - mean_absolute_error: 0.1734
# Epoch 35/100
# 278/278 [==============================] - 0s 911us/sample - loss: 0.1779 - mean_absolute_error: 0.1779
# Epoch 36/100
# 278/278 [==============================] - 0s 800us/sample - loss: 0.1723 - mean_absolute_error: 0.1723
# Epoch 37/100
# 278/278 [==============================] - 0s 790us/sample - loss: 0.1652 - mean_absolute_error: 0.1652
# Epoch 38/100
# 278/278 [==============================] - 0s 810us/sample - loss: 0.1730 - mean_absolute_error: 0.1730
# Epoch 39/100
# 278/278 [==============================] - 0s 802us/sample - loss: 0.1707 - mean_absolute_error: 0.1707
# Epoch 40/100
# 278/278 [==============================] - 0s 828us/sample - loss: 0.1736 - mean_absolute_error: 0.1736
# Epoch 41/100
# 278/278 [==============================] - 0s 729us/sample - loss: 0.1743 - mean_absolute_error: 0.1743
# Epoch 42/100
# 278/278 [==============================] - 0s 771us/sample - loss: 0.1767 - mean_absolute_error: 0.1767
# Epoch 43/100
# 278/278 [==============================] - 0s 757us/sample - loss: 0.1729 - mean_absolute_error: 0.1729
# Epoch 44/100
# 278/278 [==============================] - 0s 816us/sample - loss: 0.1744 - mean_absolute_error: 0.1744
# Epoch 45/100
# 278/278 [==============================] - 0s 770us/sample - loss: 0.1703 - mean_absolute_error: 0.1703
# Epoch 46/100
# 278/278 [==============================] - 0s 767us/sample - loss: 0.1748 - mean_absolute_error: 0.1748
# Epoch 47/100
# 278/278 [==============================] - 0s 817us/sample - loss: 0.1745 - mean_absolute_error: 0.1745
# Epoch 48/100
# 278/278 [==============================] - 0s 846us/sample - loss: 0.1757 - mean_absolute_error: 0.1757
# Epoch 49/100
# 278/278 [==============================] - 0s 801us/sample - loss: 0.1770 - mean_absolute_error: 0.1770
# Epoch 50/100
# 278/278 [==============================] - 0s 816us/sample - loss: 0.1765 - mean_absolute_error: 0.1765
# Epoch 51/100
# 278/278 [==============================] - 0s 844us/sample - loss: 0.1724 - mean_absolute_error: 0.1724
# Epoch 52/100
# 278/278 [==============================] - 0s 745us/sample - loss: 0.1727 - mean_absolute_error: 0.1727
# Epoch 53/100
# 278/278 [==============================] - 0s 779us/sample - loss: 0.1740 - mean_absolute_error: 0.1740
# Epoch 54/100
# 278/278 [==============================] - 0s 738us/sample - loss: 0.1732 - mean_absolute_error: 0.1732
# Epoch 55/100
# 278/278 [==============================] - 0s 871us/sample - loss: 0.1735 - mean_absolute_error: 0.1735
# Epoch 56/100
# 278/278 [==============================] - 0s 809us/sample - loss: 0.1732 - mean_absolute_error: 0.1732
# Epoch 57/100
# 278/278 [==============================] - 0s 818us/sample - loss: 0.1747 - mean_absolute_error: 0.1747
# Epoch 58/100
# 278/278 [==============================] - 0s 871us/sample - loss: 0.1696 - mean_absolute_error: 0.1696
# Epoch 59/100
# 278/278 [==============================] - ETA: 0s - loss: 0.1785 - mean_absolute_error: 0.178 - 0s 686us/sample - loss: 0.1730 - mean_absolute_error: 0.1730
# Epoch 60/100
# 278/278 [==============================] - 0s 724us/sample - loss: 0.1718 - mean_absolute_error: 0.1718
# Epoch 61/100
# 278/278 [==============================] - 0s 850us/sample - loss: 0.1668 - mean_absolute_error: 0.1668
# Epoch 62/100
# 278/278 [==============================] - 0s 781us/sample - loss: 0.1725 - mean_absolute_error: 0.1725
# Epoch 63/100
# 278/278 [==============================] - 0s 788us/sample - loss: 0.1710 - mean_absolute_error: 0.1710
# Epoch 64/100
# 278/278 [==============================] - 0s 833us/sample - loss: 0.1634 - mean_absolute_error: 0.1634
# Epoch 65/100
# 278/278 [==============================] - 0s 772us/sample - loss: 0.1754 - mean_absolute_error: 0.1754
# Epoch 66/100
# 278/278 [==============================] - 0s 785us/sample - loss: 0.1690 - mean_absolute_error: 0.1690
# Epoch 67/100
# 278/278 [==============================] - 0s 789us/sample - loss: 0.1750 - mean_absolute_error: 0.1750
# Epoch 68/100
# 278/278 [==============================] - 0s 855us/sample - loss: 0.1755 - mean_absolute_error: 0.1755
# Epoch 69/100
# 278/278 [==============================] - 0s 790us/sample - loss: 0.1746 - mean_absolute_error: 0.1746
# Epoch 70/100
# 278/278 [==============================] - 0s 785us/sample - loss: 0.1733 - mean_absolute_error: 0.1733
# Epoch 71/100
# 278/278 [==============================] - 0s 632us/sample - loss: 0.1717 - mean_absolute_error: 0.1717
# Epoch 72/100
# 278/278 [==============================] - 0s 517us/sample - loss: 0.1786 - mean_absolute_error: 0.1786
# Epoch 73/100
# 278/278 [==============================] - 0s 441us/sample - loss: 0.1696 - mean_absolute_error: 0.1696
# Epoch 74/100
# 278/278 [==============================] - 0s 606us/sample - loss: 0.1705 - mean_absolute_error: 0.1705
# Epoch 75/100
# 278/278 [==============================] - 0s 437us/sample - loss: 0.1739 - mean_absolute_error: 0.1739
# Epoch 76/100
# 278/278 [==============================] - 0s 404us/sample - loss: 0.1724 - mean_absolute_error: 0.1724
# Epoch 77/100
# 278/278 [==============================] - 0s 464us/sample - loss: 0.1742 - mean_absolute_error: 0.1742
# Epoch 78/100
# 278/278 [==============================] - 0s 546us/sample - loss: 0.1673 - mean_absolute_error: 0.1673s - loss: 0.1648 - mean_absolute_error: 0.16
# Epoch 79/100
# 278/278 [==============================] - 0s 546us/sample - loss: 0.1648 - mean_absolute_error: 0.1648
# Epoch 80/100
# 278/278 [==============================] - 0s 492us/sample - loss: 0.1720 - mean_absolute_error: 0.1720
# Epoch 81/100
# 278/278 [==============================] - 0s 528us/sample - loss: 0.1702 - mean_absolute_error: 0.1702
# Epoch 82/100
# 278/278 [==============================] - 0s 746us/sample - loss: 0.1723 - mean_absolute_error: 0.1723
# Epoch 83/100
# 278/278 [==============================] - 0s 779us/sample - loss: 0.1725 - mean_absolute_error: 0.1725
# Epoch 84/100
# 278/278 [==============================] - 0s 785us/sample - loss: 0.1704 - mean_absolute_error: 0.1704
# Epoch 85/100
# 278/278 [==============================] - 0s 627us/sample - loss: 0.1745 - mean_absolute_error: 0.1745
# Epoch 86/100
# 278/278 [==============================] - 0s 621us/sample - loss: 0.1743 - mean_absolute_error: 0.1743
# Epoch 87/100
# 278/278 [==============================] - 0s 500us/sample - loss: 0.1730 - mean_absolute_error: 0.1730
# Epoch 88/100
# 278/278 [==============================] - 0s 682us/sample - loss: 0.1756 - mean_absolute_error: 0.1756
# Epoch 89/100
# 278/278 [==============================] - 0s 507us/sample - loss: 0.1762 - mean_absolute_error: 0.1762
# Epoch 90/100
# 278/278 [==============================] - 0s 448us/sample - loss: 0.1656 - mean_absolute_error: 0.1656
# Epoch 91/100
# 278/278 [==============================] - 0s 524us/sample - loss: 0.1686 - mean_absolute_error: 0.1686
# Epoch 92/100
# 278/278 [==============================] - 0s 612us/sample - loss: 0.1700 - mean_absolute_error: 0.1700
# Epoch 93/100
# 278/278 [==============================] - 0s 570us/sample - loss: 0.1754 - mean_absolute_error: 0.1754
# Epoch 94/100
# 278/278 [==============================] - 0s 514us/sample - loss: 0.1728 - mean_absolute_error: 0.1728
# Epoch 95/100
# 278/278 [==============================] - 0s 564us/sample - loss: 0.1715 - mean_absolute_error: 0.1715
# Epoch 96/100
# 278/278 [==============================] - 0s 483us/sample - loss: 0.1735 - mean_absolute_error: 0.1735
# Epoch 97/100
# 278/278 [==============================] - 0s 510us/sample - loss: 0.1727 - mean_absolute_error: 0.1727
# Epoch 98/100
# 278/278 [==============================] - 0s 489us/sample - loss: 0.1727 - mean_absolute_error: 0.1727
# Epoch 99/100
# 278/278 [==============================] - 0s 471us/sample - loss: 0.1675 - mean_absolute_error: 0.1675
# Epoch 100/100
# 278/278 [==============================] - 0s 447us/sample - loss: 0.1700 - mean_absolute_error: 0.1700

# %%
df_resultados_treino
# Out:
#                  AM    MAPE    RMSE      R²    TIPO
# 0  Regressão Linear  2.5433  0.2300  0.0123  TREINO
# 1     Random Forest  1.0688  0.1010  0.8570  TREINO
# 2               MLP  5.2293  0.4322  0.0413  TREINO
# 3              LSTM  2.5497  0.2310  0.0067  TREINO

# %%
df_resultados_teste
# Out:
#                  AM    MAPE    RMSE      R²   TIPO
# 0  Regressão Linear  2.7211  0.2481  0.0003  TESTE
# 1     Random Forest  3.1977  0.2824  0.0031  TESTE
# 2               MLP  5.5112  0.4600  0.0039  TESTE
# 3              LSTM  2.7118  0.2459  0.0014  TESTE
