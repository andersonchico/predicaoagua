# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Dropout

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Dados completo.
data = trainingd.iloc[:,:].values
#treino (70%)
train = trainingd.iloc[0:174,:].values  
#teste (30%)
test = trainingd.iloc[174:,:].values 

print('Completo:',len(data))
print('treino:',len(train))
print('teste:',len(test))
data.shape
# Out:
# Completo: 248
# treino: 174
# teste: 74
# (248, 1)

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
sc = MinMaxScaler()
train = sc.fit_transform(train)
test = sc.fit_transform(test)

# %%
#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

# %%
lags = 87 # Equivalente à 10% dos dados de treino.
#Prepara os dados de treinamento
train_X, train_y = prepara_dados(train, lags)

train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))

#Prepara os dados de teste
entradas = trainingd[len(trainingd) - len(test) - lags:].values
entradas = entradas.reshape(-1, 1)
entradas = sc.fit_transform(entradas)

test_X = []
for i in range(lags, lags+len(test)):
    test_X.append(entradas[i-lags:i, 0])
test_X = np.array(test_X)
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

#Cria o modelo

model = Sequential()
model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
model.add(Dense(10, activation = 'linear'))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

#Treina o modelo
model.fit(train_X, train_y, batch_size = 32, epochs = 100)
#score = model.score(train_X,train_y)
#print(score)

#Dados de teste
previsoes = model.predict(test_X)
previsoes = previsoes.reshape(-1,1)
previsoes = sc.inverse_transform(previsoes)

#Dados de treino
previsoes_treino = model.predict(train_X)
previsoes_treino = previsoes_treino.reshape(-1,1)
previsoes_treino = sc.inverse_transform(previsoes_treino)
# Out:
# Train on 87 samples
# Epoch 1/100
# 87/87 [==============================] - 2s 19ms/sample - loss: 0.6736 - mean_absolute_error: 0.6736
# Epoch 2/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.6290 - mean_absolute_error: 0.6290
# Epoch 3/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.4845 - mean_absolute_error: 0.4845
# Epoch 4/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.4193 - mean_absolute_error: 0.4193
# Epoch 5/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.3529 - mean_absolute_error: 0.3529
# Epoch 6/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.2906 - mean_absolute_error: 0.2906
# Epoch 7/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.2076 - mean_absolute_error: 0.2076
# Epoch 8/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1685 - mean_absolute_error: 0.1685
# Epoch 9/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.2295 - mean_absolute_error: 0.2295
# Epoch 10/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1915 - mean_absolute_error: 0.1915
# Epoch 11/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1609 - mean_absolute_error: 0.1609
# Epoch 12/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.2507 - mean_absolute_error: 0.2507
# Epoch 13/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1679 - mean_absolute_error: 0.1679
# Epoch 14/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1824 - mean_absolute_error: 0.1824
# Epoch 15/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1625 - mean_absolute_error: 0.1625
# Epoch 16/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1883 - mean_absolute_error: 0.1883
# Epoch 17/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1649 - mean_absolute_error: 0.1649
# Epoch 18/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1440 - mean_absolute_error: 0.1440
# Epoch 19/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1444 - mean_absolute_error: 0.1444
# Epoch 20/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1610 - mean_absolute_error: 0.1610
# Epoch 21/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1866 - mean_absolute_error: 0.1866
# Epoch 22/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1703 - mean_absolute_error: 0.1703
# Epoch 23/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1558 - mean_absolute_error: 0.1558
# Epoch 24/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1558 - mean_absolute_error: 0.1558
# Epoch 25/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1470 - mean_absolute_error: 0.1470
# Epoch 26/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1689 - mean_absolute_error: 0.1689
# Epoch 27/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1595 - mean_absolute_error: 0.1595
# Epoch 28/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1554 - mean_absolute_error: 0.1554
# Epoch 29/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1568 - mean_absolute_error: 0.1568
# Epoch 30/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1629 - mean_absolute_error: 0.1629
# Epoch 31/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1737 - mean_absolute_error: 0.1737
# Epoch 32/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1327 - mean_absolute_error: 0.1327
# Epoch 33/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1500 - mean_absolute_error: 0.1500
# Epoch 34/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1365 - mean_absolute_error: 0.1365
# Epoch 35/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1262 - mean_absolute_error: 0.1262
# Epoch 36/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1465 - mean_absolute_error: 0.1465
# Epoch 37/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1367 - mean_absolute_error: 0.1367
# Epoch 38/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1460 - mean_absolute_error: 0.1460
# Epoch 39/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1227 - mean_absolute_error: 0.1227
# Epoch 40/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1456 - mean_absolute_error: 0.1456
# Epoch 41/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1402 - mean_absolute_error: 0.1402
# Epoch 42/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1447 - mean_absolute_error: 0.1447
# Epoch 43/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1326 - mean_absolute_error: 0.1326
# Epoch 44/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1371 - mean_absolute_error: 0.1371
# Epoch 45/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1398 - mean_absolute_error: 0.1398
# Epoch 46/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1308 - mean_absolute_error: 0.1308
# Epoch 47/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1244 - mean_absolute_error: 0.1244
# Epoch 48/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1355 - mean_absolute_error: 0.1355
# Epoch 49/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1351 - mean_absolute_error: 0.1351
# Epoch 50/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1274 - mean_absolute_error: 0.1274
# Epoch 51/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1433 - mean_absolute_error: 0.1433
# Epoch 52/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1152 - mean_absolute_error: 0.1152
# Epoch 53/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1270 - mean_absolute_error: 0.1270
# Epoch 54/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1361 - mean_absolute_error: 0.1361
# Epoch 55/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1176 - mean_absolute_error: 0.1176
# Epoch 56/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1536 - mean_absolute_error: 0.1536
# Epoch 57/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1288 - mean_absolute_error: 0.1288
# Epoch 58/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1204 - mean_absolute_error: 0.1204
# Epoch 59/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1227 - mean_absolute_error: 0.1227
# Epoch 60/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1341 - mean_absolute_error: 0.1341
# Epoch 61/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1437 - mean_absolute_error: 0.1437
# Epoch 62/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1432 - mean_absolute_error: 0.1432
# Epoch 63/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1258 - mean_absolute_error: 0.1258
# Epoch 64/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1497 - mean_absolute_error: 0.1497
# Epoch 65/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1189 - mean_absolute_error: 0.1189
# Epoch 66/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1338 - mean_absolute_error: 0.1338
# Epoch 67/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1212 - mean_absolute_error: 0.1212
# Epoch 68/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1305 - mean_absolute_error: 0.1305
# Epoch 69/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1169 - mean_absolute_error: 0.1169
# Epoch 70/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1280 - mean_absolute_error: 0.1280
# Epoch 71/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1229 - mean_absolute_error: 0.1229
# Epoch 72/100
# 87/87 [==============================] - 0s 2ms/sample - loss: 0.1346 - mean_absolute_error: 0.1346
# Epoch 73/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1274 - mean_absolute_error: 0.1274
# Epoch 74/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1275 - mean_absolute_error: 0.1275
# Epoch 75/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1377 - mean_absolute_error: 0.1377
# Epoch 76/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1329 - mean_absolute_error: 0.1329
# Epoch 77/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1189 - mean_absolute_error: 0.1189
# Epoch 78/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1157 - mean_absolute_error: 0.1157
# Epoch 79/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1298 - mean_absolute_error: 0.1298
# Epoch 80/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1217 - mean_absolute_error: 0.1217
# Epoch 81/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1350 - mean_absolute_error: 0.1350
# Epoch 82/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1163 - mean_absolute_error: 0.1163
# Epoch 83/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1171 - mean_absolute_error: 0.1171
# Epoch 84/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1235 - mean_absolute_error: 0.1235
# Epoch 85/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1183 - mean_absolute_error: 0.1183
# Epoch 86/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1271 - mean_absolute_error: 0.1271
# Epoch 87/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1216 - mean_absolute_error: 0.1216
# Epoch 88/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1336 - mean_absolute_error: 0.1336
# Epoch 89/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1412 - mean_absolute_error: 0.1412
# Epoch 90/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1216 - mean_absolute_error: 0.1216
# Epoch 91/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1224 - mean_absolute_error: 0.1224
# Epoch 92/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1147 - mean_absolute_error: 0.1147
# Epoch 93/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1225 - mean_absolute_error: 0.1225
# Epoch 94/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1205 - mean_absolute_error: 0.1205
# Epoch 95/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1150 - mean_absolute_error: 0.1150
# Epoch 96/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1174 - mean_absolute_error: 0.1174
# Epoch 97/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1135 - mean_absolute_error: 0.1135
# Epoch 98/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1225 - mean_absolute_error: 0.1225
# Epoch 99/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1332 - mean_absolute_error: 0.1332
# Epoch 100/100
# 87/87 [==============================] - 0s 1ms/sample - loss: 0.1185 - mean_absolute_error: 0.1185

# %%
#Preparação para plotagem

train_predict_plot = np.empty_like(data)
train_predict_plot[:, :] = np.nan
train_predict_plot[lags: len(previsoes_treino) + lags, :] = previsoes_treino
train_predict_plot.shape
    
test_predict_plot = np.empty_like(data)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(previsoes_treino)+lags:len(data), :] = previsoes

#Plotagem do gráfico
plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(train_predict_plot, color = 'green', label = 'Previsão de treino')
plt.plot(test_predict_plot, color = '#ff0066', label = 'Previsão de teste')
plt.title('Predição do pH com lag = 50%')
plt.xlabel('Bimestre')
plt.ylabel('Valor pH')
plt.legend()
plt.grid()
plt.show()
    
#Calculo do erro da previsão
#mape(previsoes.mean(),test.mean())
test = sc.inverse_transform(test)
treino = sc.inverse_transform(train[lags: len(previsoes_treino) + lags, :])

print('Resultados com lag', lags)
print('\n')
print('MAPE TREINO:',round(mape(previsoes_treino,treino)[0],2),'%')
print('RMSE TREINO:',round(rmse(previsoes_treino,treino),2))
print('\n')
print('MAPE TESTE:',round(mape(previsoes,test)[0],2),'%')
print('RMSE TESTE:',round(rmse(previsoes,test),2))
print('\n')
# Out:
# Resultados com lag 87
#
#
# MAPE TREINO: 1.06 %
# RMSE TREINO: 0.11
#
#
# MAPE TESTE: 1.53 %
# RMSE TESTE: 0.19

# %%
# Out:
# (248, 1)

# %%
# Out:
# 174
