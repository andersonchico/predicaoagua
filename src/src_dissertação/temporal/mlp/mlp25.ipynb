# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Dados completo.
data = trainingd.iloc[:,:].values
#treino (70%)
train = trainingd.iloc[0:174,:].values  
#teste (30%)
test = trainingd.iloc[174:,:].values 

print('Completo:',len(data))
print('treino:',len(train))
print('teste:',len(test))
data.shape
# Out:
# Completo: 248
# treino: 174
# teste: 74
# (248, 1)

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (-1 a 1).
sc = MinMaxScaler()
train = sc.fit_transform(train)
test = sc.fit_transform(test)

# %%
#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_true,y_pred)
    return rscore

# %%
lags = 43 # Equivalente à 25% dos dados de treino.
#Prepara os dados de treinamento
train_X, train_y = prepara_dados(train, lags)
    
#Prepara os dados de teste
entradas = trainingd[len(trainingd) - len(test) - lags:].values
entradas = entradas.reshape(-1, 1)
entradas = sc.fit_transform(entradas)

test_X = []
for i in range(lags, lags+len(test)):
    test_X.append(entradas[i-lags:i, 0])
test_X = np.array(test_X)
    
#Cria o modelo

model = Sequential()
model.add(Dense(units = 10, activation = 'relu', input_dim = lags))
model.add(Dense(units = 21, activation = 'relu'))
model.add(Dense(units = 1, activation = 'linear'))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

#Treina o modelo
model.fit(train_X, train_y, batch_size = 32, epochs = 100)
#score = model.score(train_X,train_y)
#print(score)

#Dados de teste
previsoes = model.predict(test_X)
previsoes = previsoes.reshape(-1, 1)
previsoes = sc.inverse_transform(previsoes)

#Dados de treino
previsoes_treino = model.predict(train_X)
previsoes_treino = previsoes_treino.reshape(-1, 1)
previsoes_treino = sc.inverse_transform(previsoes_treino)
# Out:
# Train on 131 samples
# Epoch 1/100
# 131/131 [==============================] - 1s 10ms/sample - loss: 0.2888 - mean_absolute_error: 0.2888
# Epoch 2/100
# 131/131 [==============================] - 0s 304us/sample - loss: 0.1813 - mean_absolute_error: 0.1813
# Epoch 3/100
# 131/131 [==============================] - 0s 349us/sample - loss: 0.1732 - mean_absolute_error: 0.1732
# Epoch 4/100
# 131/131 [==============================] - 0s 402us/sample - loss: 0.1723 - mean_absolute_error: 0.1723
# Epoch 5/100
# 131/131 [==============================] - 0s 337us/sample - loss: 0.1598 - mean_absolute_error: 0.1598
# Epoch 6/100
# 131/131 [==============================] - 0s 383us/sample - loss: 0.1552 - mean_absolute_error: 0.1552
# Epoch 7/100
# 131/131 [==============================] - 0s 358us/sample - loss: 0.1555 - mean_absolute_error: 0.1555
# Epoch 8/100
# 131/131 [==============================] - 0s 299us/sample - loss: 0.1512 - mean_absolute_error: 0.1512
# Epoch 9/100
# 131/131 [==============================] - 0s 384us/sample - loss: 0.1475 - mean_absolute_error: 0.1475
# Epoch 10/100
# 131/131 [==============================] - 0s 364us/sample - loss: 0.1498 - mean_absolute_error: 0.1498
# Epoch 11/100
# 131/131 [==============================] - 0s 434us/sample - loss: 0.1467 - mean_absolute_error: 0.1467
# Epoch 12/100
# 131/131 [==============================] - 0s 366us/sample - loss: 0.1416 - mean_absolute_error: 0.1416
# Epoch 13/100
# 131/131 [==============================] - 0s 370us/sample - loss: 0.1495 - mean_absolute_error: 0.1495
# Epoch 14/100
# 131/131 [==============================] - 0s 399us/sample - loss: 0.1514 - mean_absolute_error: 0.1514
# Epoch 15/100
# 131/131 [==============================] - 0s 466us/sample - loss: 0.1405 - mean_absolute_error: 0.1405
# Epoch 16/100
# 131/131 [==============================] - 0s 423us/sample - loss: 0.1442 - mean_absolute_error: 0.1442
# Epoch 17/100
# 131/131 [==============================] - 0s 392us/sample - loss: 0.1420 - mean_absolute_error: 0.1420
# Epoch 18/100
# 131/131 [==============================] - 0s 473us/sample - loss: 0.1349 - mean_absolute_error: 0.1349
# Epoch 19/100
# 131/131 [==============================] - ETA: 0s - loss: 0.1500 - mean_absolute_error: 0.150 - 0s 363us/sample - loss: 0.1364 - mean_absolute_error: 0.1364
# Epoch 20/100
# 131/131 [==============================] - 0s 257us/sample - loss: 0.1338 - mean_absolute_error: 0.1338
# Epoch 21/100
# 131/131 [==============================] - 0s 410us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 22/100
# 131/131 [==============================] - 0s 275us/sample - loss: 0.1331 - mean_absolute_error: 0.1331
# Epoch 23/100
# 131/131 [==============================] - 0s 395us/sample - loss: 0.1308 - mean_absolute_error: 0.1308
# Epoch 24/100
# 131/131 [==============================] - 0s 280us/sample - loss: 0.1307 - mean_absolute_error: 0.1307
# Epoch 25/100
# 131/131 [==============================] - 0s 416us/sample - loss: 0.1281 - mean_absolute_error: 0.1281
# Epoch 26/100
# 131/131 [==============================] - 0s 229us/sample - loss: 0.1277 - mean_absolute_error: 0.1277
# Epoch 27/100
# 131/131 [==============================] - 0s 378us/sample - loss: 0.1267 - mean_absolute_error: 0.1267
# Epoch 28/100
# 131/131 [==============================] - 0s 300us/sample - loss: 0.1268 - mean_absolute_error: 0.1268
# Epoch 29/100
# 131/131 [==============================] - 0s 457us/sample - loss: 0.1249 - mean_absolute_error: 0.1249
# Epoch 30/100
# 131/131 [==============================] - 0s 382us/sample - loss: 0.1256 - mean_absolute_error: 0.1256
# Epoch 31/100
# 131/131 [==============================] - ETA: 0s - loss: 0.1256 - mean_absolute_error: 0.125 - 0s 446us/sample - loss: 0.1246 - mean_absolute_error: 0.1246
# Epoch 32/100
# 131/131 [==============================] - 0s 414us/sample - loss: 0.1267 - mean_absolute_error: 0.1267
# Epoch 33/100
# 131/131 [==============================] - 0s 421us/sample - loss: 0.1253 - mean_absolute_error: 0.1253
# Epoch 34/100
# 131/131 [==============================] - 0s 419us/sample - loss: 0.1243 - mean_absolute_error: 0.1243
# Epoch 35/100
# 131/131 [==============================] - 0s 394us/sample - loss: 0.1228 - mean_absolute_error: 0.1228
# Epoch 36/100
# 131/131 [==============================] - 0s 422us/sample - loss: 0.1223 - mean_absolute_error: 0.1223
# Epoch 37/100
# 131/131 [==============================] - 0s 377us/sample - loss: 0.1232 - mean_absolute_error: 0.1232
# Epoch 38/100
# 131/131 [==============================] - 0s 331us/sample - loss: 0.1231 - mean_absolute_error: 0.1231
# Epoch 39/100
# 131/131 [==============================] - 0s 424us/sample - loss: 0.1216 - mean_absolute_error: 0.1216
# Epoch 40/100
# 131/131 [==============================] - 0s 395us/sample - loss: 0.1229 - mean_absolute_error: 0.1229
# Epoch 41/100
# 131/131 [==============================] - 0s 251us/sample - loss: 0.1231 - mean_absolute_error: 0.1231
# Epoch 42/100
# 131/131 [==============================] - 0s 421us/sample - loss: 0.1236 - mean_absolute_error: 0.1236
# Epoch 43/100
# 131/131 [==============================] - 0s 286us/sample - loss: 0.1218 - mean_absolute_error: 0.1218
# Epoch 44/100
# 131/131 [==============================] - 0s 371us/sample - loss: 0.1206 - mean_absolute_error: 0.1206
# Epoch 45/100
# 131/131 [==============================] - 0s 283us/sample - loss: 0.1198 - mean_absolute_error: 0.1198
# Epoch 46/100
# 131/131 [==============================] - 0s 342us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 47/100
# 131/131 [==============================] - 0s 320us/sample - loss: 0.1207 - mean_absolute_error: 0.1207
# Epoch 48/100
# 131/131 [==============================] - 0s 400us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 49/100
# 131/131 [==============================] - 0s 294us/sample - loss: 0.1190 - mean_absolute_error: 0.1190
# Epoch 50/100
# 131/131 [==============================] - 0s 346us/sample - loss: 0.1180 - mean_absolute_error: 0.1180
# Epoch 51/100
# 131/131 [==============================] - 0s 300us/sample - loss: 0.1187 - mean_absolute_error: 0.1187
# Epoch 52/100
# 131/131 [==============================] - 0s 423us/sample - loss: 0.1179 - mean_absolute_error: 0.1179
# Epoch 53/100
# 131/131 [==============================] - 0s 266us/sample - loss: 0.1179 - mean_absolute_error: 0.1179
# Epoch 54/100
# 131/131 [==============================] - 0s 254us/sample - loss: 0.1185 - mean_absolute_error: 0.1185
# Epoch 55/100
# 131/131 [==============================] - 0s 278us/sample - loss: 0.1173 - mean_absolute_error: 0.1173
# Epoch 56/100
# 131/131 [==============================] - 0s 341us/sample - loss: 0.1211 - mean_absolute_error: 0.1211
# Epoch 57/100
# 131/131 [==============================] - 0s 393us/sample - loss: 0.1179 - mean_absolute_error: 0.1179
# Epoch 58/100
# 131/131 [==============================] - 0s 287us/sample - loss: 0.1185 - mean_absolute_error: 0.1185
# Epoch 59/100
# 131/131 [==============================] - 0s 269us/sample - loss: 0.1185 - mean_absolute_error: 0.1185
# Epoch 60/100
# 131/131 [==============================] - 0s 449us/sample - loss: 0.1166 - mean_absolute_error: 0.1166
# Epoch 61/100
# 131/131 [==============================] - 0s 211us/sample - loss: 0.1180 - mean_absolute_error: 0.1180
# Epoch 62/100
# 131/131 [==============================] - 0s 437us/sample - loss: 0.1177 - mean_absolute_error: 0.1177
# Epoch 63/100
# 131/131 [==============================] - 0s 258us/sample - loss: 0.1170 - mean_absolute_error: 0.1170
# Epoch 64/100
# 131/131 [==============================] - 0s 362us/sample - loss: 0.1160 - mean_absolute_error: 0.1160
# Epoch 65/100
# 131/131 [==============================] - 0s 244us/sample - loss: 0.1167 - mean_absolute_error: 0.1167
# Epoch 66/100
# 131/131 [==============================] - 0s 383us/sample - loss: 0.1157 - mean_absolute_error: 0.1157
# Epoch 67/100
# 131/131 [==============================] - 0s 259us/sample - loss: 0.1153 - mean_absolute_error: 0.1153
# Epoch 68/100
# 131/131 [==============================] - 0s 400us/sample - loss: 0.1166 - mean_absolute_error: 0.1166
# Epoch 69/100
# 131/131 [==============================] - 0s 275us/sample - loss: 0.1148 - mean_absolute_error: 0.1148
# Epoch 70/100
# 131/131 [==============================] - 0s 377us/sample - loss: 0.1171 - mean_absolute_error: 0.1171
# Epoch 71/100
# 131/131 [==============================] - ETA: 0s - loss: 0.1117 - mean_absolute_error: 0.111 - 0s 258us/sample - loss: 0.1164 - mean_absolute_error: 0.1164
# Epoch 72/100
# 131/131 [==============================] - 0s 384us/sample - loss: 0.1138 - mean_absolute_error: 0.1138
# Epoch 73/100
# 131/131 [==============================] - 0s 292us/sample - loss: 0.1142 - mean_absolute_error: 0.1142
# Epoch 74/100
# 131/131 [==============================] - 0s 337us/sample - loss: 0.1142 - mean_absolute_error: 0.1142
# Epoch 75/100
# 131/131 [==============================] - 0s 258us/sample - loss: 0.1166 - mean_absolute_error: 0.1166
# Epoch 76/100
# 131/131 [==============================] - 0s 354us/sample - loss: 0.1153 - mean_absolute_error: 0.1153
# Epoch 77/100
# 131/131 [==============================] - 0s 306us/sample - loss: 0.1128 - mean_absolute_error: 0.1128
# Epoch 78/100
# 131/131 [==============================] - 0s 401us/sample - loss: 0.1137 - mean_absolute_error: 0.1137
# Epoch 79/100
# 131/131 [==============================] - 0s 363us/sample - loss: 0.1132 - mean_absolute_error: 0.1132
# Epoch 80/100
# 131/131 [==============================] - 0s 322us/sample - loss: 0.1135 - mean_absolute_error: 0.1135
# Epoch 81/100
# 131/131 [==============================] - 0s 372us/sample - loss: 0.1161 - mean_absolute_error: 0.1161
# Epoch 82/100
# 131/131 [==============================] - 0s 264us/sample - loss: 0.1140 - mean_absolute_error: 0.1140
# Epoch 83/100
# 131/131 [==============================] - 0s 405us/sample - loss: 0.1114 - mean_absolute_error: 0.1114
# Epoch 84/100
# 131/131 [==============================] - 0s 290us/sample - loss: 0.1142 - mean_absolute_error: 0.1142
# Epoch 85/100
# 131/131 [==============================] - 0s 411us/sample - loss: 0.1154 - mean_absolute_error: 0.1154
# Epoch 86/100
# 131/131 [==============================] - 0s 284us/sample - loss: 0.1115 - mean_absolute_error: 0.1115
# Epoch 87/100
# 131/131 [==============================] - 0s 339us/sample - loss: 0.1115 - mean_absolute_error: 0.1115
# Epoch 88/100
# 131/131 [==============================] - 0s 361us/sample - loss: 0.1132 - mean_absolute_error: 0.1132
# Epoch 89/100
# 131/131 [==============================] - 0s 325us/sample - loss: 0.1105 - mean_absolute_error: 0.1105
# Epoch 90/100
# 131/131 [==============================] - 0s 371us/sample - loss: 0.1152 - mean_absolute_error: 0.1152
# Epoch 91/100
# 131/131 [==============================] - 0s 390us/sample - loss: 0.1139 - mean_absolute_error: 0.1139
# Epoch 92/100
# 131/131 [==============================] - 0s 209us/sample - loss: 0.1142 - mean_absolute_error: 0.1142
# Epoch 93/100
# 131/131 [==============================] - 0s 303us/sample - loss: 0.1140 - mean_absolute_error: 0.1140
# Epoch 94/100
# 131/131 [==============================] - ETA: 0s - loss: 0.1143 - mean_absolute_error: 0.114 - 0s 320us/sample - loss: 0.1113 - mean_absolute_error: 0.1113
# Epoch 95/100
# 131/131 [==============================] - 0s 254us/sample - loss: 0.1106 - mean_absolute_error: 0.1106
# Epoch 96/100
# 131/131 [==============================] - 0s 394us/sample - loss: 0.1095 - mean_absolute_error: 0.1095
# Epoch 97/100
# 131/131 [==============================] - ETA: 0s - loss: 0.0889 - mean_absolute_error: 0.088 - 0s 260us/sample - loss: 0.1122 - mean_absolute_error: 0.1122
# Epoch 98/100
# 131/131 [==============================] - 0s 336us/sample - loss: 0.1101 - mean_absolute_error: 0.1101
# Epoch 99/100
# 131/131 [==============================] - 0s 446us/sample - loss: 0.1128 - mean_absolute_error: 0.1128
# Epoch 100/100
# 131/131 [==============================] - 0s 294us/sample - loss: 0.1124 - mean_absolute_error: 0.1124

# %%
#Preparação para plotagem
train_predict_plot = np.empty_like(data)
train_predict_plot[:, :] = np.nan
train_predict_plot[lags: len(previsoes_treino) + lags, :] = previsoes_treino
train_predict_plot.shape
    
test_predict_plot = np.empty_like(data)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(previsoes_treino)+lags:len(data), :] = previsoes

#Plotagem do gráfico
plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(train_predict_plot, color = 'green', label = 'Previsão de treino')
plt.plot(test_predict_plot, color = '#ff0066', label = 'Previsão de teste')
plt.title('Predição do pH com lag = 25%')
plt.xlabel('Bimestre')
plt.ylabel('Valor pH')
plt.legend()
plt.grid()
plt.show()
    
#Calculo do erro da previsão
#mape(previsoes.mean(),test.mean())
test = sc.inverse_transform(test)
treino = sc.inverse_transform(train[lags: len(previsoes_treino) + lags, :])

print('Resultados com lag', lags)
print('\n')
print('MAPE TREINO:',round(mape(previsoes_treino,treino)[0],2),'%')
print('RMSE TREINO:',round(rmse(previsoes_treino,treino),2))
print('R TREINO:',round(r2(previsoes_treino,treino),2))
print('\n')
print('MAPE TESTE:',round(mape(previsoes,test)[0],2),'%')
print('RMSE TESTE:',round(rmse(previsoes,test),2))
print('R TESTE:',round(r2(previsoes,test),2))
print('\n')
# Out:
# Resultados com lag 43
#
#
# MAPE TREINO: 1.76 %
# RMSE TREINO: 0.13
# R TREINO: 0.37
#
#
# MAPE TESTE: 1.54 %
# RMSE TESTE: 0.19
# R TESTE: 0.03

# %%
# Out:
# (248, 1)

# %%
# Out:
# 174
