# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Dropout
from tensorflow.keras.callbacks import EarlyStopping

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (12,10)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
df_ugrhi06 = pd.read_csv(str_files + "cetesb_concatenado06semoutliers.csv",encoding='utf-8',sep=',')

#Carrega os dados do arquivo .csv
df_ugrhi10 = pd.read_csv(str_files + "cetesb_concatenado10semoutliers.csv",encoding='utf-8',sep=',')
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
print('---- Tamanho dos conjuntos originais ----')
print('ugrhi06:',len(df_ugrhi06))
print('ugrhi10:',len(df_ugrhi10))

#Seleciona os dados equivalente ao tamanho da URGHI10
df_ugrhi06 = df_ugrhi06.iloc[0:len(df_ugrhi10)]

#Seleciona os valores da coluna ph da URGHI06, na qual será utilizado para a normalização dos dados quando apresentar o gráfico
#train_previsao = ugrhi06['ph'].values
#train_previsao = train_previsao.reshape(len(train_previsao),1)

print('---- Conjunto de dados y igualado ao tamanho de dados do conjunto X ----')
print('ugrhi06:',len(df_ugrhi06))
print('ugrhi10:',len(df_ugrhi10))

# %%
def seleciona_colunas(trainingd,ug):
    
    if (ug == 6):        
        fph      = trainingd.iloc[:,0:1].values
        
        frame_completo = pd.DataFrame(list(zip(fph)),columns =['ph']) 
    else:
        fph      = trainingd.iloc[:,1:2].values
            
        frame_completo = pd.DataFrame(list(zip(fph)),columns =['ph'])
        
    
    return frame_completo

def seleciona_colunas_od(trainingd,ug):
    
    if (ug == 6):
        
        fod      = trainingd.iloc[:,4:5].values
        
        frame_completo = pd.DataFrame(list(zip(fod)),columns =['od']) 
    else:
        fod      = trainingd.iloc[:,5:6].values
            
        frame_completo = pd.DataFrame(list(zip(fod)),columns =['od'])
        
    
    return frame_completo  

def pegar_dados_coluna_predita_train_test(trainingd,percent,index_coluna):
    data = trainingd.iloc[:,:].values
    train = trainingd.iloc[0:int(len(data)*percent),:].values  
    train_previsao = trainingd.iloc[0:int(len(data)*percent),index_coluna:index_coluna+1].values
    test = trainingd.iloc[len(train):,index_coluna:index_coluna+1].values
    
    return train,train_previsao, test

#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
def normalizacao(train,test):
    sc = MinMaxScaler()
    testd = test
    train = sc.fit_transform(train)
    test = sc.fit_transform(test)    
    return train,test,testd

#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
#cy = coluna que será predita
def prepara_dados(dados,lags,cy):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i,:])
        y.append(dados[i, cy])
       
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    '''  
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        
        print(real)
        mape = mape_sum/len(real)
    '''
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_true,y_pred)
    return rscore

def rquadrado(y_pred,y_true):
    #Soma Total dos Quadrados (STQ): mostra a variação de y em torno da própria média. 
    #É o somatório das diferenças entre o valor alvo real e sua média elevado ao quadrado.
    y_traco = np.mean(y_true)
    
    print('media y_true:', y_traco)
        
    stq = 0
    
    for s in y_true:
        a = s - y_traco
        st = a * a
        stq = stq + st
    
    print('Soma Total dos Quadrados (STQ):', stq[0])
    
    #Soma dos Quadrados dos Resíduos (SQU): variação de Y que não é explicada pelo modelo elaborado. 
    #É o somatório das diferenças entre o valor predito e o valor real elevados ao quadrado.
    squ = 0
    
    y_traco = np.mean(y_pred)
    print('media y_pred:', y_traco)
    
    for n in range(len(y_true)):
        a = y_true[n] - y_pred[n]
        st = a * a
        squ = squ + st
        
    print('Soma dos Quadrados dos Resíduos (SQU):',squ[0])
    print('\n')
    print('Fórmula do R²')
    print('\n')
    print('sqr = stq - squ')
    sqr = stq[0] - squ[0]
    print('R² = sqr/stq')
    sqr = sqr/stq[0]
    print('\n')
    return sqr

def correlacao_determinacao(dtframe,tipo):
    
    if (tipo == 0): #Treino
        resultado = dtframe.corr().previsao_treino.values[1]**2
    else: #teste
        resultado = dtframe.corr().previsao_teste.values[1]**2
    
    return resultado

def ajusta_array(array):
    lista = []
    
    for i in range(len(array)):
        lista.append(array[i][0])
        
    #print('ajusta array:',lista)
        
    return lista

def ajusta_lista(array):
    lista = []
    
    for i in range(len(array)):
        lista.append(array[i][0])
        
    #print('ajusta array:',lista)
        
    return lista

# %% [markdown]
# # Utilizando a função de ativação Linear

# %%
ugrhi06 = seleciona_colunas(df_ugrhi06,6)
ugrhi10 = seleciona_colunas(df_ugrhi10,10)
df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

print(ugrhi06)
print(ugrhi10)

#lags = (3,5,7) 
#for l in range(1, 9, 2):
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train06,train_previsao06, test06 = pegar_dados_coluna_predita_train_test(ugrhi06,0.70,0) 
    train10,train_previsao10, test10 = pegar_dados_coluna_predita_train_test(ugrhi10,0.70,0) 
    
    #normalização dos dados
    train06,test06,testd06 = normalizacao(train06,test06)
    train10,test10,testd10 = normalizacao(train10,test10)
    
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao06)
    
    #Prepara os dados de treinamento -ugrhi06
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X06, train_y06 = prepara_dados(train06, lags,0)
        
    #Prepara os dados de teste
    entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
    entradas06 = sc.fit_transform(entradas06)   
    
    test_X06 = []
    for i in range(lags, lags+len(test06)):
        test_X06.append(entradas06[i-lags:i, 0:1])
    test_X06 = np.array(test_X06)
          
    #Prepara os dados de treinamento -ugrhi10
    #Aqui vamos pegar test_X10.
    train_X10, train_y10 = prepara_dados(train10, lags,0)
        
    #Prepara os dados de teste
    entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
    entradas10 = sc.fit_transform(entradas10)   
    
    test_X10 = []
    for i in range(lags, lags+len(test10)):
        test_X10.append(entradas10[i-lags:i, 0:1])
    test_X10 = np.array(test_X10)
    
    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X06.shape[1], 3)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'linear'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X06, train_y06, validation_data=(test_X10, test10), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Treina o modelo
    #model.fit(train_X06, train_y06, batch_size = 32, epochs = 100)
    
    #Dados de teste
    previsoes = model.predict(test_X10)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
    
    print('Teste - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(testd10,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
    
    #Dados de treino
    previsoes_treino = model.predict(train_X10)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao10[lags: len(previsoes_treino) + lags, :]
    observado_test = testd10
    
    observado_treino = train_previsao10  
    
    print('Treinamento - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(train_previsao10,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
df_resultados.describe()
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
ugrhi06 = seleciona_colunas_od(df_ugrhi06,6)
ugrhi10 = seleciona_colunas_od(df_ugrhi10,10)
df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

print(ugrhi06)
print(ugrhi10)

#lags = (3,5,7) 
#for l in range(1, 9, 2):
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train06,train_previsao06, test06 = pegar_dados_coluna_predita_train_test(ugrhi06,0.70,0) 
    train10,train_previsao10, test10 = pegar_dados_coluna_predita_train_test(ugrhi10,0.70,0) 
    
    #normalização dos dados
    train06,test06,testd06 = normalizacao(train06,test06)
    train10,test10,testd10 = normalizacao(train10,test10)
    
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao06)
    
    #Prepara os dados de treinamento -ugrhi06
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X06, train_y06 = prepara_dados(train06, lags,0)
        
    #Prepara os dados de teste
    entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
    entradas06 = sc.fit_transform(entradas06)   
    
    test_X06 = []
    for i in range(lags, lags+len(test06)):
        test_X06.append(entradas06[i-lags:i, 0:1])
    test_X06 = np.array(test_X06)
          
    #Prepara os dados de treinamento -ugrhi10
    #Aqui vamos pegar test_X10.
    train_X10, train_y10 = prepara_dados(train10, lags,0)
        
    #Prepara os dados de teste
    entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
    entradas10 = sc.fit_transform(entradas10)   
    
    test_X10 = []
    for i in range(lags, lags+len(test10)):
        test_X10.append(entradas10[i-lags:i, 0:1])
    test_X10 = np.array(test_X10)
    
    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X06.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'linear'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X06, train_y06, validation_data=(test_X10, test10), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Treina o modelo
    #model.fit(train_X06, train_y06, batch_size = 32, epochs = 100)
    
    #Dados de teste
    previsoes = model.predict(test_X10)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
    
    print('Teste - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(testd10,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
    
    #Dados de treino
    previsoes_treino = model.predict(train_X10)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao10[lags: len(previsoes_treino) + lags, :]
    observado_test = testd10
    
    observado_treino = train_previsao10  
    
    print('Treinamento - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(train_previsao10,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
df_resultados.describe()
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %% [markdown]
# # Utilizando função de ativação Relu

# %%
ugrhi06 = seleciona_colunas(df_ugrhi06,6)
ugrhi10 = seleciona_colunas(df_ugrhi10,10)
df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

print(ugrhi06)
print(ugrhi10)

#lags = (3,5,7) 
#for l in range(1, 9, 2):
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train06,train_previsao06, test06 = pegar_dados_coluna_predita_train_test(ugrhi06,0.70,0) 
    train10,train_previsao10, test10 = pegar_dados_coluna_predita_train_test(ugrhi10,0.70,0) 
    
    #normalização dos dados
    train06,test06,testd06 = normalizacao(train06,test06)
    train10,test10,testd10 = normalizacao(train10,test10)
    
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao06)
    
    #Prepara os dados de treinamento -ugrhi06
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X06, train_y06 = prepara_dados(train06, lags,0)
        
    #Prepara os dados de teste
    entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
    entradas06 = sc.fit_transform(entradas06)   
    
    test_X06 = []
    for i in range(lags, lags+len(test06)):
        test_X06.append(entradas06[i-lags:i, 0:1])
    test_X06 = np.array(test_X06)
          
    #Prepara os dados de treinamento -ugrhi10
    #Aqui vamos pegar test_X10.
    train_X10, train_y10 = prepara_dados(train10, lags,0)
        
    #Prepara os dados de teste
    entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
    entradas10 = sc.fit_transform(entradas10)   
    
    test_X10 = []
    for i in range(lags, lags+len(test10)):
        test_X10.append(entradas10[i-lags:i, 0:1])
    test_X10 = np.array(test_X10)
    
    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X06.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X06, train_y06, validation_data=(test_X10, test10), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Treina o modelo
    #model.fit(train_X06, train_y06, batch_size = 32, epochs = 100)
    
    #Dados de teste
    previsoes = model.predict(test_X10)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
    
    print('Teste - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(testd10,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
    
    #Dados de treino
    previsoes_treino = model.predict(train_X10)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao10[lags: len(previsoes_treino) + lags, :]
    observado_test = testd10
    
    observado_treino = train_previsao10  
    
    print('Treinamento - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(train_previsao10,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)

df_resultados.describe()

# %%
ugrhi06 = seleciona_colunas_od(df_ugrhi06,6)
ugrhi10 = seleciona_colunas_od(df_ugrhi10,10)
df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

print(ugrhi06)
print(ugrhi10)

#lags = (3,5,7) 
#for l in range(1, 9, 2):
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train06,train_previsao06, test06 = pegar_dados_coluna_predita_train_test(ugrhi06,0.70,0) 
    train10,train_previsao10, test10 = pegar_dados_coluna_predita_train_test(ugrhi10,0.70,0) 
    
    #normalização dos dados
    train06,test06,testd06 = normalizacao(train06,test06)
    train10,test10,testd10 = normalizacao(train10,test10)
    
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao06)
    
    #Prepara os dados de treinamento -ugrhi06
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X06, train_y06 = prepara_dados(train06, lags,0)
        
    #Prepara os dados de teste
    entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
    entradas06 = sc.fit_transform(entradas06)   
    
    test_X06 = []
    for i in range(lags, lags+len(test06)):
        test_X06.append(entradas06[i-lags:i, 0:1])
    test_X06 = np.array(test_X06)
          
    #Prepara os dados de treinamento -ugrhi10
    #Aqui vamos pegar test_X10.
    train_X10, train_y10 = prepara_dados(train10, lags,0)
        
    #Prepara os dados de teste
    entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
    entradas10 = sc.fit_transform(entradas10)   
    
    test_X10 = []
    for i in range(lags, lags+len(test10)):
        test_X10.append(entradas10[i-lags:i, 0:1])
    test_X10 = np.array(test_X10)
    
    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X06.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X06, train_y06, validation_data=(test_X10, test10), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Treina o modelo
    #model.fit(train_X06, train_y06, batch_size = 32, epochs = 100)
    
    #Dados de teste
    previsoes = model.predict(test_X10)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
    
    print('Teste - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(testd10,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
    
    #Dados de treino
    previsoes_treino = model.predict(train_X10)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao10[lags: len(previsoes_treino) + lags, :]
    observado_test = testd10
    
    observado_treino = train_previsao10  
    
    print('Treinamento - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(train_previsao10,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)

df_resultados.describe()

# %% [markdown]
# # Utilizando a função de ativação Sigmoid

# %%
ugrhi06 = seleciona_colunas(df_ugrhi06,6)
ugrhi10 = seleciona_colunas(df_ugrhi10,10)
df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

print(ugrhi06)
print(ugrhi10)

#lags = (3,5,7) 
#for l in range(1, 9, 2):
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train06,train_previsao06, test06 = pegar_dados_coluna_predita_train_test(ugrhi06,0.70,0) 
    train10,train_previsao10, test10 = pegar_dados_coluna_predita_train_test(ugrhi10,0.70,0) 
    
    #normalização dos dados
    train06,test06,testd06 = normalizacao(train06,test06)
    train10,test10,testd10 = normalizacao(train10,test10)
    
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao06)
    
    #Prepara os dados de treinamento -ugrhi06
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X06, train_y06 = prepara_dados(train06, lags,0)
        
    #Prepara os dados de teste
    entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
    entradas06 = sc.fit_transform(entradas06)   
    
    test_X06 = []
    for i in range(lags, lags+len(test06)):
        test_X06.append(entradas06[i-lags:i, 0:1])
    test_X06 = np.array(test_X06)
          
    #Prepara os dados de treinamento -ugrhi10
    #Aqui vamos pegar test_X10.
    train_X10, train_y10 = prepara_dados(train10, lags,0)
        
    #Prepara os dados de teste
    entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
    entradas10 = sc.fit_transform(entradas10)   
    
    test_X10 = []
    for i in range(lags, lags+len(test10)):
        test_X10.append(entradas10[i-lags:i, 0:1])
    test_X10 = np.array(test_X10)
    
    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X06.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X06, train_y06, validation_data=(test_X10, test10), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Treina o modelo
    #model.fit(train_X06, train_y06, batch_size = 32, epochs = 100)
    
    #Dados de teste
    previsoes = model.predict(test_X10)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
    
    print('Teste - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(testd10,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
    
    #Dados de treino
    previsoes_treino = model.predict(train_X10)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao10[lags: len(previsoes_treino) + lags, :]
    observado_test = testd10
    
    observado_treino = train_previsao10  
    
    print('Treinamento - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(train_previsao10,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
df_resultados.describe()
# Out:
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [251 rows x 1 columns]

# %%
ugrhi06 = seleciona_colunas_od(df_ugrhi06,6)
ugrhi10 = seleciona_colunas_od(df_ugrhi10,10)
df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

print(ugrhi06)
print(ugrhi10)

#lags = (3,5,7) 
#for l in range(1, 9, 2):
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train06,train_previsao06, test06 = pegar_dados_coluna_predita_train_test(ugrhi06,0.70,0) 
    train10,train_previsao10, test10 = pegar_dados_coluna_predita_train_test(ugrhi10,0.70,0) 
    
    #normalização dos dados
    train06,test06,testd06 = normalizacao(train06,test06)
    train10,test10,testd10 = normalizacao(train10,test10)
    
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao06)
    
    #Prepara os dados de treinamento -ugrhi06
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X06, train_y06 = prepara_dados(train06, lags,0)
        
    #Prepara os dados de teste
    entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
    entradas06 = sc.fit_transform(entradas06)   
    
    test_X06 = []
    for i in range(lags, lags+len(test06)):
        test_X06.append(entradas06[i-lags:i, 0:1])
    test_X06 = np.array(test_X06)
          
    #Prepara os dados de treinamento -ugrhi10
    #Aqui vamos pegar test_X10.
    train_X10, train_y10 = prepara_dados(train10, lags,0)
        
    #Prepara os dados de teste
    entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
    entradas10 = sc.fit_transform(entradas10)   
    
    test_X10 = []
    for i in range(lags, lags+len(test10)):
        test_X10.append(entradas10[i-lags:i, 0:1])
    test_X10 = np.array(test_X10)
    
    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X06.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X06, train_y06, validation_data=(test_X10, test10), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Treina o modelo
    #model.fit(train_X06, train_y06, batch_size = 32, epochs = 100)
    
    #Dados de teste
    previsoes = model.predict(test_X10)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
    
    print('Teste - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(testd10,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
    
    #Dados de treino
    previsoes_treino = model.predict(train_X10)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao10[lags: len(previsoes_treino) + lags, :]
    observado_test = testd10
    
    observado_treino = train_previsao10  
    
    print('Treinamento - Gráficos com lag', l)
    '''
    #Plotagem do gráfico
    plt.plot(train_previsao10,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    '''
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
df_resultados.describe()

# %%
for field in trainingd.columns:
    print(field, 'NaN:', trainingd[field].isnull().sum())
# Out:
# valor NaN: 2

# %%
trainingd = trainingd.dropna(axis=0,how='any')

# %%
for field in trainingd.columns:
    print(field, 'NaN:', trainingd[field].isnull().sum())
trainingd
# Out:
# valor NaN: 0
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [249 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < inferior.valor)]

outlier
# Out:
# primeiro_quartil: valor    6.583333
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.002667
# Name: 0.75, dtype: float64
# fig: valor    0.419333
# dtype: float64
# Inferior: valor    5.954333
# dtype: float64
# Superior: valor    7.631667
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                 valor
# data_coleta
# 1979-11-30   5.916667
# 1985-03-31   5.883333

# %%
trainingd
# Out:
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [249 rows x 1 columns]

# %%
#Remove a última linha do dataframe
trainingd = trainingd.drop(trainingd[trainingd.index == '2019-09-30'].index)

# %%
trainingd.describe()
# Out:
#             valor
# count  248.000000
# mean     6.793328
# std      0.294764
# min      5.883333
# 25%      6.581944
# 50%      6.838095
# 75%      7.001821
# max      7.405000

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingds.valor < inferior.valor] = 6.79

ugrhi06 = trainingd

outlier = trainingd[(trainingd.valor < inferior.valor)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
#Dados completo.
dataugrhi10 = ugrhi10.iloc[:,:].values
dataugrhi06 = ugrhi06.iloc[:,:].values
#treino (70%)
train10 = ugrhi10.iloc[0:int(len(dataugrhi10)*0.70),:].values  
train06 = ugrhi06.iloc[0:int(len(dataugrhi06)*0.70),:].values

#teste (30%)
test10 = ugrhi10.iloc[len(train10):,:].values 
test06 = ugrhi06.iloc[len(train06):,:].values

teste_observado = test06

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
sc = MinMaxScaler()
train10 = sc.fit_transform(train10)
#train06 = sc.fit_transform(train06)
test10 = sc.fit_transform(test10)
test06 = sc.fit_transform(test06)

# %%
def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_true,y_pred)
    return rscore

# %%
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

# %%
for l in range(3, 9, 2):
    
    lags = l
    #Prepara os dados de treinamento
    X_train10, y_train10 = prepara_dados(train10, lags)

    X_train10 = np.reshape(X_train10, (X_train10.shape[0], X_train10.shape[1], 1))
    
    #Prepara os dados de teste
    entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
    entradas10 = entradas10.reshape(-1, 1)
    entradas10 = sc.fit_transform(entradas10)

    X_test10 = []
    for i in range(lags, lags+len(test10)):
        X_test10.append(entradas10[i-lags:i, 0])
    X_test10 = np.array(X_test10)
    X_test10 = np.reshape(X_test10, (X_test10.shape[0], X_test10.shape[1], 1))

    #Prepara os dados de teste06
    entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
    entradas06 = entradas06.reshape(-1, 1)
    entradas06 = sc.fit_transform(entradas06)

    X_test06 = []
    for i in range(lags, lags+len(test06)):
        X_test06.append(entradas06[i-lags:i, 0])
    X_test06 = np.array(X_test06)
    X_test06 = np.reshape(X_test06, (X_test06.shape[0], X_test06.shape[1], 1))

    #Cria o modelo

    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (X_train10.shape[1], 1)))
    model.add(Dense(10, activation = 'linear'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'linear'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    #Treina o modelo
    model.fit(X_train10, y_train10, batch_size = 32, epochs = 100)

    #Predição dos dados de teste
    y_pred10 = model.predict(X_test06)
    y_pred10 = y_pred10.reshape(-1, 1)
    y_pred10 = sc.inverse_transform(y_pred10)
   
    #Predição dos dados de treinamento
    y_pred10t = model.predict(X_train10)
    y_pred10t = y_pred10t.reshape(-1, 1)
    y_pred10t = sc.inverse_transform(y_pred10t)
    
    y_train10 = y_train10.reshape(-1, 1)
    treino = sc.inverse_transform(y_train10)
    
    #Plotagem do gráfico
    print('Gráficos com lag', l)
    plt.plot(y_pred10, color = 'green', label = 'Observado UGRHI06')
    plt.plot(teste_observado, color = '#ff0066', label = 'Previsão UGRHI10')
    plt.title('Predição do pH com lag igual a ' + str(l) + ' bimestres')
    plt.xlabel('Bimestre')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    if l == 3:
        observado_treino_a = treino
        previsoes_treino_a = y_pred10t
        previsoes_a        = y_pred10
        
        mape_treino_a        = round(mape(y_pred10t,treino)[0],4)
        rmse_treino_a        = round(rmse(y_pred10t,treino),4)
        r_treino_a           = round(r2(y_pred10t,treino),4)
        
        mape_teste_a        = round(mape(y_pred10,teste_observado)[0],4)
        rmse_teste_a        = round(rmse(y_pred10,teste_observado),4)
        r_teste_a           = round(r2(y_pred10,teste_observado),4)
        
    elif l == 5:
        observado_treino_b = treino
        previsoes_treino_b = y_pred10t
        previsoes_b        = y_pred10
        
        mape_treino_b        = round(mape(y_pred10t,treino)[0],4)
        rmse_treino_b        = round(rmse(y_pred10t,treino),4)
        r_treino_b           = round(r2(y_pred10t,treino),4)
        
        mape_teste_b        = round(mape(y_pred10,teste_observado)[0],4)
        rmse_teste_b        = round(rmse(y_pred10,teste_observado),4)
        r_teste_b           = round(r2(y_pred10,teste_observado),4)
        
    else:
        observado_treino_c = treino
        previsoes_treino_c = y_pred10t
        previsoes_c        = y_pred10
        
        mape_treino_c        = round(mape(y_pred10t,treino)[0],4)
        rmse_treino_c        = round(rmse(y_pred10t,treino),4)
        r_treino_c           = round(r2(y_pred10t,treino),4)
        
        mape_teste_c        = round(mape(y_pred10,teste_observado)[0],4)
        rmse_teste_c        = round(rmse(y_pred10,teste_observado),4)
        r_teste_c           = round(r2(y_pred10,teste_observado),4)
        
#Plotagem do gráfico
plt.plot(observado_treino_a, color = '#006699', alpha=0.7, label = 'Observado pH lag 3')
plt.plot(previsoes_treino_a, color = 'red',linestyle = '--', label = 'Predição pH lag 3')
plt.plot(observado_treino_b, color = 'indigo', alpha=0.5, label = 'Observado pH lag 5')
plt.plot(previsoes_treino_b, color = 'black',linestyle = '--', label = 'Predição pH lag 5')
plt.plot(observado_treino_c, color = 'green', alpha=0.3, label = 'Observado pH lag 7')
plt.plot(previsoes_treino_c, color = 'orange',linestyle = '--', label = 'Predição pH lag 7')
plt.title('Treino')
plt.xlabel('Tempo (Bimestre)')
plt.ylabel('Valor pH')
plt.legend()
plt.show()

#Plotagem do gráfico
#plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(teste_observado, color = '#006699', alpha=0.7, label = 'Observado pH')
plt.plot(previsoes_a, color = 'red',linestyle = '--', label = 'Predição pH lag 3')
plt.plot(previsoes_b, color = 'black',linestyle = '--', label = 'Predição pH lag 5')
plt.plot(previsoes_c, color = 'orange',linestyle = '--', label = 'Predição pH lag 7')
plt.title('Teste')
plt.xlabel('Tempo (Bimestre)')
plt.ylabel('Valor pH')
plt.legend()
plt.show()


# intialise data of lists.
data_treino = {'Lags':[3, 5, 7],
        'MAPE':[mape_treino_a, mape_treino_b, mape_treino_c],
        'RMSE':[rmse_treino_a, rmse_treino_b, rmse_treino_c],
        'R²':[r_treino_a, r_treino_b, r_treino_c],
        'TIPO':['TREINO', 'TREINO', 'TREINO']}

# intialise data of lists.
data_teste = {'Lags':[3, 5, 7],
        'MAPE':[mape_teste_a, mape_teste_b, mape_teste_c],
        'RMSE':[rmse_teste_a, rmse_teste_b, rmse_teste_c],
        'R²':[r_teste_a, r_teste_b, r_teste_c],
        'TIPO':['TESTE', 'TESTE', 'TESTE']}
 
# Create DataFrame
df_resultados_treino = pd.DataFrame(data_treino)
df_resultados_teste = pd.DataFrame(data_teste)
# Out:
# Train on 170 samples
# Epoch 1/100
# 170/170 [==============================] - 2s 9ms/sample - loss: 0.4682 - mean_absolute_error: 0.4682
# Epoch 2/100
# 170/170 [==============================] - 0s 267us/sample - loss: 0.4196 - mean_absolute_error: 0.4196
# Epoch 3/100
# 170/170 [==============================] - 0s 279us/sample - loss: 0.3732 - mean_absolute_error: 0.3732
# Epoch 4/100
# 170/170 [==============================] - 0s 298us/sample - loss: 0.3302 - mean_absolute_error: 0.3302
# Epoch 5/100
# 170/170 [==============================] - 0s 316us/sample - loss: 0.2747 - mean_absolute_error: 0.2747
# Epoch 6/100
# 170/170 [==============================] - 0s 298us/sample - loss: 0.2346 - mean_absolute_error: 0.2346
# Epoch 7/100
# 170/170 [==============================] - 0s 263us/sample - loss: 0.1986 - mean_absolute_error: 0.1986
# Epoch 8/100
# 170/170 [==============================] - 0s 352us/sample - loss: 0.1625 - mean_absolute_error: 0.1625
# Epoch 9/100
# 170/170 [==============================] - 0s 331us/sample - loss: 0.1535 - mean_absolute_error: 0.1535
# Epoch 10/100
# 170/170 [==============================] - 0s 274us/sample - loss: 0.1463 - mean_absolute_error: 0.1463
# Epoch 11/100
# 170/170 [==============================] - 0s 319us/sample - loss: 0.1432 - mean_absolute_error: 0.1432
# Epoch 12/100
# 170/170 [==============================] - 0s 328us/sample - loss: 0.1526 - mean_absolute_error: 0.1526
# Epoch 13/100
# 170/170 [==============================] - 0s 366us/sample - loss: 0.1570 - mean_absolute_error: 0.1570
# Epoch 14/100
# 170/170 [==============================] - 0s 310us/sample - loss: 0.1568 - mean_absolute_error: 0.1568
# Epoch 15/100
# 170/170 [==============================] - 0s 281us/sample - loss: 0.1545 - mean_absolute_error: 0.1545
# Epoch 16/100
# 170/170 [==============================] - 0s 291us/sample - loss: 0.1561 - mean_absolute_error: 0.1561
# Epoch 17/100
# 170/170 [==============================] - 0s 341us/sample - loss: 0.1565 - mean_absolute_error: 0.1565
# Epoch 18/100
# 170/170 [==============================] - 0s 224us/sample - loss: 0.1426 - mean_absolute_error: 0.1426
# Epoch 19/100
# 170/170 [==============================] - 0s 255us/sample - loss: 0.1613 - mean_absolute_error: 0.1613
# Epoch 20/100
# 170/170 [==============================] - 0s 212us/sample - loss: 0.1549 - mean_absolute_error: 0.1549
# Epoch 21/100
# 170/170 [==============================] - 0s 296us/sample - loss: 0.1512 - mean_absolute_error: 0.1512
# Epoch 22/100
# 170/170 [==============================] - 0s 291us/sample - loss: 0.1429 - mean_absolute_error: 0.1429
# Epoch 23/100
# 170/170 [==============================] - 0s 290us/sample - loss: 0.1456 - mean_absolute_error: 0.1456
# Epoch 24/100
# 170/170 [==============================] - 0s 355us/sample - loss: 0.1480 - mean_absolute_error: 0.1480
# Epoch 25/100
# 170/170 [==============================] - 0s 369us/sample - loss: 0.1511 - mean_absolute_error: 0.1511
# Epoch 26/100
# 170/170 [==============================] - 0s 307us/sample - loss: 0.1596 - mean_absolute_error: 0.1596
# Epoch 27/100
# 170/170 [==============================] - 0s 346us/sample - loss: 0.1555 - mean_absolute_error: 0.1555
# Epoch 28/100
# 170/170 [==============================] - 0s 293us/sample - loss: 0.1518 - mean_absolute_error: 0.1518
# Epoch 29/100
# 170/170 [==============================] - 0s 313us/sample - loss: 0.1467 - mean_absolute_error: 0.1467
# Epoch 30/100
# 170/170 [==============================] - 0s 345us/sample - loss: 0.1461 - mean_absolute_error: 0.1461
# Epoch 31/100
# 170/170 [==============================] - 0s 313us/sample - loss: 0.1511 - mean_absolute_error: 0.1511
# Epoch 32/100
# 170/170 [==============================] - 0s 328us/sample - loss: 0.1433 - mean_absolute_error: 0.1433
# Epoch 33/100
# 170/170 [==============================] - 0s 263us/sample - loss: 0.1529 - mean_absolute_error: 0.1529
# Epoch 34/100
# 170/170 [==============================] - 0s 344us/sample - loss: 0.1470 - mean_absolute_error: 0.1470
# Epoch 35/100
# 170/170 [==============================] - 0s 369us/sample - loss: 0.1448 - mean_absolute_error: 0.1448
# Epoch 36/100
# 170/170 [==============================] - 0s 255us/sample - loss: 0.1444 - mean_absolute_error: 0.1444
# Epoch 37/100
# 170/170 [==============================] - 0s 341us/sample - loss: 0.1451 - mean_absolute_error: 0.1451
# Epoch 38/100
# 170/170 [==============================] - 0s 281us/sample - loss: 0.1497 - mean_absolute_error: 0.1497
# Epoch 39/100
# 170/170 [==============================] - 0s 276us/sample - loss: 0.1384 - mean_absolute_error: 0.1384
# Epoch 40/100
# 170/170 [==============================] - 0s 285us/sample - loss: 0.1495 - mean_absolute_error: 0.1495
# Epoch 41/100
# 170/170 [==============================] - 0s 267us/sample - loss: 0.1457 - mean_absolute_error: 0.1457
# Epoch 42/100
# 170/170 [==============================] - 0s 344us/sample - loss: 0.1524 - mean_absolute_error: 0.1524
# Epoch 43/100
# 170/170 [==============================] - 0s 297us/sample - loss: 0.1354 - mean_absolute_error: 0.1354
# Epoch 44/100
# 170/170 [==============================] - 0s 278us/sample - loss: 0.1405 - mean_absolute_error: 0.1405
# Epoch 45/100
# 170/170 [==============================] - 0s 336us/sample - loss: 0.1281 - mean_absolute_error: 0.1281
# Epoch 46/100
# 170/170 [==============================] - 0s 340us/sample - loss: 0.1370 - mean_absolute_error: 0.1370
# Epoch 47/100
# 170/170 [==============================] - 0s 250us/sample - loss: 0.1350 - mean_absolute_error: 0.1350
# Epoch 48/100
# 170/170 [==============================] - 0s 220us/sample - loss: 0.1355 - mean_absolute_error: 0.1355
# Epoch 49/100
# 170/170 [==============================] - 0s 328us/sample - loss: 0.1384 - mean_absolute_error: 0.1384
# Epoch 50/100
# 170/170 [==============================] - 0s 235us/sample - loss: 0.1399 - mean_absolute_error: 0.1399
# Epoch 51/100
# 170/170 [==============================] - 0s 292us/sample - loss: 0.1410 - mean_absolute_error: 0.1410
# Epoch 52/100
# 170/170 [==============================] - 0s 269us/sample - loss: 0.1384 - mean_absolute_error: 0.1384
# Epoch 53/100
# 170/170 [==============================] - 0s 319us/sample - loss: 0.1481 - mean_absolute_error: 0.1481
# Epoch 54/100
# 170/170 [==============================] - 0s 248us/sample - loss: 0.1392 - mean_absolute_error: 0.1392
# Epoch 55/100
# 170/170 [==============================] - 0s 300us/sample - loss: 0.1360 - mean_absolute_error: 0.1360
# Epoch 56/100
# 170/170 [==============================] - 0s 355us/sample - loss: 0.1485 - mean_absolute_error: 0.1485
# Epoch 57/100
# 170/170 [==============================] - 0s 344us/sample - loss: 0.1443 - mean_absolute_error: 0.1443
# Epoch 58/100
# 170/170 [==============================] - 0s 257us/sample - loss: 0.1439 - mean_absolute_error: 0.1439
# Epoch 59/100
# 170/170 [==============================] - 0s 226us/sample - loss: 0.1456 - mean_absolute_error: 0.1456
# Epoch 60/100
# 170/170 [==============================] - 0s 265us/sample - loss: 0.1360 - mean_absolute_error: 0.1360
# Epoch 61/100
# 170/170 [==============================] - 0s 319us/sample - loss: 0.1332 - mean_absolute_error: 0.1332
# Epoch 62/100
# 170/170 [==============================] - 0s 266us/sample - loss: 0.1451 - mean_absolute_error: 0.1451
# Epoch 63/100
# 170/170 [==============================] - 0s 238us/sample - loss: 0.1320 - mean_absolute_error: 0.1320
# Epoch 64/100
# 170/170 [==============================] - 0s 241us/sample - loss: 0.1464 - mean_absolute_error: 0.1464
# Epoch 65/100
# 170/170 [==============================] - 0s 155us/sample - loss: 0.1346 - mean_absolute_error: 0.1346
# Epoch 66/100
# 170/170 [==============================] - 0s 245us/sample - loss: 0.1334 - mean_absolute_error: 0.1334
# Epoch 67/100
# 170/170 [==============================] - 0s 227us/sample - loss: 0.1471 - mean_absolute_error: 0.1471
# Epoch 68/100
# 170/170 [==============================] - 0s 207us/sample - loss: 0.1410 - mean_absolute_error: 0.1410
# Epoch 69/100
# 170/170 [==============================] - 0s 285us/sample - loss: 0.1400 - mean_absolute_error: 0.1400
# Epoch 70/100
# 170/170 [==============================] - 0s 256us/sample - loss: 0.1367 - mean_absolute_error: 0.1367
# Epoch 71/100
# 170/170 [==============================] - 0s 304us/sample - loss: 0.1434 - mean_absolute_error: 0.1434
# Epoch 72/100
# 170/170 [==============================] - 0s 207us/sample - loss: 0.1448 - mean_absolute_error: 0.1448
# Epoch 73/100
# 170/170 [==============================] - 0s 203us/sample - loss: 0.1388 - mean_absolute_error: 0.1388
# Epoch 74/100
# 170/170 [==============================] - 0s 265us/sample - loss: 0.1508 - mean_absolute_error: 0.1508
# Epoch 75/100
# 170/170 [==============================] - 0s 253us/sample - loss: 0.1435 - mean_absolute_error: 0.1435
# Epoch 76/100
# 170/170 [==============================] - 0s 218us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 77/100
# 170/170 [==============================] - 0s 179us/sample - loss: 0.1390 - mean_absolute_error: 0.1390
# Epoch 78/100
# 170/170 [==============================] - 0s 207us/sample - loss: 0.1339 - mean_absolute_error: 0.1339
# Epoch 79/100
# 170/170 [==============================] - 0s 263us/sample - loss: 0.1392 - mean_absolute_error: 0.1392
# Epoch 80/100
# 170/170 [==============================] - 0s 191us/sample - loss: 0.1352 - mean_absolute_error: 0.1352
# Epoch 81/100
# 170/170 [==============================] - 0s 211us/sample - loss: 0.1370 - mean_absolute_error: 0.1370
# Epoch 82/100
# 170/170 [==============================] - 0s 199us/sample - loss: 0.1395 - mean_absolute_error: 0.1395
# Epoch 83/100
# 170/170 [==============================] - 0s 200us/sample - loss: 0.1449 - mean_absolute_error: 0.1449
# Epoch 84/100
# 170/170 [==============================] - 0s 252us/sample - loss: 0.1302 - mean_absolute_error: 0.1302
# Epoch 85/100
# 170/170 [==============================] - 0s 212us/sample - loss: 0.1347 - mean_absolute_error: 0.1347
# Epoch 86/100
# 170/170 [==============================] - 0s 252us/sample - loss: 0.1371 - mean_absolute_error: 0.1371
# Epoch 87/100
# 170/170 [==============================] - 0s 186us/sample - loss: 0.1325 - mean_absolute_error: 0.1325
# Epoch 88/100
# 170/170 [==============================] - 0s 238us/sample - loss: 0.1346 - mean_absolute_error: 0.1346
# Epoch 89/100
# 170/170 [==============================] - 0s 191us/sample - loss: 0.1329 - mean_absolute_error: 0.1329
# Epoch 90/100
# 170/170 [==============================] - 0s 242us/sample - loss: 0.1337 - mean_absolute_error: 0.1337
# Epoch 91/100
# 170/170 [==============================] - 0s 193us/sample - loss: 0.1381 - mean_absolute_error: 0.1381
# Epoch 92/100
# 170/170 [==============================] - 0s 239us/sample - loss: 0.1390 - mean_absolute_error: 0.1390
# Epoch 93/100
# 170/170 [==============================] - 0s 188us/sample - loss: 0.1399 - mean_absolute_error: 0.1399
# Epoch 94/100
# 170/170 [==============================] - 0s 271us/sample - loss: 0.1344 - mean_absolute_error: 0.1344
# Epoch 95/100
# 170/170 [==============================] - 0s 187us/sample - loss: 0.1437 - mean_absolute_error: 0.1437
# Epoch 96/100
# 170/170 [==============================] - 0s 208us/sample - loss: 0.1422 - mean_absolute_error: 0.1422
# Epoch 97/100
# 170/170 [==============================] - 0s 217us/sample - loss: 0.1391 - mean_absolute_error: 0.1391
# Epoch 98/100
# 170/170 [==============================] - 0s 242us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 99/100
# 170/170 [==============================] - 0s 207us/sample - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 100/100
# 170/170 [==============================] - 0s 194us/sample - loss: 0.1313 - mean_absolute_error: 0.1313
# Gráficos com lag 3
# Train on 168 samples
# Epoch 1/100
# 168/168 [==============================] - 1s 8ms/sample - loss: 0.4289 - mean_absolute_error: 0.4289
# Epoch 2/100
# 168/168 [==============================] - 0s 191us/sample - loss: 0.3706 - mean_absolute_error: 0.3706
# Epoch 3/100
# 168/168 [==============================] - 0s 234us/sample - loss: 0.3036 - mean_absolute_error: 0.3036
# Epoch 4/100
# 168/168 [==============================] - 0s 199us/sample - loss: 0.2473 - mean_absolute_error: 0.2473
# Epoch 5/100
# 168/168 [==============================] - 0s 204us/sample - loss: 0.2049 - mean_absolute_error: 0.2049
# Epoch 6/100
# 168/168 [==============================] - 0s 264us/sample - loss: 0.1783 - mean_absolute_error: 0.1783
# Epoch 7/100
# 168/168 [==============================] - 0s 246us/sample - loss: 0.1868 - mean_absolute_error: 0.1868
# Epoch 8/100
# 168/168 [==============================] - 0s 204us/sample - loss: 0.1714 - mean_absolute_error: 0.1714
# Epoch 9/100
# 168/168 [==============================] - 0s 281us/sample - loss: 0.1681 - mean_absolute_error: 0.1681
# Epoch 10/100
# 168/168 [==============================] - 0s 279us/sample - loss: 0.1597 - mean_absolute_error: 0.1597
# Epoch 11/100
# 168/168 [==============================] - 0s 283us/sample - loss: 0.1720 - mean_absolute_error: 0.1720
# Epoch 12/100
# 168/168 [==============================] - 0s 274us/sample - loss: 0.1474 - mean_absolute_error: 0.1474
# Epoch 13/100
# 168/168 [==============================] - 0s 293us/sample - loss: 0.1500 - mean_absolute_error: 0.1500
# Epoch 14/100
# 168/168 [==============================] - 0s 268us/sample - loss: 0.1580 - mean_absolute_error: 0.1580
# Epoch 15/100
# 168/168 [==============================] - 0s 280us/sample - loss: 0.1661 - mean_absolute_error: 0.1661
# Epoch 16/100
# 168/168 [==============================] - 0s 272us/sample - loss: 0.1639 - mean_absolute_error: 0.1639
# Epoch 17/100
# 168/168 [==============================] - 0s 275us/sample - loss: 0.1514 - mean_absolute_error: 0.1514
# Epoch 18/100
# 168/168 [==============================] - 0s 278us/sample - loss: 0.1561 - mean_absolute_error: 0.1561
# Epoch 19/100
# 168/168 [==============================] - 0s 337us/sample - loss: 0.1544 - mean_absolute_error: 0.1544
# Epoch 20/100
# 168/168 [==============================] - 0s 254us/sample - loss: 0.1508 - mean_absolute_error: 0.1508
# Epoch 21/100
# 168/168 [==============================] - 0s 216us/sample - loss: 0.1565 - mean_absolute_error: 0.1565
# Epoch 22/100
# 168/168 [==============================] - 0s 304us/sample - loss: 0.1491 - mean_absolute_error: 0.1491
# Epoch 23/100
# 168/168 [==============================] - 0s 303us/sample - loss: 0.1535 - mean_absolute_error: 0.1535
# Epoch 24/100
# 168/168 [==============================] - 0s 221us/sample - loss: 0.1622 - mean_absolute_error: 0.1622
# Epoch 25/100
# 168/168 [==============================] - 0s 208us/sample - loss: 0.1574 - mean_absolute_error: 0.1574
# Epoch 26/100
# 168/168 [==============================] - 0s 272us/sample - loss: 0.1514 - mean_absolute_error: 0.1514
# Epoch 27/100
# 168/168 [==============================] - 0s 271us/sample - loss: 0.1531 - mean_absolute_error: 0.1531
# Epoch 28/100
# 168/168 [==============================] - 0s 272us/sample - loss: 0.1489 - mean_absolute_error: 0.1489
# Epoch 29/100
# 168/168 [==============================] - 0s 214us/sample - loss: 0.1518 - mean_absolute_error: 0.1518
# Epoch 30/100
# 168/168 [==============================] - 0s 247us/sample - loss: 0.1485 - mean_absolute_error: 0.1485
# Epoch 31/100
# 168/168 [==============================] - 0s 239us/sample - loss: 0.1537 - mean_absolute_error: 0.1537
# Epoch 32/100
# 168/168 [==============================] - 0s 337us/sample - loss: 0.1451 - mean_absolute_error: 0.1451
# Epoch 33/100
# 168/168 [==============================] - 0s 277us/sample - loss: 0.1461 - mean_absolute_error: 0.1461
# Epoch 34/100
# 168/168 [==============================] - 0s 280us/sample - loss: 0.1529 - mean_absolute_error: 0.1529
# Epoch 35/100
# 168/168 [==============================] - 0s 273us/sample - loss: 0.1475 - mean_absolute_error: 0.1475
# Epoch 36/100
# 168/168 [==============================] - 0s 259us/sample - loss: 0.1542 - mean_absolute_error: 0.1542
# Epoch 37/100
# 168/168 [==============================] - 0s 257us/sample - loss: 0.1442 - mean_absolute_error: 0.1442
# Epoch 38/100
# 168/168 [==============================] - 0s 236us/sample - loss: 0.1358 - mean_absolute_error: 0.1358
# Epoch 39/100
# 168/168 [==============================] - 0s 249us/sample - loss: 0.1533 - mean_absolute_error: 0.1533
# Epoch 40/100
# 168/168 [==============================] - 0s 276us/sample - loss: 0.1418 - mean_absolute_error: 0.1418
# Epoch 41/100
# 168/168 [==============================] - 0s 254us/sample - loss: 0.1431 - mean_absolute_error: 0.1431
# Epoch 42/100
# 168/168 [==============================] - 0s 305us/sample - loss: 0.1433 - mean_absolute_error: 0.1433
# Epoch 43/100
# 168/168 [==============================] - 0s 271us/sample - loss: 0.1436 - mean_absolute_error: 0.1436
# Epoch 44/100
# 168/168 [==============================] - 0s 220us/sample - loss: 0.1393 - mean_absolute_error: 0.1393
# Epoch 45/100
# 168/168 [==============================] - 0s 245us/sample - loss: 0.1465 - mean_absolute_error: 0.1465
# Epoch 46/100
# 168/168 [==============================] - 0s 212us/sample - loss: 0.1509 - mean_absolute_error: 0.1509
# Epoch 47/100
# 168/168 [==============================] - 0s 282us/sample - loss: 0.1484 - mean_absolute_error: 0.1484
# Epoch 48/100
# 168/168 [==============================] - 0s 258us/sample - loss: 0.1437 - mean_absolute_error: 0.1437
# Epoch 49/100
# 168/168 [==============================] - 0s 218us/sample - loss: 0.1461 - mean_absolute_error: 0.1461
# Epoch 50/100
# 168/168 [==============================] - 0s 394us/sample - loss: 0.1433 - mean_absolute_error: 0.1433
# Epoch 51/100
# 168/168 [==============================] - 0s 342us/sample - loss: 0.1443 - mean_absolute_error: 0.1443
# Epoch 52/100
# 168/168 [==============================] - 0s 355us/sample - loss: 0.1333 - mean_absolute_error: 0.1333
# Epoch 53/100
# 168/168 [==============================] - 0s 326us/sample - loss: 0.1512 - mean_absolute_error: 0.1512
# Epoch 54/100
# 168/168 [==============================] - 0s 268us/sample - loss: 0.1412 - mean_absolute_error: 0.1412
# Epoch 55/100
# 168/168 [==============================] - 0s 277us/sample - loss: 0.1381 - mean_absolute_error: 0.1381
# Epoch 56/100
# 168/168 [==============================] - 0s 201us/sample - loss: 0.1382 - mean_absolute_error: 0.1382
# Epoch 57/100
# 168/168 [==============================] - 0s 267us/sample - loss: 0.1430 - mean_absolute_error: 0.1430
# Epoch 58/100
# 168/168 [==============================] - 0s 259us/sample - loss: 0.1451 - mean_absolute_error: 0.1451
# Epoch 59/100
# 168/168 [==============================] - 0s 225us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 60/100
# 168/168 [==============================] - 0s 251us/sample - loss: 0.1463 - mean_absolute_error: 0.1463
# Epoch 61/100
# 168/168 [==============================] - 0s 230us/sample - loss: 0.1428 - mean_absolute_error: 0.1428
# Epoch 62/100
# 168/168 [==============================] - 0s 326us/sample - loss: 0.1509 - mean_absolute_error: 0.1509
# Epoch 63/100
# 168/168 [==============================] - 0s 244us/sample - loss: 0.1542 - mean_absolute_error: 0.1542
# Epoch 64/100
# 168/168 [==============================] - 0s 305us/sample - loss: 0.1375 - mean_absolute_error: 0.1375
# Epoch 65/100
# 168/168 [==============================] - 0s 211us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 66/100
# 168/168 [==============================] - 0s 276us/sample - loss: 0.1466 - mean_absolute_error: 0.1466
# Epoch 67/100
# 168/168 [==============================] - 0s 211us/sample - loss: 0.1442 - mean_absolute_error: 0.1442
# Epoch 68/100
# 168/168 [==============================] - 0s 244us/sample - loss: 0.1430 - mean_absolute_error: 0.1430
# Epoch 69/100
# 168/168 [==============================] - 0s 213us/sample - loss: 0.1417 - mean_absolute_error: 0.1417
# Epoch 70/100
# 168/168 [==============================] - 0s 214us/sample - loss: 0.1420 - mean_absolute_error: 0.1420
# Epoch 71/100
# 168/168 [==============================] - 0s 281us/sample - loss: 0.1397 - mean_absolute_error: 0.1397
# Epoch 72/100
# 168/168 [==============================] - 0s 221us/sample - loss: 0.1368 - mean_absolute_error: 0.1368
# Epoch 73/100
# 168/168 [==============================] - 0s 214us/sample - loss: 0.1489 - mean_absolute_error: 0.1489
# Epoch 74/100
# 168/168 [==============================] - 0s 282us/sample - loss: 0.1341 - mean_absolute_error: 0.1341
# Epoch 75/100
# 168/168 [==============================] - 0s 249us/sample - loss: 0.1372 - mean_absolute_error: 0.1372
# Epoch 76/100
# 168/168 [==============================] - 0s 209us/sample - loss: 0.1387 - mean_absolute_error: 0.1387
# Epoch 77/100
# 168/168 [==============================] - 0s 256us/sample - loss: 0.1412 - mean_absolute_error: 0.1412
# Epoch 78/100
# 168/168 [==============================] - 0s 239us/sample - loss: 0.1437 - mean_absolute_error: 0.1437
# Epoch 79/100
# 168/168 [==============================] - 0s 220us/sample - loss: 0.1443 - mean_absolute_error: 0.1443
# Epoch 80/100
# 168/168 [==============================] - 0s 261us/sample - loss: 0.1387 - mean_absolute_error: 0.1387
# Epoch 81/100
# 168/168 [==============================] - 0s 236us/sample - loss: 0.1394 - mean_absolute_error: 0.1394
# Epoch 82/100
# 168/168 [==============================] - 0s 213us/sample - loss: 0.1374 - mean_absolute_error: 0.1374
# Epoch 83/100
# 168/168 [==============================] - 0s 265us/sample - loss: 0.1440 - mean_absolute_error: 0.1440
# Epoch 84/100
# 168/168 [==============================] - 0s 211us/sample - loss: 0.1423 - mean_absolute_error: 0.1423
# Epoch 85/100
# 168/168 [==============================] - 0s 263us/sample - loss: 0.1389 - mean_absolute_error: 0.1389
# Epoch 86/100
# 168/168 [==============================] - 0s 273us/sample - loss: 0.1357 - mean_absolute_error: 0.1357
# Epoch 87/100
# 168/168 [==============================] - 0s 246us/sample - loss: 0.1404 - mean_absolute_error: 0.1404
# Epoch 88/100
# 168/168 [==============================] - 0s 197us/sample - loss: 0.1422 - mean_absolute_error: 0.1422
# Epoch 89/100
# 168/168 [==============================] - 0s 233us/sample - loss: 0.1385 - mean_absolute_error: 0.1385
# Epoch 90/100
# 168/168 [==============================] - 0s 225us/sample - loss: 0.1410 - mean_absolute_error: 0.1410
# Epoch 91/100
# 168/168 [==============================] - 0s 266us/sample - loss: 0.1384 - mean_absolute_error: 0.1384
# Epoch 92/100
# 168/168 [==============================] - 0s 273us/sample - loss: 0.1336 - mean_absolute_error: 0.1336
# Epoch 93/100
# 168/168 [==============================] - 0s 258us/sample - loss: 0.1380 - mean_absolute_error: 0.1380
# Epoch 94/100
# 168/168 [==============================] - 0s 244us/sample - loss: 0.1302 - mean_absolute_error: 0.1302
# Epoch 95/100
# 168/168 [==============================] - 0s 313us/sample - loss: 0.1309 - mean_absolute_error: 0.1309
# Epoch 96/100
# 168/168 [==============================] - 0s 203us/sample - loss: 0.1323 - mean_absolute_error: 0.1323
# Epoch 97/100
# 168/168 [==============================] - 0s 291us/sample - loss: 0.1361 - mean_absolute_error: 0.1361
# Epoch 98/100
# 168/168 [==============================] - 0s 291us/sample - loss: 0.1305 - mean_absolute_error: 0.1305
# Epoch 99/100
# 168/168 [==============================] - 0s 201us/sample - loss: 0.1433 - mean_absolute_error: 0.1433
# Epoch 100/100
# 168/168 [==============================] - 0s 273us/sample - loss: 0.1335 - mean_absolute_error: 0.1335
# Gráficos com lag 5
# Train on 166 samples
# Epoch 1/100
# 166/166 [==============================] - 2s 10ms/sample - loss: 0.6200 - mean_absolute_error: 0.6200
# Epoch 2/100
# 166/166 [==============================] - 0s 280us/sample - loss: 0.5418 - mean_absolute_error: 0.5418
# Epoch 3/100
# 166/166 [==============================] - 0s 297us/sample - loss: 0.4886 - mean_absolute_error: 0.4886
# Epoch 4/100
# 166/166 [==============================] - 0s 309us/sample - loss: 0.4250 - mean_absolute_error: 0.4250
# Epoch 5/100
# 166/166 [==============================] - 0s 228us/sample - loss: 0.3689 - mean_absolute_error: 0.3689
# Epoch 6/100
# 166/166 [==============================] - 0s 283us/sample - loss: 0.3055 - mean_absolute_error: 0.3055
# Epoch 7/100
# 166/166 [==============================] - 0s 309us/sample - loss: 0.2419 - mean_absolute_error: 0.2419
# Epoch 8/100
# 166/166 [==============================] - 0s 343us/sample - loss: 0.1882 - mean_absolute_error: 0.1882
# Epoch 9/100
# 166/166 [==============================] - 0s 319us/sample - loss: 0.1642 - mean_absolute_error: 0.1642
# Epoch 10/100
# 166/166 [==============================] - 0s 296us/sample - loss: 0.1782 - mean_absolute_error: 0.1782
# Epoch 11/100
# 166/166 [==============================] - 0s 255us/sample - loss: 0.1849 - mean_absolute_error: 0.1849
# Epoch 12/100
# 166/166 [==============================] - 0s 236us/sample - loss: 0.1865 - mean_absolute_error: 0.1865
# Epoch 13/100
# 166/166 [==============================] - 0s 288us/sample - loss: 0.1731 - mean_absolute_error: 0.1731
# Epoch 14/100
# 166/166 [==============================] - 0s 250us/sample - loss: 0.1666 - mean_absolute_error: 0.1666
# Epoch 15/100
# 166/166 [==============================] - 0s 271us/sample - loss: 0.1686 - mean_absolute_error: 0.1686
# Epoch 16/100
# 166/166 [==============================] - 0s 472us/sample - loss: 0.1612 - mean_absolute_error: 0.1612
# Epoch 17/100
# 166/166 [==============================] - 0s 363us/sample - loss: 0.1432 - mean_absolute_error: 0.1432
# Epoch 18/100
# 166/166 [==============================] - 0s 520us/sample - loss: 0.1620 - mean_absolute_error: 0.1620
# Epoch 19/100
# 166/166 [==============================] - 0s 378us/sample - loss: 0.1652 - mean_absolute_error: 0.1652
# Epoch 20/100
# 166/166 [==============================] - 0s 403us/sample - loss: 0.1665 - mean_absolute_error: 0.1665
# Epoch 21/100
# 166/166 [==============================] - 0s 294us/sample - loss: 0.1704 - mean_absolute_error: 0.1704
# Epoch 22/100
# 166/166 [==============================] - 0s 251us/sample - loss: 0.1566 - mean_absolute_error: 0.1566
# Epoch 23/100
# 166/166 [==============================] - 0s 340us/sample - loss: 0.1682 - mean_absolute_error: 0.1682
# Epoch 24/100
# 166/166 [==============================] - 0s 279us/sample - loss: 0.1529 - mean_absolute_error: 0.1529
# Epoch 25/100
# 166/166 [==============================] - 0s 224us/sample - loss: 0.1746 - mean_absolute_error: 0.1746
# Epoch 26/100
# 166/166 [==============================] - 0s 359us/sample - loss: 0.1638 - mean_absolute_error: 0.1638
# Epoch 27/100
# 166/166 [==============================] - 0s 295us/sample - loss: 0.1534 - mean_absolute_error: 0.1534
# Epoch 28/100
# 166/166 [==============================] - 0s 244us/sample - loss: 0.1567 - mean_absolute_error: 0.1567
# Epoch 29/100
# 166/166 [==============================] - 0s 254us/sample - loss: 0.1532 - mean_absolute_error: 0.1532
# Epoch 30/100
# 166/166 [==============================] - 0s 347us/sample - loss: 0.1558 - mean_absolute_error: 0.1558
# Epoch 31/100
# 166/166 [==============================] - 0s 266us/sample - loss: 0.1595 - mean_absolute_error: 0.1595
# Epoch 32/100
# 166/166 [==============================] - 0s 394us/sample - loss: 0.1574 - mean_absolute_error: 0.1574
# Epoch 33/100
# 166/166 [==============================] - 0s 534us/sample - loss: 0.1599 - mean_absolute_error: 0.1599
# Epoch 34/100
# 166/166 [==============================] - 0s 342us/sample - loss: 0.1455 - mean_absolute_error: 0.1455
# Epoch 35/100
# 166/166 [==============================] - 0s 379us/sample - loss: 0.1466 - mean_absolute_error: 0.1466
# Epoch 36/100
# 166/166 [==============================] - 0s 340us/sample - loss: 0.1622 - mean_absolute_error: 0.1622
# Epoch 37/100
# 166/166 [==============================] - 0s 247us/sample - loss: 0.1469 - mean_absolute_error: 0.1469
# Epoch 38/100
# 166/166 [==============================] - 0s 522us/sample - loss: 0.1525 - mean_absolute_error: 0.1525
# Epoch 39/100
# 166/166 [==============================] - 0s 511us/sample - loss: 0.1477 - mean_absolute_error: 0.1477
# Epoch 40/100
# 166/166 [==============================] - 0s 415us/sample - loss: 0.1537 - mean_absolute_error: 0.1537
# Epoch 41/100
# 166/166 [==============================] - 0s 495us/sample - loss: 0.1545 - mean_absolute_error: 0.1545
# Epoch 42/100
# 166/166 [==============================] - 0s 298us/sample - loss: 0.1481 - mean_absolute_error: 0.1481
# Epoch 43/100
# 166/166 [==============================] - 0s 304us/sample - loss: 0.1479 - mean_absolute_error: 0.1479
# Epoch 44/100
# 166/166 [==============================] - 0s 395us/sample - loss: 0.1420 - mean_absolute_error: 0.1420
# Epoch 45/100
# 166/166 [==============================] - 0s 449us/sample - loss: 0.1446 - mean_absolute_error: 0.1446
# Epoch 46/100
# 166/166 [==============================] - 0s 616us/sample - loss: 0.1493 - mean_absolute_error: 0.1493
# Epoch 47/100
# 166/166 [==============================] - 0s 328us/sample - loss: 0.1525 - mean_absolute_error: 0.1525
# Epoch 48/100
# 166/166 [==============================] - 0s 420us/sample - loss: 0.1429 - mean_absolute_error: 0.1429
# Epoch 49/100
# 166/166 [==============================] - 0s 342us/sample - loss: 0.1404 - mean_absolute_error: 0.1404
# Epoch 50/100
# 166/166 [==============================] - 0s 431us/sample - loss: 0.1449 - mean_absolute_error: 0.1449
# Epoch 51/100
# 166/166 [==============================] - 0s 440us/sample - loss: 0.1497 - mean_absolute_error: 0.1497
# Epoch 52/100
# 166/166 [==============================] - 0s 518us/sample - loss: 0.1436 - mean_absolute_error: 0.1436
# Epoch 53/100
# 166/166 [==============================] - 0s 420us/sample - loss: 0.1418 - mean_absolute_error: 0.1418
# Epoch 54/100
# 166/166 [==============================] - 0s 398us/sample - loss: 0.1384 - mean_absolute_error: 0.1384
# Epoch 55/100
# 166/166 [==============================] - 0s 430us/sample - loss: 0.1417 - mean_absolute_error: 0.1417
# Epoch 56/100
# 166/166 [==============================] - 0s 480us/sample - loss: 0.1418 - mean_absolute_error: 0.1418
# Epoch 57/100
# 166/166 [==============================] - 0s 458us/sample - loss: 0.1414 - mean_absolute_error: 0.1414
# Epoch 58/100
# 166/166 [==============================] - 0s 424us/sample - loss: 0.1496 - mean_absolute_error: 0.1496
# Epoch 59/100
# 166/166 [==============================] - 0s 706us/sample - loss: 0.1376 - mean_absolute_error: 0.1376
# Epoch 60/100
# 166/166 [==============================] - 0s 369us/sample - loss: 0.1391 - mean_absolute_error: 0.1391
# Epoch 61/100
# 166/166 [==============================] - 0s 377us/sample - loss: 0.1362 - mean_absolute_error: 0.1362
# Epoch 62/100
# 166/166 [==============================] - 0s 465us/sample - loss: 0.1394 - mean_absolute_error: 0.1394
# Epoch 63/100
# 166/166 [==============================] - 0s 423us/sample - loss: 0.1415 - mean_absolute_error: 0.1415
# Epoch 64/100
# 166/166 [==============================] - 0s 419us/sample - loss: 0.1397 - mean_absolute_error: 0.1397
# Epoch 65/100
# 166/166 [==============================] - 0s 375us/sample - loss: 0.1504 - mean_absolute_error: 0.1504
# Epoch 66/100
# 166/166 [==============================] - 0s 326us/sample - loss: 0.1453 - mean_absolute_error: 0.1453
# Epoch 67/100
# 166/166 [==============================] - 0s 449us/sample - loss: 0.1341 - mean_absolute_error: 0.1341
# Epoch 68/100
# 166/166 [==============================] - 0s 413us/sample - loss: 0.1427 - mean_absolute_error: 0.1427
# Epoch 69/100
# 166/166 [==============================] - 0s 413us/sample - loss: 0.1462 - mean_absolute_error: 0.1462
# Epoch 70/100
# 166/166 [==============================] - 0s 461us/sample - loss: 0.1382 - mean_absolute_error: 0.1382
# Epoch 71/100
# 166/166 [==============================] - 0s 413us/sample - loss: 0.1470 - mean_absolute_error: 0.1470
# Epoch 72/100
# 166/166 [==============================] - 0s 348us/sample - loss: 0.1432 - mean_absolute_error: 0.1432
# Epoch 73/100
# 166/166 [==============================] - 0s 360us/sample - loss: 0.1370 - mean_absolute_error: 0.1370
# Epoch 74/100
# 166/166 [==============================] - 0s 394us/sample - loss: 0.1408 - mean_absolute_error: 0.1408
# Epoch 75/100
# 166/166 [==============================] - 0s 466us/sample - loss: 0.1403 - mean_absolute_error: 0.1403
# Epoch 76/100
# 166/166 [==============================] - 0s 374us/sample - loss: 0.1376 - mean_absolute_error: 0.1376
# Epoch 77/100
# 166/166 [==============================] - 0s 566us/sample - loss: 0.1405 - mean_absolute_error: 0.1405
# Epoch 78/100
# 166/166 [==============================] - 0s 437us/sample - loss: 0.1379 - mean_absolute_error: 0.1379
# Epoch 79/100
# 166/166 [==============================] - 0s 489us/sample - loss: 0.1397 - mean_absolute_error: 0.1397
# Epoch 80/100
# 166/166 [==============================] - 0s 402us/sample - loss: 0.1366 - mean_absolute_error: 0.1366
# Epoch 81/100
# 166/166 [==============================] - 0s 405us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 82/100
# 166/166 [==============================] - 0s 403us/sample - loss: 0.1334 - mean_absolute_error: 0.1334
# Epoch 83/100
# 166/166 [==============================] - 0s 291us/sample - loss: 0.1428 - mean_absolute_error: 0.1428
# Epoch 84/100
# 166/166 [==============================] - 0s 292us/sample - loss: 0.1426 - mean_absolute_error: 0.1426
# Epoch 85/100
# 166/166 [==============================] - 0s 282us/sample - loss: 0.1423 - mean_absolute_error: 0.1423
# Epoch 86/100
# 166/166 [==============================] - 0s 281us/sample - loss: 0.1422 - mean_absolute_error: 0.1422
# Epoch 87/100
# 166/166 [==============================] - 0s 328us/sample - loss: 0.1413 - mean_absolute_error: 0.1413
# Epoch 88/100
# 166/166 [==============================] - 0s 381us/sample - loss: 0.1330 - mean_absolute_error: 0.1330
# Epoch 89/100
# 166/166 [==============================] - 0s 343us/sample - loss: 0.1419 - mean_absolute_error: 0.1419
# Epoch 90/100
# 166/166 [==============================] - 0s 508us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 91/100
# 166/166 [==============================] - 0s 413us/sample - loss: 0.1458 - mean_absolute_error: 0.1458
# Epoch 92/100
# 166/166 [==============================] - 0s 414us/sample - loss: 0.1390 - mean_absolute_error: 0.1390
# Epoch 93/100
# 166/166 [==============================] - 0s 402us/sample - loss: 0.1276 - mean_absolute_error: 0.1276
# Epoch 94/100
# 166/166 [==============================] - 0s 374us/sample - loss: 0.1470 - mean_absolute_error: 0.1470
# Epoch 95/100
# 166/166 [==============================] - 0s 287us/sample - loss: 0.1360 - mean_absolute_error: 0.1360
# Epoch 96/100
# 166/166 [==============================] - 0s 307us/sample - loss: 0.1316 - mean_absolute_error: 0.1316
# Epoch 97/100
# 166/166 [==============================] - 0s 330us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 98/100
# 166/166 [==============================] - 0s 312us/sample - loss: 0.1381 - mean_absolute_error: 0.1381
# Epoch 99/100
# 166/166 [==============================] - 0s 325us/sample - loss: 0.1371 - mean_absolute_error: 0.1371
# Epoch 100/100
# 166/166 [==============================] - 0s 380us/sample - loss: 0.1380 - mean_absolute_error: 0.1380
# Gráficos com lag 7

# %%
df_resultados_treino
# Out:
#    Lags    MAPE    RMSE      R²    TIPO
# 0     3  2.5977  0.1405  0.4088  TREINO
# 1     5  2.5755  0.1388  0.4133  TREINO
# 2     7  2.5299  0.1383  0.4188  TREINO

# %%
df_resultados_teste
# Out:
#    Lags    MAPE    RMSE      R²   TIPO
# 0     3  1.3130  0.1470  0.1288  TESTE
# 1     5  1.2335  0.1425  0.1820  TESTE
# 2     7  1.1741  0.1370  0.2439  TESTE
