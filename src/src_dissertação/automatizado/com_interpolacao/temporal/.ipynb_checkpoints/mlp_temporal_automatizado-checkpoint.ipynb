# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (12,10)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
df = pd.read_csv(str_files + "cetesb_concatenado06semoutliers.csv",encoding='utf-8',sep=',')
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
def seleciona_colunas(trainingd):
    fph      = trainingd.iloc[:,0:1].values
        
    frame_completo = pd.DataFrame(list(zip(fph)),columns =['ph']) 
    
    return frame_completo

def seleciona_colunas_od(trainingd):
    fod      = trainingd.iloc[:,4:5].values
        
    frame_completo = pd.DataFrame(list(zip(fod)),columns =['od']) 
    
    return frame_completo

def pegar_dados_coluna_predita_train_test(trainingd,percent,index_coluna):
    data = trainingd.iloc[:,:].values
    train = trainingd.iloc[0:int(len(data)*percent),:].values  
    train_previsao = trainingd.iloc[0:int(len(data)*percent),index_coluna:index_coluna+1].values
    test = trainingd.iloc[len(train):,index_coluna:index_coluna+1].values
    
    print('Nº observações:', len(data))
    print('treino:',len(train))
    print('teste:',len(test))
    
    return train,train_previsao, test

#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
def normalizacao(train,test):
    sc = MinMaxScaler()
    testd = test
    train = sc.fit_transform(train)
    test = sc.fit_transform(test)    
    return train,test,testd

#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
#cy = coluna que será predita
def prepara_dados(dados,lags,cy):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i,:])
        y.append(dados[i, cy])
       
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    '''  
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        
        print(real)
        mape = mape_sum/len(real)
    '''
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_true,y_pred)
    return rscore

def rquadrado(y_pred,y_true):
    #Soma Total dos Quadrados (STQ): mostra a variação de y em torno da própria média. 
    #É o somatório das diferenças entre o valor alvo real e sua média elevado ao quadrado.
    y_traco = np.mean(y_true)
    
    print('media y_true:', y_traco)
        
    stq = 0
    
    for s in y_true:
        a = s - y_traco
        st = a * a
        stq = stq + st
    
    print('Soma Total dos Quadrados (STQ):', stq[0])
    
    #Soma dos Quadrados dos Resíduos (SQU): variação de Y que não é explicada pelo modelo elaborado. 
    #É o somatório das diferenças entre o valor predito e o valor real elevados ao quadrado.
    squ = 0
    
    y_traco = np.mean(y_pred)
    print('media y_pred:', y_traco)
    
    for n in range(len(y_true)):
        a = y_true[n] - y_pred[n]
        st = a * a
        squ = squ + st
        
    print('Soma dos Quadrados dos Resíduos (SQU):',squ[0])
    print('\n')
    print('Fórmula do R²')
    print('\n')
    print('sqr = stq - squ')
    sqr = stq[0] - squ[0]
    print('R² = sqr/stq')
    sqr = sqr/stq[0]
    print('\n')
    return sqr

def correlacao_determinacao(dtframe,tipo):
    
    if (tipo == 0): #Treino
        resultado = dtframe.corr().previsao_treino.values[1] ** 2 
    else: #teste
        resultado = dtframe.corr().previsao_teste.values[1] ** 2 
    
    return resultado

def ajusta_array(array):
    lista = []
    
    for i in range(len(array)):
        lista.append(array[i][0])
        
    #print('ajusta array:',lista)
        
    return lista

def ajusta_lista(array):
    lista = []
    
    for i in range(len(array)):
        lista.append(array[i][0])
        
    #print('ajusta array:',lista)
        
    return lista

# %% [markdown]
# # Utilizando função de ativação Linear

# %%
trainingd = seleciona_colunas(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 20):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    n_input = train_X.shape[1] * train_X.shape[2]
    
    test_X = test_X.reshape((test_X.shape[0],n_input))
    
    train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(Dense(units = 10, activation = 'relu', input_dim = n_input))
    model.add(Dense(units = 21, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'linear'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
         
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
df_resultados.describe()
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
trainingd = seleciona_colunas_od(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    n_input = train_X.shape[1] * train_X.shape[2]
    
    test_X = test_X.reshape((test_X.shape[0],n_input))
    
    train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(Dense(units = 10, activation = 'relu', input_dim = n_input))
    model.add(Dense(units = 21, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'linear'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
         
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
df_resultados.describe()
# Out:
# Completo: 248
# treino: 173
# teste: 75
# (248, 1)

# %% [markdown]
# # Utilizando função de ativação Relu

# %%
trainingd = seleciona_colunas(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    n_input = train_X.shape[1] * train_X.shape[2]
    
    test_X = test_X.reshape((test_X.shape[0],n_input))
    
    train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(Dense(units = 10, activation = 'relu', input_dim = n_input))
    model.add(Dense(units = 21, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'relu'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
         
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
df_resultados.describe()

# %%
trainingd = seleciona_colunas_od(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    n_input = train_X.shape[1] * train_X.shape[2]
    
    test_X = test_X.reshape((test_X.shape[0],n_input))
    
    train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(Dense(units = 10, activation = 'relu', input_dim = n_input))
    model.add(Dense(units = 21, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'relu'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
         
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
# Out:
# Train on 170 samples
# Epoch 1/100
# 170/170 [==============================] - 0s 3ms/sample - loss: 0.2397 - mean_absolute_error: 0.2397
# Epoch 2/100
# 170/170 [==============================] - 0s 156us/sample - loss: 0.1731 - mean_absolute_error: 0.1731
# Epoch 3/100
# 170/170 [==============================] - 0s 106us/sample - loss: 0.1285 - mean_absolute_error: 0.1285
# Epoch 4/100
# 170/170 [==============================] - 0s 146us/sample - loss: 0.1266 - mean_absolute_error: 0.1266
# Epoch 5/100
# 170/170 [==============================] - 0s 111us/sample - loss: 0.1270 - mean_absolute_error: 0.1270
# Epoch 6/100
# 170/170 [==============================] - 0s 156us/sample - loss: 0.1211 - mean_absolute_error: 0.1211
# Epoch 7/100
# 170/170 [==============================] - 0s 96us/sample - loss: 0.1237 - mean_absolute_error: 0.1237
# Epoch 8/100
# 170/170 [==============================] - 0s 133us/sample - loss: 0.1219 - mean_absolute_error: 0.1219
# Epoch 9/100
# 170/170 [==============================] - 0s 149us/sample - loss: 0.1207 - mean_absolute_error: 0.1207
# Epoch 10/100
# 170/170 [==============================] - 0s 131us/sample - loss: 0.1225 - mean_absolute_error: 0.1225
# Epoch 11/100
# 170/170 [==============================] - 0s 110us/sample - loss: 0.1208 - mean_absolute_error: 0.1208
# Epoch 12/100
# 170/170 [==============================] - 0s 157us/sample - loss: 0.1204 - mean_absolute_error: 0.1204
# Epoch 13/100
# 170/170 [==============================] - 0s 173us/sample - loss: 0.1201 - mean_absolute_error: 0.1201
# Epoch 14/100
# 170/170 [==============================] - 0s 118us/sample - loss: 0.1202 - mean_absolute_error: 0.1202
# Epoch 15/100
# 170/170 [==============================] - 0s 114us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 16/100
# 170/170 [==============================] - 0s 158us/sample - loss: 0.1202 - mean_absolute_error: 0.1202
# Epoch 17/100
# 170/170 [==============================] - 0s 115us/sample - loss: 0.1200 - mean_absolute_error: 0.1200
# Epoch 18/100
# 170/170 [==============================] - 0s 165us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 19/100
# 170/170 [==============================] - 0s 95us/sample - loss: 0.1201 - mean_absolute_error: 0.1201
# Epoch 20/100
# 170/170 [==============================] - 0s 127us/sample - loss: 0.1195 - mean_absolute_error: 0.1195
# Epoch 21/100
# 170/170 [==============================] - 0s 117us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch
/sample - loss: 0.1206 - mean_absolute_error: 0.1206
# Epoch 74/100
# 168/168 [==============================] - 0s 97us/sample - loss: 0.1203 - mean_absolute_error: 0.1203
# Epoch 75/100
# 168/168 [==============================] - 0s 179us/sample - loss: 0.1205 - mean_absolute_error: 0.1205
# Epoch 76/100
# 168/168 [==============================] - 0s 111us/sample - loss: 0.1203 - mean_absolute_error: 0.1203
# Epoch 77/100
# 168/168 [==============================] - 0s 146us/sample - loss: 0.1202 - mean_absolute_error: 0.1202
# Epoch 78/100
# 168/168 [==============================] - 0s 81us/sample - loss: 0.1203 - mean_absolute_error: 0.1203
# Epoch 79/100
# 168/168 [==============================] - 0s 119us/sample - loss: 0.1202 - mean_absolute_error: 0.1202
# Epoch 80/100
# 168/168 [==============================] - 0s 67us/sample - loss: 0.1206 - mean_absolute_error: 0.1206
# Epoch 81/100
# 168/168 [==============================] - 0s 142us/sample - loss: 0.1201 - mean_absolute_error: 0.1201
# Epoch 82/100
# 168/168 [==============================] - 0s 117us/sample - loss: 0.1201 - mean_absolute_error: 0.1201
# Epoch 83/100
# 168/168 [==============================] - 0s 181us/sample - loss: 0.1198 - mean_absolute_error: 0.1198
# Epoch 84/100
# 168/168 [==============================] - 0s 187us/sample - loss: 0.1200 - mean_absolute_error: 0.1200
# Epoch 85/100
# 168/168 [==============================] - 0s 146us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 86/100
# 168/168 [==============================] - 0s 104us/sample - loss: 0.1206 - mean_absolute_error: 0.1206
# Epoch 87/100
# 168/168 [==============================] - 0s 143us/sample - loss: 0.1201 - mean_absolute_error: 0.1201
# Epoch 88/100
# 168/168 [==============================] - 0s 106us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 89/100
# 168/168 [==============================] - 0s 100us/sample - loss: 0.1194 - mean_absolute_error: 0.1194
# Epoch 90/100
# 168/168 [==============================] - 0s 187us/sample - loss: 0.1201 - mean_absolute_error: 0.1201
# Epoch 91/100
# 168/168 [==============================] - 0s 73us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 92/100
# 168/168 [==============================] - 0s 174us/sample - loss: 0.1195 - mean_absolute_error: 0.1195
# Epoch 93/100
# 168/168 [==============================] - 0s 83us/sample - loss: 0.1198 - mean_absolute_error: 0.1198
# Epoch 94/100
# 168/168 [==============================] - 0s 201us/sample - loss: 0.1197 - mean_absolute_error: 0.1197
# Epoch 95/100
# 168/168 [==============================] - 0s 75us/sample - loss: 0.1194 - mean_absolute_error: 0.1194
# Epoch 96/100
# 168/168 [==============================] - 0s 159us/sample - loss: 0.1205 - mean_absolute_error: 0.1205
# Epoch 97/100
# 168/168 [==============================] - 0s 124us/sample - loss: 0.1192 - mean_absolute_error: 0.1192
# Epoch 98/100
# 168/168 [==============================] - 0s 179us/sample - loss: 0.1193 - mean_absolute_error: 0.1193
# Epoch 99/100
# 168/168 [==============================] - 0s 132us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 100/100
# 168/168 [==============================] - 0s 185us/sample - loss: 0.1193 - mean_absolute_error: 0.1193
# Gráficos com lag 5
# Train on 166 samples
# Epoch 1/100
# 166/166 [==============================] - 0s 2ms/sample - loss: 0.2957 - mean_absolute_error: 0.2957
# Epoch 2/100
# 166/166 [==============================] - 0s 119us/sample - loss: 0.2429 - mean_absolute_error: 0.2429
# Epoch 3/100
# 166/166 [==============================] - 0s 145us/sample - loss: 0.1990 - mean_absolute_error: 0.1990
# Epoch 4/100
# 166/166 [==============================] - 0s 154us/sample - loss: 0.1779 - mean_absolute_error: 0.1779
# Epoch 5/100
# 166/166 [==============================] - 0s 147us/sample - loss: 0.1731 - mean_absolute_error: 0.1731
# Epoch 6/100
# 166/166 [==============================] - 0s 137us/sample - loss: 0.1721 - mean_absolute_error: 0.1721
# Epoch 7/100
# 166/166 [==============================] - 0s 121us/sample - loss: 0.1692 - mean_absolute_error: 0.1692
# Epoch 8/100
# 166/166 [==============================] - 0s 134us/sample - loss: 0.1642 - mean_absolute_error: 0.1642
# Epoch 9/100
# 166/166 [==============================] - 0s 139us/sample - loss: 0.1600 - mean_absolute_error: 0.1600
# Epoch 10/100
# 166/166 [==============================] - 0s 54us/sample - loss: 0.1569 - mean_absolute_error: 0.1569
# Epoch 11/100
# 166/166 [==============================] - 0s 74us/sample - loss: 0.1543 - mean_absolute_error: 0.1543
# Epoch 12/100
# 166/166 [==============================] - 0s 154us/sample - loss: 0.1521 - mean_absolute_error: 0.1521
# Epoch 13/100
# 166/166 [==============================] - 0s 141us/sample - loss: 0.1498 - mean_absolute_error: 0.1498
# Epoch 14/100
# 166/166 [==============================] - 0s 133us/sample - loss: 0.1488 - mean_absolute_error: 0.1488
# Epoch 15/100
# 166/166 [==============================] - ETA: 0s - loss: 0.1244 - mean_absolute_error: 0.124 - 0s 106us/sample - loss: 0.1462 - mean_absolute_error: 0.1462
# Epoch 16/100
# 166/166 [==============================] - 0s 80us/sample - loss: 0.1445 - mean_absolute_error: 0.1445
# Epoch 17/100
# 166/166 [==============================] - 0s 84us/sample - loss: 0.1421 - mean_absolute_error: 0.1421
# Epoch 18/100
# 166/166 [==============================] - 0s 115us/sample - loss: 0.1397 - mean_absolute_error: 0.1397
# Epoch 19/100
# 166/166 [==============================] - 0s 136us/sample - loss: 0.1376 - mean_absolute_error: 0.1376
# Epoch 20/100
# 166/166 [==============================] - 0s 103us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 21/100
# 166/166 [==============================] - 0s 148us/sample - loss: 0.1349 - mean_absolute_error: 0.1349
# Epoch 22/100
# 166/166 [==============================] - 0s 102us/sample - loss: 0.1318 - mean_absolute_error: 0.1318
# Epoch 23/100
# 166/166 [==============================] - 0s 130us/sample - loss: 0.1305 - mean_absolute_error: 0.1305
# Epoch 24/100
# 166/166 [==============================] - 0s 158us/sample - loss: 0.1288 - mean_absolute_error: 0.1288
# Epoch 25/100
# 166/166 [==============================] - 0s 111us/sample - loss: 0.1264 - mean_absolute_error: 0.1264
# Epoch 26/100
# 166/166 [==============================] - 0s 140us/sample - loss: 0.1246 - mean_absolute_error: 0.1246
# Epoch 27/100
# 166/166 [==============================] - 0s 108us/sample - loss: 0.1232 - mean_absolute_error: 0.1232
# Epoch 28/100
# 166/166 [==============================] - 0s 141us/sample - loss: 0.1219 - mean_absolute_error: 0.1219
# Epoch 29/100
# 166/166 [==============================] - 0s 113us/sample - loss: 0.1219 - mean_absolute_error: 0.1219
# Epoch 30/100
# 166/166 [==============================] - 0s 158us/sample - loss: 0.1208 - mean_absolute_error: 0.1208
# Epoch 31/100
# 166/166 [==============================] - 0s 115us/sample - loss: 0.1208 - mean_absolute_error: 0.1208
# Epoch 32/100
# 166/166 [==============================] - 0s 133us/sample - loss: 0.1206 - mean_absolute_error: 0.1206
# Epoch 33/100
# 166/166 [==============================] - ETA: 0s - loss: 0.1506 - mean_absolute_error: 0.150 - 0s 103us/sample - loss: 0.1192 - mean_absolute_error: 0.1192
# Epoch 34/100
# 166/166 [==============================] - 0s 97us/sample - loss: 0.1186 - mean_absolute_error: 0.1186
# Epoch 35/100
# 166/166 [==============================] - 0s 182us/sample - loss: 0.1183 - mean_absolute_error: 0.1183
# Epoch 36/100
# 166/166 [==============================] - 0s 82us/sample - loss: 0.1172 - mean_absolute_error: 0.1172
# Epoch 37/100
# 166/166 [==============================] - 0s 144us/sample - loss: 0.1194 - mean_absolute_error: 0.1194
# Epoch 38/100
# 166/166 [==============================] - 0s 120us/sample - loss: 0.1187 - mean_absolute_error: 0.1187
# Epoch 39/100
# 166/166 [==============================] - 0s 140us/sample - loss: 0.1173 - mean_absolute_error: 0.1173
# Epoch 40/100
# 166/166 [==============================] - 0s 118us/sample - loss: 0.1164 - mean_absolute_error: 0.1164
# Epoch 41/100
# 166/166 [==============================] - 0s 86us/sample - loss: 0.1162 - mean_absolute_error: 0.1162
# Epoch 42/100
# 166/166 [==============================] - 0s 181us/sample - loss: 0.1162 - mean_absolute_error: 0.1162
# Epoch 43/100
# 166/166 [==============================] - 0s 100us/sample - loss: 0.1157 - mean_absolute_error: 0.1157
# Epoch 44/100
# 166/166 [==============================] - 0s 97us/sample - loss: 0.1165 - mean_absolute_error: 0.1165
# Epoch 45/100
# 166/166 [==============================] - 0s 125us/sample - loss: 0.1154 - mean_absolute_error: 0.1154
# Epoch 46/100
# 166/166 [==============================] - 0s 101us/sample - loss: 0.1148 - mean_absolute_error: 0.1148
# Epoch 47/100
# 166/166 [==============================] - 0s 179us/sample - loss: 0.1162 - mean_absolute_error: 0.1162
# Epoch 48/100
# 166/166 [==============================] - 0s 95us/sample - loss: 0.1149 - mean_absolute_error: 0.1149
# Epoch 49/100
# 166/166 [==============================] - 0s 142us/sample - loss: 0.1145 - mean_absolute_error: 0.1145
# Epoch 50/100
# 166/166 [==============================] - 0s 113us/sample - loss: 0.1138 - mean_absolute_error: 0.1138
# Epoch 51/100
# 166/166 [==============================] - 0s 85us/sample - loss: 0.1147 - mean_absolute_error: 0.1147
# Epoch 52/100
# 166/166 [==============================] - 0s 81us/sample - loss: 0.1141 - mean_absolute_error: 0.1141
# Epoch 53/100
# 166/166 [==============================] - 0s 121us/sample - loss: 0.1133 - mean_absolute_error: 0.1133
# Epoch 54/100
# 166/166 [==============================] - 0s 109us/sample - loss: 0.1131 - mean_absolute_error: 0.1131
# Epoch 55/100
# 166/166 [==============================] - 0s 143us/sample - loss: 0.1129 - mean_absolute_error: 0.1129
# Epoch 56/100
# 166/166 [==============================] - 0s 121us/sample - loss: 0.1131 - mean_absolute_error: 0.1131
# Epoch 57/100
# 166/166 [==============================] - 0s 106us/sample - loss: 0.1130 - mean_absolute_error: 0.1130
# Epoch 58/100
# 166/166 [==============================] - 0s 133us/sample - loss: 0.1131 - mean_absolute_error: 0.1131
# Epoch 59/100
# 166/166 [==============================] - 0s 108us/sample - loss: 0.1122 - mean_absolute_error: 0.1122
# Epoch 60/100
# 166/166 [==============================] - 0s 137us/sample - loss: 0.1130 - mean_absolute_error: 0.1130
# Epoch 61/100
# 166/166 [==============================] - ETA: 0s - loss: 0.1029 - mean_absolute_error: 0.102 - 0s 119us/sample - loss: 0.1131 - mean_absolute_error: 0.1131
# Epoch 62/100
# 166/166 [==============================] - 0s 91us/sample - loss: 0.1121 - mean_absolute_error: 0.1121
# Epoch 63/100
# 166/166 [==============================] - 0s 82us/sample - loss: 0.1121 - mean_absolute_error: 0.1121
# Epoch 64/100
# 166/166 [==============================] - 0s 152us/sample - loss: 0.1124 - mean_absolute_error: 0.1124
# Epoch 65/100
# 166/166 [==============================] - 0s 126us/sample - loss: 0.1116 - mean_absolute_error: 0.1116
# Epoch 66/100
# 166/166 [==============================] - 0s 147us/sample - loss: 0.1125 - mean_absolute_error: 0.1125
# Epoch 67/100
# 166/166 [==============================] - 0s 149us/sample - loss: 0.1117 - mean_absolute_error: 0.1117
# Epoch 68/100
# 166/166 [==============================] - 0s 118us/sample - loss: 0.1119 - mean_absolute_error: 0.1119
# Epoch 69/100
# 166/166 [==============================] - 0s 87us/sample - loss: 0.1116 - mean_absolute_error: 0.1116
# Epoch 70/100
# 166/166 [==============================] - 0s 139us/sample - loss: 0.1110 - mean_absolute_error: 0.1110
# Epoch 71/100
# 166/166 [==============================] - 0s 116us/sample - loss: 0.1108 - mean_absolute_error: 0.1108
# Epoch 72/100
# 166/166 [==============================] - 0s 141us/sample - loss: 0.1113 - mean_absolute_error: 0.1113
# Epoch 73/100
# 166/166 [==============================] - 0s 106us/sample - loss: 0.1110 - mean_absolute_error: 0.1110
# Epoch 74/100
# 166/166 [==============================] - ETA: 0s - loss: 0.1296 - mean_absolute_error: 0.129 - 0s 120us/sample - loss: 0.1111 - mean_absolute_error: 0.1111
# Epoch 75/100
# 166/166 [==============================] - 0s 154us/sample - loss: 0.1106 - mean_absolute_error: 0.1106
# Epoch 76/100
# 166/166 [==============================] - 0s 156us/sample - loss: 0.1106 - mean_absolute_error: 0.1106
# Epoch 77/100
# 166/166 [==============================] - 0s 114us/sample - loss: 0.1113 - mean_absolute_error: 0.1113
# Epoch 78/100
# 166/166 [==============================] - 0s 90us/sample - loss: 0.1107 - mean_absolute_error: 0.1107
# Epoch 79/100
# 166/166 [==============================] - 0s 103us/sample - loss: 0.1103 - mean_absolute_error: 0.1103
# Epoch 80/100
# 166/166 [==============================] - 0s 160us/sample - loss: 0.1101 - mean_absolute_error: 0.1101
# Epoch 81/100
# 166/166 [==============================] - 0s 156us/sample - loss: 0.1108 - mean_absolute_error: 0.1108
# Epoch 82/100
# 166/166 [==============================] - 0s 110us/sample - loss: 0.1108 - mean_absolute_error: 0.1108
# Epoch 83/100
# 166/166 [==============================] - 0s 131us/sample - loss: 0.1101 - mean_absolute_error: 0.1101
# Epoch 84/100
# 166/166 [==============================] - 0s 103us/sample - loss: 0.1101 - mean_absolute_error: 0.1101
# Epoch 85/100
# 166/166 [==============================] - 0s 154us/sample - loss: 0.1100 - mean_absolute_error: 0.1100
# Epoch 86/100
# 166/166 [==============================] - 0s 94us/sample - loss: 0.1101 - mean_absolute_error: 0.1101
# Epoch 87/100
# 166/166 [==============================] - 0s 180us/sample - loss: 0.1095 - mean_absolute_error: 0.1095
# Epoch 88/100
# 166/166 [==============================] - 0s 93us/sample - loss: 0.1095 - mean_absolute_error: 0.1095
# Epoch 89/100
# 166/166 [==============================] - 0s 125us/sample - loss: 0.1094 - mean_absolute_error: 0.1094
# Epoch 90/100
# 166/166 [==============================] - 0s 109us/sample - loss: 0.1094 - mean_absolute_error: 0.1094
# Epoch 91/100
# 166/166 [==============================] - 0s 139us/sample - loss: 0.1096 - mean_absolute_error: 0.1096
# Epoch 92/100
# 166/166 [==============================] - 0s 170us/sample - loss: 0.1095 - mean_absolute_error: 0.1095
# Epoch 93/100
# 166/166 [==============================] - 0s 148us/sample - loss: 0.1102 - mean_absolute_error: 0.1102
# Epoch 94/100
# 166/166 [==============================] - 0s 100us/sample - loss: 0.1084 - mean_absolute_error: 0.1084
# Epoch 95/100
# 166/166 [==============================] - 0s 131us/sample - loss: 0.1108 - mean_absolute_error: 0.1108
# Epoch 96/100
# 166/166 [==============================] - 0s 55us/sample - loss: 0.1088 - mean_absolute_error: 0.1088
# Epoch 97/100
# 166/166 [==============================] - 0s 152us/sample - loss: 0.1100 - mean_absolute_error: 0.1100
# Epoch 98/100
# 166/166 [==============================] - 0s 71us/sample - loss: 0.1095 - mean_absolute_error: 0.1095
# Epoch 99/100
# 166/166 [==============================] - 0s 137us/sample - loss: 0.1090 - mean_absolute_error: 0.1090
# Epoch 100/100
# 166/166 [==============================] - 0s 97us/sample - loss: 0.1096 - mean_absolute_error: 0.1096
# Gráficos com lag 7

# %%
df_resultados
# Out:
#    Lags    MAPE    RMSE      R²    TIPO
# 0     3  2.4690  0.1450  0.4082  TREINO
# 1     5  2.4337  0.1394  0.4437  TREINO
# 2     7  2.1837  0.1301  0.5164  TREINO

# %% [markdown]
# # Utilizando função de ativação Sigmoid

# %%
trainingd = seleciona_colunas(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    n_input = train_X.shape[1] * train_X.shape[2]
    
    test_X = test_X.reshape((test_X.shape[0],n_input))
    
    train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(Dense(units = 10, activation = 'relu', input_dim = n_input))
    model.add(Dense(units = 21, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'sigmoid'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
         
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
df_resultados.describe()

# %%
trainingd = seleciona_colunas_od(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    n_input = train_X.shape[1] * train_X.shape[2]
    
    test_X = test_X.reshape((test_X.shape[0],n_input))
    
    train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(Dense(units = 10, activation = 'relu', input_dim = n_input))
    model.add(Dense(units = 21, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'sigmoid'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
         
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
df_resultados.describe()
