# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Dropout
from tensorflow.keras.callbacks import EarlyStopping

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (12,10)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
df = pd.read_csv(str_files + "cetesb_concatenado06semoutliers.csv",encoding='utf-8',sep=',')
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
def seleciona_colunas(trainingd):
    fph      = trainingd.iloc[:,0:1].values
        
    frame_completo = pd.DataFrame(list(zip(fph)),columns =['ph']) 
    
    return frame_completo

def seleciona_colunas_od(trainingd):
    fod      = trainingd.iloc[:,4:5].values
        
    frame_completo = pd.DataFrame(list(zip(fod)),columns =['od']) 
    
    return frame_completo

def pegar_dados_coluna_predita_train_test(trainingd,percent,index_coluna):
    data = trainingd.iloc[:,:].values
    train = trainingd.iloc[0:int(len(data)*percent),:].values  
    train_previsao = trainingd.iloc[0:int(len(data)*percent),index_coluna:index_coluna+1].values
    test = trainingd.iloc[len(train):,index_coluna:index_coluna+1].values
    
    print('Nº observações:', len(data))
    print('treino:',len(train))
    print('teste:',len(test))
    
    return train,train_previsao, test

#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
def normalizacao(train,test):
    sc = MinMaxScaler()
    testd = test
    train = sc.fit_transform(train)
    test = sc.fit_transform(test)    
    return train,test,testd

#Prepara o conjunto de dados em X e y, considerando a janela de visualização (lags).
#cy = coluna que será predita
def prepara_dados(dados,lags,cy):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i,:])
        y.append(dados[i, cy])
       
    return np.array(X), np.array(y)

#Calcula o MAPE
#Define função para calcular o MAPE
#def mape(y_pred,y_true):
 #   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def mape(y_pred,y_true):
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    '''  
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        
        print(real)
        mape = mape_sum/len(real)
    '''
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_true,y_pred)
    return rscore

def rquadrado(y_pred,y_true):
    #Soma Total dos Quadrados (STQ): mostra a variação de y em torno da própria média. 
    #É o somatório das diferenças entre o valor alvo real e sua média elevado ao quadrado.
    y_traco = np.mean(y_true)
    
    print('media y_true:', y_traco)
        
    stq = 0
    
    for s in y_true:
        a = s - y_traco
        st = a * a
        stq = stq + st
    
    print('Soma Total dos Quadrados (STQ):', stq[0])
    
    #Soma dos Quadrados dos Resíduos (SQU): variação de Y que não é explicada pelo modelo elaborado. 
    #É o somatório das diferenças entre o valor predito e o valor real elevados ao quadrado.
    squ = 0
    
    y_traco = np.mean(y_pred)
    print('media y_pred:', y_traco)
    
    for n in range(len(y_true)):
        a = y_true[n] - y_pred[n]
        st = a * a
        squ = squ + st
        
    print('Soma dos Quadrados dos Resíduos (SQU):',squ[0])
    print('\n')
    print('Fórmula do R²')
    print('\n')
    print('sqr = stq - squ')
    sqr = stq[0] - squ[0]
    print('R² = sqr/stq')
    sqr = sqr/stq[0]
    print('\n')
    return sqr

def correlacao_determinacao(dtframe,tipo):
    
    if (tipo == 0): #Treino
        resultado = dtframe.corr().previsao_treino.values[1] ** 2 
    else: #teste
        resultado = dtframe.corr().previsao_teste.values[1] ** 2 
    
    return resultado

def ajusta_array(array):
    lista = []
    
    for i in range(len(array)):
        lista.append(array[i][0])
        
    #print('ajusta array:',lista)
        
    return lista

def ajusta_lista(array):
    lista = []
    
    for i in range(len(array)):
        lista.append(array[i][0])
        
    #print('ajusta array:',lista)
        
    return lista

# %% [markdown]
# # Utilizando função de ativação Linear

# %%
trainingd = seleciona_colunas(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    #   n_input = train_X.shape[1] * train_X.shape[2]
    
    #  test_X = test_X.reshape((test_X.shape[0],n_input))
    
    #train_X = train_X.reshape((train_X.shape[0],n_input))
    
    #callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'linear'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])
    
    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
        
    #len(history.history['loss'])
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
        
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
df_resultados.describe()
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
trainingd = seleciona_colunas_od(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    #   n_input = train_X.shape[1] * train_X.shape[2]
    
    #  test_X = test_X.reshape((test_X.shape[0],n_input))
    
    #train_X = train_X.reshape((train_X.shape[0],n_input))
    
    #callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'linear'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])
    
    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
        
    #len(history.history['loss'])
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
        
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
df_resultados.describe()
# Out:
# Completo: 248
# treino: 173
# teste: 75
# (248, 1)

# %% [markdown]
# # Utilizando função de ativação Relu

# %%
trainingd = seleciona_colunas(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    #   n_input = train_X.shape[1] * train_X.shape[2]
    
    #  test_X = test_X.reshape((test_X.shape[0],n_input))
    
    #train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])
    
    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)

    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
        
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
df_resultados.describe()

# %%
trainingd = seleciona_colunas_od(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    #   n_input = train_X.shape[1] * train_X.shape[2]
    
    #  test_X = test_X.reshape((test_X.shape[0],n_input))
    
    #train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])
    
    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)

    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
        
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()
# Out:
# Train on 170 samples
# Epoch 1/100
# 170/170 [==============================] - 2s 9ms/sample - loss: 0.3881 - mean_absolute_error: 0.3881
# Epoch 2/100
# 170/170 [==============================] - 0s 228us/sample - loss: 0.3266 - mean_absolute_error: 0.3266
# Epoch 3/100
# 170/170 [==============================] - 0s 275us/sample - loss: 0.2714 - mean_absolute_error: 0.2714
# Epoch 4/100
# 170/170 [==============================] - 0s 297us/sample - loss: 0.2204 - mean_absolute_error: 0.2204
# Epoch 5/100
# 170/170 [==============================] - 0s 289us/sample - loss: 0.1721 - mean_absolute_error: 0.1721
# Epoch 6/100
# 170/170 [==============================] - 0s 352us/sample - loss: 0.1581 - mean_absolute_error: 0.1581
# Epoch 7/100
# 170/170 [==============================] - 0s 305us/sample - loss: 0.1665 - mean_absolute_error: 0.1665
# Epoch 8/100
# 170/170 [==============================] - 0s 253us/sample - loss: 0.1652 - mean_absolute_error: 0.1652
# Epoch 9/100
# 170/170 [==============================] - 0s 269us/sample - loss: 0.1548 - mean_absolute_error: 0.1548
# Epoch 10/100
# 170/170 [==============================] - 0s 290us/sample - loss: 0.1477 - mean_absolute_error: 0.1477
# Epoch 11/100
# 170/170 [==============================] - 0s 289us/sample - loss: 0.1636 - mean_absolute_error: 0.1636
# Epoch 12/100
# 170/170 [==============================] - 0s 314us/sample - loss: 0.1476 - mean_absolute_error: 0.1476
# Epoch 13/100
# 170/170 [==============================] - 0s 328us/sample - loss: 0.1585 - mean_absolute_error: 0.1585
# Epoch 14/100
# 170/170 [==============================] - 0s 266us/sample - loss: 0.1539 - mean_absolute_error: 0.1539
# Epoch 15/100
# 170/170 [==============================] - 0s 300us/sample - loss: 0.1626 - mean_absolute_error: 0.1626
# Epoch 16/100
# 170/170 [==============================] - 0s 318us/sample - loss: 0.1589 - mean_absolute_error: 0.1589
# Epoch 17/100
# 170/170 [==============================] - 0s 322us/sample - loss: 0.1575 - mean_absolute_error: 0.1575
# Epoch 18/100
# 170/170 [==============================] - 0s 171us/sample - loss: 0.1549 - mean_absolute_error: 0.1549
# Epoch 19/100
# 170/170 [==============================] - 0s 305us/sample - loss: 0.1485 - mean_absolute_error: 0.1485
# Epoch
# Epoch 95/100
# 168/168 [==============================] - 0s 224us/sample - loss: 0.1364 - mean_absolute_error: 0.1364
# Epoch 96/100
# 168/168 [==============================] - 0s 227us/sample - loss: 0.1413 - mean_absolute_error: 0.1413
# Epoch 97/100
# 168/168 [==============================] - 0s 303us/sample - loss: 0.1326 - mean_absolute_error: 0.1326
# Epoch 98/100
# 168/168 [==============================] - 0s 247us/sample - loss: 0.1435 - mean_absolute_error: 0.1435
# Epoch 99/100
# 168/168 [==============================] - 0s 268us/sample - loss: 0.1422 - mean_absolute_error: 0.1422
# Epoch 100/100
# 168/168 [==============================] - 0s 270us/sample - loss: 0.1360 - mean_absolute_error: 0.1360
# Gráficos com lag 5
# Train on 166 samples
# Epoch 1/100
# 166/166 [==============================] - 2s 10ms/sample - loss: 0.4503 - mean_absolute_error: 0.4503
# Epoch 2/100
# 166/166 [==============================] - 0s 225us/sample - loss: 0.3585 - mean_absolute_error: 0.3585
# Epoch 3/100
# 166/166 [==============================] - 0s 219us/sample - loss: 0.2753 - mean_absolute_error: 0.2753
# Epoch 4/100
# 166/166 [==============================] - 0s 238us/sample - loss: 0.2094 - mean_absolute_error: 0.2094
# Epoch 5/100
# 166/166 [==============================] - 0s 227us/sample - loss: 0.1626 - mean_absolute_error: 0.1626
# Epoch 6/100
# 166/166 [==============================] - 0s 222us/sample - loss: 0.1781 - mean_absolute_error: 0.1781
# Epoch 7/100
# 166/166 [==============================] - 0s 301us/sample - loss: 0.1689 - mean_absolute_error: 0.1689
# Epoch 8/100
# 166/166 [==============================] - 0s 249us/sample - loss: 0.1624 - mean_absolute_error: 0.1624
# Epoch 9/100
# 166/166 [==============================] - 0s 255us/sample - loss: 0.1596 - mean_absolute_error: 0.1596
# Epoch 10/100
# 166/166 [==============================] - 0s 314us/sample - loss: 0.1372 - mean_absolute_error: 0.1372
# Epoch 11/100
# 166/166 [==============================] - 0s 218us/sample - loss: 0.1557 - mean_absolute_error: 0.1557
# Epoch 12/100
# 166/166 [==============================] - 0s 217us/sample - loss: 0.1494 - mean_absolute_error: 0.1494
# Epoch 13/100
# 166/166 [==============================] - 0s 253us/sample - loss: 0.1521 - mean_absolute_error: 0.1521
# Epoch 14/100
# 166/166 [==============================] - 0s 270us/sample - loss: 0.1508 - mean_absolute_error: 0.1508
# Epoch 15/100
# 166/166 [==============================] - 0s 239us/sample - loss: 0.1507 - mean_absolute_error: 0.1507
# Epoch 16/100
# 166/166 [==============================] - 0s 234us/sample - loss: 0.1526 - mean_absolute_error: 0.1526
# Epoch 17/100
# 166/166 [==============================] - 0s 314us/sample - loss: 0.1480 - mean_absolute_error: 0.1480
# Epoch 18/100
# 166/166 [==============================] - 0s 302us/sample - loss: 0.1521 - mean_absolute_error: 0.1521
# Epoch 19/100
# 166/166 [==============================] - 0s 242us/sample - loss: 0.1496 - mean_absolute_error: 0.1496
# Epoch 20/100
# 166/166 [==============================] - 0s 259us/sample - loss: 0.1448 - mean_absolute_error: 0.1448
# Epoch 21/100
# 166/166 [==============================] - 0s 241us/sample - loss: 0.1357 - mean_absolute_error: 0.1357
# Epoch 22/100
# 166/166 [==============================] - 0s 336us/sample - loss: 0.1344 - mean_absolute_error: 0.1344
# Epoch 23/100
# 166/166 [==============================] - 0s 242us/sample - loss: 0.1497 - mean_absolute_error: 0.1497
# Epoch 24/100
# 166/166 [==============================] - 0s 272us/sample - loss: 0.1443 - mean_absolute_error: 0.1443
# Epoch 25/100
# 166/166 [==============================] - 0s 325us/sample - loss: 0.1450 - mean_absolute_error: 0.1450
# Epoch 26/100
# 166/166 [==============================] - 0s 251us/sample - loss: 0.1387 - mean_absolute_error: 0.1387
# Epoch 27/100
# 166/166 [==============================] - 0s 279us/sample - loss: 0.1512 - mean_absolute_error: 0.1512
# Epoch 28/100
# 166/166 [==============================] - 0s 266us/sample - loss: 0.1434 - mean_absolute_error: 0.1434
# Epoch 29/100
# 166/166 [==============================] - 0s 282us/sample - loss: 0.1503 - mean_absolute_error: 0.1503
# Epoch 30/100
# 166/166 [==============================] - 0s 290us/sample - loss: 0.1442 - mean_absolute_error: 0.1442
# Epoch 31/100
# 166/166 [==============================] - 0s 270us/sample - loss: 0.1452 - mean_absolute_error: 0.1452
# Epoch 32/100
# 166/166 [==============================] - 0s 289us/sample - loss: 0.1494 - mean_absolute_error: 0.1494
# Epoch 33/100
# 166/166 [==============================] - 0s 293us/sample - loss: 0.1537 - mean_absolute_error: 0.1537
# Epoch 34/100
# 166/166 [==============================] - 0s 231us/sample - loss: 0.1442 - mean_absolute_error: 0.1442
# Epoch 35/100
# 166/166 [==============================] - 0s 288us/sample - loss: 0.1376 - mean_absolute_error: 0.1376
# Epoch 36/100
# 166/166 [==============================] - 0s 331us/sample - loss: 0.1522 - mean_absolute_error: 0.1522
# Epoch 37/100
# 166/166 [==============================] - 0s 234us/sample - loss: 0.1405 - mean_absolute_error: 0.1405
# Epoch 38/100
# 166/166 [==============================] - 0s 292us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 39/100
# 166/166 [==============================] - 0s 229us/sample - loss: 0.1318 - mean_absolute_error: 0.1318
# Epoch 40/100
# 166/166 [==============================] - 0s 319us/sample - loss: 0.1477 - mean_absolute_error: 0.1477
# Epoch 41/100
# 166/166 [==============================] - 0s 286us/sample - loss: 0.1491 - mean_absolute_error: 0.1491
# Epoch 42/100
# 166/166 [==============================] - 0s 252us/sample - loss: 0.1402 - mean_absolute_error: 0.1402
# Epoch 43/100
# 166/166 [==============================] - 0s 294us/sample - loss: 0.1372 - mean_absolute_error: 0.1372
# Epoch 44/100
# 166/166 [==============================] - 0s 246us/sample - loss: 0.1446 - mean_absolute_error: 0.1446
# Epoch 45/100
# 166/166 [==============================] - 0s 321us/sample - loss: 0.1396 - mean_absolute_error: 0.1396
# Epoch 46/100
# 166/166 [==============================] - 0s 250us/sample - loss: 0.1428 - mean_absolute_error: 0.1428
# Epoch 47/100
# 166/166 [==============================] - 0s 291us/sample - loss: 0.1553 - mean_absolute_error: 0.1553
# Epoch 48/100
# 166/166 [==============================] - 0s 274us/sample - loss: 0.1519 - mean_absolute_error: 0.1519
# Epoch 49/100
# 166/166 [==============================] - 0s 231us/sample - loss: 0.1505 - mean_absolute_error: 0.1505
# Epoch 50/100
# 166/166 [==============================] - 0s 291us/sample - loss: 0.1446 - mean_absolute_error: 0.1446
# Epoch 51/100
# 166/166 [==============================] - 0s 320us/sample - loss: 0.1383 - mean_absolute_error: 0.1383
# Epoch 52/100
# 166/166 [==============================] - 0s 244us/sample - loss: 0.1477 - mean_absolute_error: 0.1477
# Epoch 53/100
# 166/166 [==============================] - 0s 258us/sample - loss: 0.1365 - mean_absolute_error: 0.1365
# Epoch 54/100
# 166/166 [==============================] - 0s 272us/sample - loss: 0.1468 - mean_absolute_error: 0.1468
# Epoch 55/100
# 166/166 [==============================] - 0s 232us/sample - loss: 0.1428 - mean_absolute_error: 0.1428
# Epoch 56/100
# 166/166 [==============================] - 0s 372us/sample - loss: 0.1376 - mean_absolute_error: 0.1376
# Epoch 57/100
# 166/166 [==============================] - 0s 254us/sample - loss: 0.1449 - mean_absolute_error: 0.1449
# Epoch 58/100
# 166/166 [==============================] - 0s 285us/sample - loss: 0.1414 - mean_absolute_error: 0.1414
# Epoch 59/100
# 166/166 [==============================] - 0s 298us/sample - loss: 0.1379 - mean_absolute_error: 0.1379
# Epoch 60/100
# 166/166 [==============================] - 0s 285us/sample - loss: 0.1501 - mean_absolute_error: 0.1501
# Epoch 61/100
# 166/166 [==============================] - 0s 311us/sample - loss: 0.1353 - mean_absolute_error: 0.1353
# Epoch 62/100
# 166/166 [==============================] - 0s 241us/sample - loss: 0.1337 - mean_absolute_error: 0.1337
# Epoch 63/100
# 166/166 [==============================] - 0s 284us/sample - loss: 0.1434 - mean_absolute_error: 0.1434
# Epoch 64/100
# 166/166 [==============================] - 0s 303us/sample - loss: 0.1459 - mean_absolute_error: 0.1459
# Epoch 65/100
# 166/166 [==============================] - 0s 238us/sample - loss: 0.1446 - mean_absolute_error: 0.1446
# Epoch 66/100
# 166/166 [==============================] - 0s 240us/sample - loss: 0.1346 - mean_absolute_error: 0.1346
# Epoch 67/100
# 166/166 [==============================] - 0s 233us/sample - loss: 0.1386 - mean_absolute_error: 0.1386
# Epoch 68/100
# 166/166 [==============================] - 0s 301us/sample - loss: 0.1303 - mean_absolute_error: 0.1303
# Epoch 69/100
# 166/166 [==============================] - 0s 265us/sample - loss: 0.1439 - mean_absolute_error: 0.1439
# Epoch 70/100
# 166/166 [==============================] - 0s 240us/sample - loss: 0.1435 - mean_absolute_error: 0.1435
# Epoch 71/100
# 166/166 [==============================] - 0s 299us/sample - loss: 0.1532 - mean_absolute_error: 0.1532
# Epoch 72/100
# 166/166 [==============================] - 0s 243us/sample - loss: 0.1448 - mean_absolute_error: 0.1448
# Epoch 73/100
# 166/166 [==============================] - 0s 316us/sample - loss: 0.1366 - mean_absolute_error: 0.1366
# Epoch 74/100
# 166/166 [==============================] - 0s 246us/sample - loss: 0.1370 - mean_absolute_error: 0.1370
# Epoch 75/100
# 166/166 [==============================] - 0s 304us/sample - loss: 0.1399 - mean_absolute_error: 0.1399
# Epoch 76/100
# 166/166 [==============================] - 0s 271us/sample - loss: 0.1391 - mean_absolute_error: 0.1391
# Epoch 77/100
# 166/166 [==============================] - 0s 223us/sample - loss: 0.1329 - mean_absolute_error: 0.1329
# Epoch 78/100
# 166/166 [==============================] - 0s 220us/sample - loss: 0.1357 - mean_absolute_error: 0.1357
# Epoch 79/100
# 166/166 [==============================] - 0s 359us/sample - loss: 0.1408 - mean_absolute_error: 0.1408
# Epoch 80/100
# 166/166 [==============================] - 0s 247us/sample - loss: 0.1363 - mean_absolute_error: 0.1363
# Epoch 81/100
# 166/166 [==============================] - 0s 269us/sample - loss: 0.1362 - mean_absolute_error: 0.1362
# Epoch 82/100
# 166/166 [==============================] - 0s 259us/sample - loss: 0.1341 - mean_absolute_error: 0.1341
# Epoch 83/100
# 166/166 [==============================] - 0s 234us/sample - loss: 0.1413 - mean_absolute_error: 0.1413
# Epoch 84/100
# 166/166 [==============================] - 0s 229us/sample - loss: 0.1377 - mean_absolute_error: 0.1377
# Epoch 85/100
# 166/166 [==============================] - 0s 246us/sample - loss: 0.1361 - mean_absolute_error: 0.1361
# Epoch 86/100
# 166/166 [==============================] - 0s 250us/sample - loss: 0.1370 - mean_absolute_error: 0.1370
# Epoch 87/100
# 166/166 [==============================] - 0s 272us/sample - loss: 0.1367 - mean_absolute_error: 0.1367
# Epoch 88/100
# 166/166 [==============================] - 0s 292us/sample - loss: 0.1393 - mean_absolute_error: 0.1393
# Epoch 89/100
# 166/166 [==============================] - 0s 281us/sample - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 90/100
# 166/166 [==============================] - 0s 270us/sample - loss: 0.1407 - mean_absolute_error: 0.1407
# Epoch 91/100
# 166/166 [==============================] - 0s 274us/sample - loss: 0.1390 - mean_absolute_error: 0.1390
# Epoch 92/100
# 166/166 [==============================] - 0s 190us/sample - loss: 0.1333 - mean_absolute_error: 0.1333
# Epoch 93/100
# 166/166 [==============================] - 0s 379us/sample - loss: 0.1417 - mean_absolute_error: 0.1417
# Epoch 94/100
# 166/166 [==============================] - 0s 330us/sample - loss: 0.1387 - mean_absolute_error: 0.1387
# Epoch 95/100
# 166/166 [==============================] - 0s 291us/sample - loss: 0.1413 - mean_absolute_error: 0.1413
# Epoch 96/100
# 166/166 [==============================] - 0s 233us/sample - loss: 0.1389 - mean_absolute_error: 0.1389
# Epoch 97/100
# 166/166 [==============================] - 0s 234us/sample - loss: 0.1306 - mean_absolute_error: 0.1306
# Epoch 98/100
# 166/166 [==============================] - 0s 277us/sample - loss: 0.1278 - mean_absolute_error: 0.1278
# Epoch 99/100
# 166/166 [==============================] - 0s 319us/sample - loss: 0.1338 - mean_absolute_error: 0.1338
# Epoch 100/100
# 166/166 [==============================] - 0s 274us/sample - loss: 0.1382 - mean_absolute_error: 0.1382
# Gráficos com lag 7

# %%
df_resultados.describe()
# Out:
#    Lags    MAPE    RMSE      R²    TIPO
# 0     3  2.5888  0.1450  0.4084  TREINO
# 1     5  2.5262  0.1428  0.4164  TREINO
# 2     7  2.5048  0.1423  0.4212  TREINO

# %% [markdown]
# # Utilizando função de ativação Sigmoid

# %%
trainingd = seleciona_colunas(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    #   n_input = train_X.shape[1] * train_X.shape[2]
    
    #  test_X = test_X.reshape((test_X.shape[0],n_input))
    
    #train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])


    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
        
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
df_resultados.describe()

# %%
trainingd = seleciona_colunas_od(df)

df_resultados_treino = pd.DataFrame()
df_resultados_teste = pd.DataFrame()
df_resultados = pd.DataFrame()

#lags = (3,5,7) 
for l in range(1, 21):
    
    lags = l
    
    #seleciona os dados
    
    train,train_previsao, test = pegar_dados_coluna_predita_train_test(trainingd,0.70,0) 
    
    #normalização dos dados
    train,test,testd = normalizacao(train,test)
    normalizador_previsao = MinMaxScaler()
    sc = MinMaxScaler()
    normalizador_previsao.fit_transform(train_previsao)
    
    #Prepara os dados de treinamento
    #Vai predizer o valor da coluna 4 (valor ph)
    train_X, train_y = prepara_dados(train, lags,0)
    
    #Prepara os dados de teste
    entradas = trainingd[len(trainingd) - len(test) - lags:].values
    entradas = sc.fit_transform(entradas)   
    
    test_X = []
    for i in range(lags, lags+len(test)):
        test_X.append(entradas[i-lags:i, 0:1])
    test_X = np.array(test_X)
    
    #Nivelar entrada
    #   n_input = train_X.shape[1] * train_X.shape[2]
    
    #  test_X = test_X.reshape((test_X.shape[0],n_input))
    
    #train_X = train_X.reshape((train_X.shape[0],n_input))

    model = Sequential()
    model.add(LSTM(units = 10, input_shape = (train_X.shape[1], 1)))
    model.add(Dense(10, activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])


    es = EarlyStopping(monitor='val_loss', patience = 3, verbose=1)


    #Treina o modelo
    history = model.fit(train_X, train_y, validation_data=(test_X, test), batch_size = 32, epochs = 2000, 
                        callbacks=[es], verbose=0)
    
    #Dados de teste
    previsoes = model.predict(test_X)
    #previsoes = previsoes.reshape(-1, 1)
    previsoes = normalizador_previsao.inverse_transform(previsoes)
           
    print('Teste - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(testd,color='red',label = 'Observado')
    plt.plot(previsoes,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
    
    #Dados de treino
    previsoes_treino = model.predict(train_X)
    previsoes_treino = previsoes_treino.reshape(-1, 1)
    previsoes_treino = normalizador_previsao.inverse_transform(previsoes_treino)
    
    treino = train_previsao[lags: len(previsoes_treino) + lags, :]
    observado_test = testd
    
    observado_treino = train_previsao  
        
    print('Treinamento - Gráficos com lag', l)
    #Plotagem do gráfico
    plt.plot(train_previsao,color='red',label = 'Observado')
    plt.plot(previsoes_treino,color='blue',label = 'Previsoes')
    plt.xlabel('Tempo')
    plt.ylabel('Valor pH')
    plt.legend()
    plt.show()
            
    treino         = ajusta_array(treino)
    observado_test = ajusta_array(observado_test)
               
    #Calculo do erro da previsão MAPE, RMSE e R²
    
    observado_treino_d = observado_treino
    previsoes_treino_d = previsoes_treino
    previsoes_d        = previsoes
          
    mape_treino_d        = round(mape(previsoes_treino,treino),4)
    rmse_treino_d        = round(rmse(previsoes_treino,treino),4)
    #r_treino_d           = round(r2(previsoes_treino,treino),4)
        
    mape_teste_d        = round(mape(previsoes,observado_test),4)
    rmse_teste_d        = round(rmse(previsoes,observado_test),4)
    #r_teste_d           = round(r2(previsoes,observado_test),4) 
       
    df_corr_determinacao_treino = pd.DataFrame()
    df_corr_determinacao_teste  = pd.DataFrame()
    
    #Calcula o coeficiente de determinação
    dict = {'previsao_treino': ajusta_lista(previsoes_treino), 'treino': ajusta_array(treino)} 
    
    df_treino = pd.DataFrame(dict)
    dframes_treino = [df_corr_determinacao_treino,df_treino]
    df_corr_determinacao_treino = pd.concat(dframes_treino)
    
    dict = {'previsao_teste': ajusta_lista(previsoes), 'teste': ajusta_array(observado_test)} 
    
    df_teste = pd.DataFrame(dict)
    dframes_teste = [df_corr_determinacao_teste,df_teste]
    df_corr_determinacao_teste = pd.concat(dframes_teste)
    
    r_treino_d = []
    r_teste_d  = []
    
    r_treino_d.append(round(correlacao_determinacao(df_corr_determinacao_treino,0),4))
    r_teste_d.append(round(correlacao_determinacao(df_corr_determinacao_teste,1),4))
    
    lag_treino = []
    lag_teste = []
    
    lag_treino.append(lags)
    lag_teste.append(lags)
        
    # dictionary of lists  
    
    dict = {'lags_treino': lag_treino, 'mape_treino': mape_treino_d, 'rmse_treino': rmse_treino_d,'r_quad_treino':r_treino_d,
            'lags_teste': lag_teste, 'mape_teste': mape_teste_d, 'rmse_teste': rmse_teste_d,'r_quad_teste':r_teste_d} 
    
    df_result = pd.DataFrame(dict)
    dframes = [df_resultados,df_result]
    df_resultados = pd.concat(dframes)
    
    # plot training history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

# %%
df_resultados.describe()
