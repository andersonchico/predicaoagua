# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Dropout

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

ugrhi10 = trainingd

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
ugrhi10
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '06 - ALTO TIÊTE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [251 rows x 1 columns]

# %%
for field in trainingd.columns:
    print(field, 'NaN:', trainingd[field].isnull().sum())
# Out:
# valor NaN: 2

# %%
trainingd = trainingd.dropna(axis=0,how='any')

# %%
for field in trainingd.columns:
    print(field, 'NaN:', trainingd[field].isnull().sum())
trainingd
# Out:
# valor NaN: 0
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [249 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < inferior.valor)]

outlier
# Out:
# primeiro_quartil: valor    6.583333
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.002667
# Name: 0.75, dtype: float64
# fig: valor    0.419333
# dtype: float64
# Inferior: valor    5.954333
# dtype: float64
# Superior: valor    7.631667
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                 valor
# data_coleta
# 1979-11-30   5.916667
# 1985-03-31   5.883333

# %%
trainingd
# Out:
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [249 rows x 1 columns]

# %%
#Remove a última linha do dataframe
trainingd = trainingd.drop(trainingd[trainingd.index == '2019-09-30'].index)

# %%
trainingd.describe()
# Out:
#             valor
# count  248.000000
# mean     6.793328
# std      0.294764
# min      5.883333
# 25%      6.581944
# 50%      6.838095
# 75%      7.001821
# max      7.405000

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingds.valor < inferior.valor] = 6.79

ugrhi06 = trainingd

outlier = trainingd[(trainingd.valor < inferior.valor)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
#Dados completo.
#data = trainingd.iloc[:,:].values
#treino (70%)
train10 = ugrhi10.iloc[0:174,:].values  
train06 = ugrhi06.iloc[0:174,:].values

#teste (30%)
test10 = ugrhi10.iloc[174:,:].values 
test06 = ugrhi06.iloc[174:,:].values

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
sc = MinMaxScaler()
train10 = sc.fit_transform(train10)
#train06 = sc.fit_transform(train06)
test10 = sc.fit_transform(test10)
test06 = sc.fit_transform(test06)

# %%
#X = ugrhi10
#y = ugrhi06

#assert X.shape == (len(X),1)
#assert y.shape == (len(y),1)

# %%
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

# %%
lags = 17 # Equivalente à 25% dos dados de treino.
#Prepara os dados de treinamento
X_train10, y_train10 = prepara_dados(train10, lags)

X_train10 = np.reshape(X_train10, (X_train10.shape[0], X_train10.shape[1], 1))
    
#Prepara os dados de teste
entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
entradas10 = entradas10.reshape(-1, 1)
entradas10 = sc.fit_transform(entradas10)

X_test10 = []
for i in range(lags, lags+len(test10)):
    X_test10.append(entradas10[i-lags:i, 0])
X_test10 = np.array(X_test10)
X_test10 = np.reshape(X_test10, (X_test10.shape[0], X_test10.shape[1], 1))

# %%
#Prepara os dados de teste06
entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
entradas06 = entradas06.reshape(-1, 1)
entradas06 = sc.fit_transform(entradas06)

X_test06 = []
for i in range(lags, lags+len(test06)):
    X_test06.append(entradas06[i-lags:i, 0])
X_test06 = np.array(X_test06)
X_test06 = np.reshape(X_test06, (X_test06.shape[0], X_test06.shape[1], 1))

# %%
#Cria o modelo

model = Sequential()
model.add(LSTM(units = 10, input_shape = (X_train10.shape[1], 1)))
model.add(Dense(10, activation = 'linear'))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'linear'))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

#Treina o modelo
model.fit(X_train10, y_train10, batch_size = 32, epochs = 100)

y_pred10 = model.predict(X_test06)
y_pred10 = y_pred10.reshape(-1, 1)
y_pred10 = sc.inverse_transform(y_pred10)

#X_test = sc.inverse_transform(X_test)
#y_test = sc.inverse_transform(y_test)
# Out:
# Train on 157 samples
# Epoch 1/100
# 157/157 [==============================] - 2s 10ms/sample - loss: 0.4628 - mean_absolute_error: 0.4628
# Epoch 2/100
# 157/157 [==============================] - 0s 452us/sample - loss: 0.3840 - mean_absolute_error: 0.3840
# Epoch 3/100
# 157/157 [==============================] - 0s 541us/sample - loss: 0.2964 - mean_absolute_error: 0.2964
# Epoch 4/100
# 157/157 [==============================] - 0s 578us/sample - loss: 0.2364 - mean_absolute_error: 0.2364
# Epoch 5/100
# 157/157 [==============================] - 0s 706us/sample - loss: 0.1761 - mean_absolute_error: 0.1761
# Epoch 6/100
# 157/157 [==============================] - 0s 732us/sample - loss: 0.1577 - mean_absolute_error: 0.1577
# Epoch 7/100
# 157/157 [==============================] - 0s 646us/sample - loss: 0.1647 - mean_absolute_error: 0.1647
# Epoch 8/100
# 157/157 [==============================] - 0s 642us/sample - loss: 0.1513 - mean_absolute_error: 0.1513
# Epoch 9/100
# 157/157 [==============================] - 0s 697us/sample - loss: 0.1585 - mean_absolute_error: 0.1585
# Epoch 10/100
# 157/157 [==============================] - 0s 672us/sample - loss: 0.1587 - mean_absolute_error: 0.1587
# Epoch 11/100
# 157/157 [==============================] - 0s 644us/sample - loss: 0.1664 - mean_absolute_error: 0.1664
# Epoch 12/100
# 157/157 [==============================] - 0s 721us/sample - loss: 0.1562 - mean_absolute_error: 0.1562
# Epoch 13/100
# 157/157 [==============================] - 0s 644us/sample - loss: 0.1691 - mean_absolute_error: 0.1691
# Epoch 14/100
# 157/157 [==============================] - 0s 647us/sample - loss: 0.1591 - mean_absolute_error: 0.1591
# Epoch 15/100
# 157/157 [==============================] - 0s 669us/sample - loss: 0.1448 - mean_absolute_error: 0.1448
# Epoch 16/100
# 157/157 [==============================] - 0s 666us/sample - loss: 0.1470 - mean_absolute_error: 0.1470
# Epoch 17/100
# 157/157 [==============================] - 0s 653us/sample - loss: 0.1492 - mean_absolute_error: 0.1492
# Epoch 18/100
# 157/157 [==============================] - 0s 663us/sample - loss: 0.1600 - mean_absolute_error: 0.1600
# Epoch 19/100
# 157/157 [==============================] - 0s 696us/sample - loss: 0.1615 - mean_absolute_error: 0.1615
# Epoch 20/100
# 157/157 [==============================] - 0s 659us/sample - loss: 0.1506 - mean_absolute_error: 0.1506
# Epoch 21/100
# 157/157 [==============================] - 0s 625us/sample - loss: 0.1439 - mean_absolute_error: 0.1439
# Epoch 22/100
# 157/157 [==============================] - 0s 659us/sample - loss: 0.1538 - mean_absolute_error: 0.1538
# Epoch 23/100
# 157/157 [==============================] - 0s 682us/sample - loss: 0.1552 - mean_absolute_error: 0.1552
# Epoch 24/100
# 157/157 [==============================] - 0s 685us/sample - loss: 0.1480 - mean_absolute_error: 0.1480
# Epoch 25/100
# 157/157 [==============================] - 0s 693us/sample - loss: 0.1485 - mean_absolute_error: 0.1485
# Epoch 26/100
# 157/157 [==============================] - 0s 690us/sample - loss: 0.1488 - mean_absolute_error: 0.1488
# Epoch 27/100
# 157/157 [==============================] - 0s 692us/sample - loss: 0.1508 - mean_absolute_error: 0.1508
# Epoch 28/100
# 157/157 [==============================] - 0s 687us/sample - loss: 0.1483 - mean_absolute_error: 0.1483
# Epoch 29/100
# 157/157 [==============================] - 0s 693us/sample - loss: 0.1382 - mean_absolute_error: 0.1382
# Epoch 30/100
# 157/157 [==============================] - 0s 531us/sample - loss: 0.1453 - mean_absolute_error: 0.1453
# Epoch 31/100
# 157/157 [==============================] - 0s 689us/sample - loss: 0.1401 - mean_absolute_error: 0.1401
# Epoch 32/100
# 157/157 [==============================] - 0s 626us/sample - loss: 0.1499 - mean_absolute_error: 0.1499
# Epoch 33/100
# 157/157 [==============================] - 0s 751us/sample - loss: 0.1449 - mean_absolute_error: 0.1449
# Epoch 34/100
# 157/157 [==============================] - 0s 485us/sample - loss: 0.1494 - mean_absolute_error: 0.1494
# Epoch 35/100
# 157/157 [==============================] - 0s 659us/sample - loss: 0.1417 - mean_absolute_error: 0.1417
# Epoch 36/100
# 157/157 [==============================] - 0s 738us/sample - loss: 0.1449 - mean_absolute_error: 0.1449
# Epoch 37/100
# 157/157 [==============================] - 0s 729us/sample - loss: 0.1454 - mean_absolute_error: 0.1454
# Epoch 38/100
# 157/157 [==============================] - 0s 733us/sample - loss: 0.1404 - mean_absolute_error: 0.1404
# Epoch 39/100
# 157/157 [==============================] - 0s 735us/sample - loss: 0.1372 - mean_absolute_error: 0.1372
# Epoch 40/100
# 157/157 [==============================] - 0s 539us/sample - loss: 0.1534 - mean_absolute_error: 0.1534
# Epoch 41/100
# 157/157 [==============================] - 0s 636us/sample - loss: 0.1367 - mean_absolute_error: 0.1367
# Epoch 42/100
# 157/157 [==============================] - 0s 534us/sample - loss: 0.1417 - mean_absolute_error: 0.1417
# Epoch 43/100
# 157/157 [==============================] - 0s 659us/sample - loss: 0.1378 - mean_absolute_error: 0.1378
# Epoch 44/100
# 157/157 [==============================] - 0s 698us/sample - loss: 0.1371 - mean_absolute_error: 0.1371
# Epoch 45/100
# 157/157 [==============================] - 0s 711us/sample - loss: 0.1329 - mean_absolute_error: 0.1329
# Epoch 46/100
# 157/157 [==============================] - 0s 761us/sample - loss: 0.1273 - mean_absolute_error: 0.1273
# Epoch 47/100
# 157/157 [==============================] - 0s 713us/sample - loss: 0.1419 - mean_absolute_error: 0.1419
# Epoch 48/100
# 157/157 [==============================] - 0s 708us/sample - loss: 0.1375 - mean_absolute_error: 0.1375
# Epoch 49/100
# 157/157 [==============================] - 0s 695us/sample - loss: 0.1450 - mean_absolute_error: 0.1450
# Epoch 50/100
# 157/157 [==============================] - 0s 590us/sample - loss: 0.1311 - mean_absolute_error: 0.1311
# Epoch 51/100
# 157/157 [==============================] - 0s 760us/sample - loss: 0.1410 - mean_absolute_error: 0.1410
# Epoch 52/100
# 157/157 [==============================] - 0s 710us/sample - loss: 0.1516 - mean_absolute_error: 0.1516
# Epoch 53/100
# 157/157 [==============================] - 0s 687us/sample - loss: 0.1379 - mean_absolute_error: 0.1379
# Epoch 54/100
# 157/157 [==============================] - 0s 575us/sample - loss: 0.1416 - mean_absolute_error: 0.1416
# Epoch 55/100
# 157/157 [==============================] - 0s 427us/sample - loss: 0.1420 - mean_absolute_error: 0.1420
# Epoch 56/100
# 157/157 [==============================] - 0s 594us/sample - loss: 0.1529 - mean_absolute_error: 0.1529
# Epoch 57/100
# 157/157 [==============================] - 0s 554us/sample - loss: 0.1354 - mean_absolute_error: 0.1354
# Epoch 58/100
# 157/157 [==============================] - 0s 609us/sample - loss: 0.1447 - mean_absolute_error: 0.1447
# Epoch 59/100
# 157/157 [==============================] - 0s 575us/sample - loss: 0.1515 - mean_absolute_error: 0.1515
# Epoch 60/100
# 157/157 [==============================] - 0s 641us/sample - loss: 0.1379 - mean_absolute_error: 0.1379
# Epoch 61/100
# 157/157 [==============================] - 0s 617us/sample - loss: 0.1362 - mean_absolute_error: 0.1362
# Epoch 62/100
# 157/157 [==============================] - 0s 621us/sample - loss: 0.1298 - mean_absolute_error: 0.1298
# Epoch 63/100
# 157/157 [==============================] - 0s 505us/sample - loss: 0.1400 - mean_absolute_error: 0.1400
# Epoch 64/100
# 157/157 [==============================] - 0s 536us/sample - loss: 0.1272 - mean_absolute_error: 0.1272
# Epoch 65/100
# 157/157 [==============================] - 0s 651us/sample - loss: 0.1318 - mean_absolute_error: 0.1318
# Epoch 66/100
# 157/157 [==============================] - 0s 681us/sample - loss: 0.1277 - mean_absolute_error: 0.1277
# Epoch 67/100
# 157/157 [==============================] - 0s 644us/sample - loss: 0.1391 - mean_absolute_error: 0.1391
# Epoch 68/100
# 157/157 [==============================] - 0s 615us/sample - loss: 0.1383 - mean_absolute_error: 0.1383
# Epoch 69/100
# 157/157 [==============================] - 0s 516us/sample - loss: 0.1299 - mean_absolute_error: 0.1299
# Epoch 70/100
# 157/157 [==============================] - 0s 671us/sample - loss: 0.1340 - mean_absolute_error: 0.1340
# Epoch 71/100
# 157/157 [==============================] - 0s 565us/sample - loss: 0.1292 - mean_absolute_error: 0.1292
# Epoch 72/100
# 157/157 [==============================] - 0s 328us/sample - loss: 0.1294 - mean_absolute_error: 0.1294
# Epoch 73/100
# 157/157 [==============================] - 0s 344us/sample - loss: 0.1360 - mean_absolute_error: 0.1360
# Epoch 74/100
# 157/157 [==============================] - 0s 375us/sample - loss: 0.1308 - mean_absolute_error: 0.1308
# Epoch 75/100
# 157/157 [==============================] - 0s 359us/sample - loss: 0.1352 - mean_absolute_error: 0.1352
# Epoch 76/100
# 157/157 [==============================] - 0s 325us/sample - loss: 0.1302 - mean_absolute_error: 0.1302
# Epoch 77/100
# 157/157 [==============================] - 0s 356us/sample - loss: 0.1393 - mean_absolute_error: 0.1393
# Epoch 78/100
# 157/157 [==============================] - 0s 335us/sample - loss: 0.1313 - mean_absolute_error: 0.1313
# Epoch 79/100
# 157/157 [==============================] - 0s 346us/sample - loss: 0.1326 - mean_absolute_error: 0.1326
# Epoch 80/100
# 157/157 [==============================] - 0s 364us/sample - loss: 0.1403 - mean_absolute_error: 0.1403
# Epoch 81/100
# 157/157 [==============================] - 0s 347us/sample - loss: 0.1280 - mean_absolute_error: 0.1280
# Epoch 82/100
# 157/157 [==============================] - 0s 341us/sample - loss: 0.1362 - mean_absolute_error: 0.1362
# Epoch 83/100
# 157/157 [==============================] - 0s 362us/sample - loss: 0.1403 - mean_absolute_error: 0.1403
# Epoch 84/100
# 157/157 [==============================] - 0s 328us/sample - loss: 0.1308 - mean_absolute_error: 0.1308
# Epoch 85/100
# 157/157 [==============================] - 0s 348us/sample - loss: 0.1311 - mean_absolute_error: 0.1311
# Epoch 86/100
# 157/157 [==============================] - 0s 360us/sample - loss: 0.1336 - mean_absolute_error: 0.1336
# Epoch 87/100
# 157/157 [==============================] - 0s 358us/sample - loss: 0.1414 - mean_absolute_error: 0.1414
# Epoch 88/100
# 157/157 [==============================] - 0s 321us/sample - loss: 0.1308 - mean_absolute_error: 0.1308
# Epoch 89/100
# 157/157 [==============================] - 0s 350us/sample - loss: 0.1317 - mean_absolute_error: 0.1317
# Epoch 90/100
# 157/157 [==============================] - 0s 340us/sample - loss: 0.1352 - mean_absolute_error: 0.1352
# Epoch 91/100
# 157/157 [==============================] - 0s 363us/sample - loss: 0.1264 - mean_absolute_error: 0.1264
# Epoch 92/100
# 157/157 [==============================] - 0s 319us/sample - loss: 0.1325 - mean_absolute_error: 0.1325
# Epoch 93/100
# 157/157 [==============================] - 0s 462us/sample - loss: 0.1302 - mean_absolute_error: 0.1302
# Epoch 94/100
# 157/157 [==============================] - 0s 387us/sample - loss: 0.1338 - mean_absolute_error: 0.1338
# Epoch 95/100
# 157/157 [==============================] - 0s 546us/sample - loss: 0.1333 - mean_absolute_error: 0.1333
# Epoch 96/100
# 157/157 [==============================] - 0s 361us/sample - loss: 0.1275 - mean_absolute_error: 0.1275
# Epoch 97/100
# 157/157 [==============================] - 0s 339us/sample - loss: 0.1417 - mean_absolute_error: 0.1417
# Epoch 98/100
# 157/157 [==============================] - 0s 364us/sample - loss: 0.1271 - mean_absolute_error: 0.1271
# Epoch 99/100
# 157/157 [==============================] - 0s 329us/sample - loss: 0.1310 - mean_absolute_error: 0.1310
# Epoch 100/100
# 157/157 [==============================] - 0s 439us/sample - loss: 0.1278 - mean_absolute_error: 0.1278

# %%
y_pred10t = model.predict(X_train10)
y_pred10t = y_pred10t.reshape(-1, 1)
y_pred10t = sc.inverse_transform(y_pred10t)

# %%
y_train10 = y_train10.reshape(-1, 1)
treino = sc.inverse_transform(y_train10)
#y_train10.shape

# %%
test06 = sc.inverse_transform(test06)

#Plotagem do gráfico
plt.plot(y_pred10, color = 'green', label = 'Observado UGRHI06')
plt.plot(test06, color = '#ff0066', label = 'Previsão UGRHI10')
plt.title('Predição do pH com lag = 10%')
plt.xlabel('Bimestre')
plt.ylabel('Valor pH')
plt.legend()
plt.grid()
plt.show()

# %%
def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_true,y_pred)
    return rscore

# %%
print('Resultados com lag', lags)
print('\n')
print('MAPE TREINO:',round(mape(y_pred10t,treino)[0],2),'%')
print('RMSE TREINO:',round(rmse(y_pred10t,treino),2))
print('R TREINO:',round(r2(y_pred10t,treino),2))
print('\n')
print('MAPE TESTE:',round(mape(y_pred10,test06)[0],2),'%')
print('RMSE TESTE:',round(rmse(y_pred10,test06),2))
print('R TESTE:',round(r2(y_pred10,test06),2))
print('\n')
# Out:
# Resultados com lag 17
#
#
# MAPE TREINO: 2.29 %
# RMSE TREINO: 0.13
# R TREINO: 0.43
#
#
# MAPE TESTE: 1.16 %
# RMSE TESTE: 0.14
# R TESTE: 0.25

# %%
#train_y = train_y.reshape(-1, 1)
#observado_treino = sc.inverse_transform(train_y)

#Plotagem do gráfico
#plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(treino, color = '#006699', alpha=0.5, label = 'Observado UGRHI10')
plt.plot(y_pred10t, color = 'red',linestyle = '--', label = 'Previsão UGRHI10')
#plt.title('Predição do pH com lag = 10%')
plt.xlabel('Tempo (Bimestre)')
plt.ylabel('Valor pH')
plt.legend()
#plt.grid()
plt.show()

observado_test = test06

#Plotagem do gráfico
#plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(observado_test, color = '#006699', alpha=0.5, label = 'Observado UGRHI06')
plt.plot(y_pred10, color = 'red',linestyle = '--', label = 'Previsão UGRHI06')
#plt.title('Predição do pH com lag = 10%')
plt.xlabel('Tempo (Bimestre)')
plt.ylabel('Valor pH')
plt.legend()
#plt.grid()
plt.show()
