# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 24
plt.rcParams.update({'font.size':20})
plt.rcParams["figure.figsize"] = (10,6)

# %%
str_files = ''
#Carrega os dados do arquivo .csv
#df = pd.read_csv(str_files + "ph.csv",encoding='utf-8',sep=';')
dateparse = lambda dates:pd.datetime.strptime(dates,'%d/%m/%Y')
df = pd.read_csv(str_files + 'ph.CSV',encoding='utf-8',sep=';', parse_dates = ['data_coleta'],index_col=['data_coleta'],date_parser=dateparse)
# Out:
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '10 - SOROCABA/MEDIO TIETE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < 6.34725)]

outlier
# Out:
# primeiro_quartil: valor    6.9
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.2685
# Name: 0.75, dtype: float64
# fig: valor    0.3685
# dtype: float64
# Inferior: valor    6.34725
# dtype: float64
# Superior: valor    7.82125
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              valor
# data_coleta
# 1987-01-31     6.2

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingd['valor'] == 6.20] = 7.08

ugrhi10 = trainingd

outlier = trainingd[(trainingd.valor < 6.34725)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
ugrhi10
# Out:
#              valor
# data_coleta
# 1978-01-31   7.100
# 1978-03-31   6.625
# 1978-05-31   6.650
# 1978-07-31   6.625
# 1978-09-30   6.575
# ...            ...
# 2018-07-31   7.266
# 2018-09-30   7.250
# 2018-11-30   7.244
# 2019-01-31   7.136
# 2019-03-31   7.650
#
# [248 rows x 1 columns]

# %%
#Seleciona os dados da UGRHI 10 - SOROCABA/MEDIO TIETE
z = df.loc[df['UGRHI'] == '06 - ALTO TIÊTE']

# %%
#Agrupa os dados pela media bimestral
trainingd = z.resample('2M').mean()

# %%
trainingd
#Remove as colunas que não serão utilizadas no experimento.
trainingd = trainingd.drop(['cod_interaguas', 'sinal','Altitude'], axis=1)
trainingd
# Out:
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [251 rows x 1 columns]

# %%
for field in trainingd.columns:
    print(field, 'NaN:', trainingd[field].isnull().sum())
# Out:
# valor NaN: 2

# %%
trainingd = trainingd.dropna(axis=0,how='any')

# %%
for field in trainingd.columns:
    print(field, 'NaN:', trainingd[field].isnull().sum())
trainingd
# Out:
# valor NaN: 0
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [249 rows x 1 columns]

# %%
#Regra 1.5*FIG --> Calcula-se o limite inferior e superior do diagrama de caixa.

#Ordena o dataframe
trainingds = trainingd.sort_values('valor',axis=0)

trainingds

tamanho = len(trainingds)
#Calcula o 1Q, ou seja, os primeiros 25% do diagrama de caixa.
primeiro_quartil = trainingds.quantile(q=0.25, axis=0, numeric_only=True, interpolation='linear')
#Calcula o 3Q, ou seja, 75% do diagrama de caixa.
terceiro_quartil = trainingds.quantile(q=0.75, axis=0, numeric_only=True, interpolation='linear')

print('primeiro_quartil:',primeiro_quartil)
print('terceiro_quartil:',terceiro_quartil)

#Calcula-se o interquartil(FIQ).
fig = terceiro_quartil - primeiro_quartil
print('fig:',fig)

#Calcula o limite inferior.
inferior = primeiro_quartil - (1.5*fig)
#Calcula o limite superior.
superior = terceiro_quartil + (1.5*fig)

print('Inferior:',inferior)
print('Superior:',superior)

#Seleciona os valores abaixo  do limite inferior, ou seja, os outlier.
outlier = trainingd[(trainingds.valor < inferior.valor)]

outlier
# Out:
# primeiro_quartil: valor    6.583333
# Name: 0.25, dtype: float64
# terceiro_quartil: valor    7.002667
# Name: 0.75, dtype: float64
# fig: valor    0.419333
# dtype: float64
# Inferior: valor    5.954333
# dtype: float64
# Superior: valor    7.631667
# dtype: float64
# /home/anderson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                 valor
# data_coleta
# 1979-11-30   5.916667
# 1985-03-31   5.883333

# %%
trainingd
# Out:
#                 valor
# data_coleta
# 1978-01-31   6.680000
# 1978-03-31   6.680000
# 1978-05-31   6.440000
# 1978-07-31   6.560000
# 1978-09-30   6.110000
# ...               ...
# 2019-01-31   7.056429
# 2019-03-31   7.323333
# 2019-05-31   7.405000
# 2019-07-31   7.345000
# 2019-09-30   7.336667
#
# [249 rows x 1 columns]

# %%
#Remove a última linha do dataframe
trainingd = trainingd.drop(trainingd[trainingd.index == '2019-09-30'].index)

# %%
trainingd.describe()
# Out:
#             valor
# count  248.000000
# mean     6.793328
# std      0.294764
# min      5.883333
# 25%      6.581944
# 50%      6.838095
# 75%      7.001821
# max      7.405000

# %%
#Substituição do outlier pelo valor médio da serie dos dados.
trainingd.loc[trainingds.valor < inferior.valor] = 6.79

ugrhi06 = trainingd

outlier = trainingd[(trainingd.valor < inferior.valor)]

outlier
# Out:
# Empty DataFrame
# Columns: [valor]
# Index: []

# %%
#Dados completo.
#data = trainingd.iloc[:,:].values
#treino (70%)
train10 = ugrhi10.iloc[0:174,:].values  
train06 = ugrhi06.iloc[0:174,:].values

#teste (30%)
test10 = ugrhi10.iloc[174:,:].values 
test06 = ugrhi06.iloc[174:,:].values

# %%
#Normalização dos dados: Normaliza os dados dentro um intervalo (0 a 1).
sc = MinMaxScaler()
train10 = sc.fit_transform(train10)
#train06 = sc.fit_transform(train06)
test10 = sc.fit_transform(test10)
test06 = sc.fit_transform(test06)

# %%
#X = ugrhi10
#y = ugrhi06

#assert X.shape == (len(X),1)
#assert y.shape == (len(y),1)

# %%
def prepara_dados(dados,lags):
    X = []
    y = []
    for i in range(lags, len(dados)):
        X.append(dados[i-lags:i, 0])
        y.append(dados[i, 0])
    return np.array(X), np.array(y)

# %%
lags = 43 # Equivalente à 25% dos dados de treino.
#Prepara os dados de treinamento
X_train10, y_train10 = prepara_dados(train10, lags)
    
#Prepara os dados de teste
entradas10 = ugrhi10[len(ugrhi10) - len(test10) - lags:].values
entradas10 = entradas10.reshape(-1, 1)
entradas10 = sc.fit_transform(entradas10)

X_test10 = []
for i in range(lags, lags+len(test10)):
    X_test10.append(entradas10[i-lags:i, 0])
X_test10 = np.array(X_test10)

# %%
#Prepara os dados de teste06
entradas06 = ugrhi06[len(ugrhi06) - len(test06) - lags:].values
entradas06 = entradas06.reshape(-1, 1)
entradas06 = sc.fit_transform(entradas06)

X_test06 = []
for i in range(lags, lags+len(test06)):
    X_test06.append(entradas06[i-lags:i, 0])
X_test06 = np.array(X_test06)

# %%
model = Sequential()
model.add(Dense(units = 10, activation = 'relu', input_dim = lags))
model.add(Dense(units = 21, activation = 'relu'))
model.add(Dense(units = 1, activation = 'linear'))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam',
                  metrics = ['mean_absolute_error'])

#Treina o modelo
model.fit(X_train10, y_train10, batch_size = 32, epochs = 100)

y_pred10 = model.predict(X_test06)
y_pred10 = y_pred10.reshape(-1, 1)
y_pred10 = sc.inverse_transform(y_pred10)

#X_test = sc.inverse_transform(X_test)
#y_test = sc.inverse_transform(y_test)
# Out:
# Train on 131 samples
# Epoch 1/100
# 131/131 [==============================] - 0s 4ms/sample - loss: 0.1804 - mean_absolute_error: 0.1804
# Epoch 2/100
# 131/131 [==============================] - 0s 127us/sample - loss: 0.1531 - mean_absolute_error: 0.1531
# Epoch 3/100
# 131/131 [==============================] - 0s 185us/sample - loss: 0.1508 - mean_absolute_error: 0.1508
# Epoch 4/100
# 131/131 [==============================] - 0s 166us/sample - loss: 0.1475 - mean_absolute_error: 0.1475
# Epoch 5/100
# 131/131 [==============================] - 0s 171us/sample - loss: 0.1465 - mean_absolute_error: 0.1465
# Epoch 6/100
# 131/131 [==============================] - 0s 205us/sample - loss: 0.1425 - mean_absolute_error: 0.1425
# Epoch 7/100
# 131/131 [==============================] - 0s 171us/sample - loss: 0.1403 - mean_absolute_error: 0.1403
# Epoch 8/100
# 131/131 [==============================] - 0s 172us/sample - loss: 0.1381 - mean_absolute_error: 0.1381
# Epoch 9/100
# 131/131 [==============================] - 0s 190us/sample - loss: 0.1359 - mean_absolute_error: 0.1359
# Epoch 10/100
# 131/131 [==============================] - 0s 171us/sample - loss: 0.1347 - mean_absolute_error: 0.1347
# Epoch 11/100
# 131/131 [==============================] - 0s 117us/sample - loss: 0.1356 - mean_absolute_error: 0.1356
# Epoch 12/100
# 131/131 [==============================] - 0s 129us/sample - loss: 0.1341 - mean_absolute_error: 0.1341
# Epoch 13/100
# 131/131 [==============================] - 0s 201us/sample - loss: 0.1320 - mean_absolute_error: 0.1320
# Epoch 14/100
# 131/131 [==============================] - 0s 150us/sample - loss: 0.1309 - mean_absolute_error: 0.1309
# Epoch 15/100
# 131/131 [==============================] - 0s 151us/sample - loss: 0.1299 - mean_absolute_error: 0.1299
# Epoch 16/100
# 131/131 [==============================] - 0s 224us/sample - loss: 0.1299 - mean_absolute_error: 0.1299
# Epoch 17/100
# 131/131 [==============================] - 0s 175us/sample - loss: 0.1334 - mean_absolute_error: 0.1334
# Epoch 18/100
# 131/131 [==============================] - 0s 100us/sample - loss: 0.1279 - mean_absolute_error: 0.1279
# Epoch 19/100
# 131/131 [==============================] - 0s 246us/sample - loss: 0.1315 - mean_absolute_error: 0.1315
# Epoch 20/100
# 131/131 [==============================] - 0s 176us/sample - loss: 0.1299 - mean_absolute_error: 0.1299
# Epoch 21/100
# 131/131 [==============================] - 0s 128us/sample - loss: 0.1269 - mean_absolute_error: 0.1269
# Epoch 22/100
# 131/131 [==============================] - 0s 213us/sample - loss: 0.1271 - mean_absolute_error: 0.1271
# Epoch 23/100
# 131/131 [==============================] - 0s 121us/sample - loss: 0.1258 - mean_absolute_error: 0.1258
# Epoch 24/100
# 131/131 [==============================] - 0s 187us/sample - loss: 0.1263 - mean_absolute_error: 0.1263
# Epoch 25/100
# 131/131 [==============================] - 0s 169us/sample - loss: 0.1276 - mean_absolute_error: 0.1276
# Epoch 26/100
# 131/131 [==============================] - 0s 207us/sample - loss: 0.1241 - mean_absolute_error: 0.1241
# Epoch 27/100
# 131/131 [==============================] - 0s 190us/sample - loss: 0.1234 - mean_absolute_error: 0.1234
# Epoch 28/100
# 131/131 [==============================] - 0s 187us/sample - loss: 0.1226 - mean_absolute_error: 0.1226
# Epoch 29/100
# 131/131 [==============================] - 0s 133us/sample - loss: 0.1230 - mean_absolute_error: 0.1230
# Epoch 30/100
# 131/131 [==============================] - 0s 195us/sample - loss: 0.1215 - mean_absolute_error: 0.1215
# Epoch 31/100
# 131/131 [==============================] - 0s 220us/sample - loss: 0.1224 - mean_absolute_error: 0.1224
# Epoch 32/100
# 131/131 [==============================] - 0s 215us/sample - loss: 0.1248 - mean_absolute_error: 0.1248
# Epoch 33/100
# 131/131 [==============================] - 0s 117us/sample - loss: 0.1199 - mean_absolute_error: 0.1199
# Epoch 34/100
# 131/131 [==============================] - 0s 221us/sample - loss: 0.1214 - mean_absolute_error: 0.1214
# Epoch 35/100
# 131/131 [==============================] - 0s 124us/sample - loss: 0.1261 - mean_absolute_error: 0.1261
# Epoch 36/100
# 131/131 [==============================] - 0s 167us/sample - loss: 0.1231 - mean_absolute_error: 0.1231
# Epoch 37/100
# 131/131 [==============================] - 0s 170us/sample - loss: 0.1194 - mean_absolute_error: 0.1194
# Epoch 38/100
# 131/131 [==============================] - 0s 143us/sample - loss: 0.1194 - mean_absolute_error: 0.1194
# Epoch 39/100
# 131/131 [==============================] - 0s 187us/sample - loss: 0.1178 - mean_absolute_error: 0.1178
# Epoch 40/100
# 131/131 [==============================] - 0s 198us/sample - loss: 0.1181 - mean_absolute_error: 0.1181
# Epoch 41/100
# 131/131 [==============================] - 0s 144us/sample - loss: 0.1184 - mean_absolute_error: 0.1184
# Epoch 42/100
# 131/131 [==============================] - 0s 116us/sample - loss: 0.1176 - mean_absolute_error: 0.1176
# Epoch 43/100
# 131/131 [==============================] - 0s 210us/sample - loss: 0.1172 - mean_absolute_error: 0.1172
# Epoch 44/100
# 131/131 [==============================] - 0s 169us/sample - loss: 0.1153 - mean_absolute_error: 0.1153
# Epoch 45/100
# 131/131 [==============================] - 0s 170us/sample - loss: 0.1149 - mean_absolute_error: 0.1149
# Epoch 46/100
# 131/131 [==============================] - 0s 189us/sample - loss: 0.1162 - mean_absolute_error: 0.1162
# Epoch 47/100
# 131/131 [==============================] - 0s 227us/sample - loss: 0.1141 - mean_absolute_error: 0.1141
# Epoch 48/100
# 131/131 [==============================] - 0s 163us/sample - loss: 0.1216 - mean_absolute_error: 0.1216
# Epoch 49/100
# 131/131 [==============================] - 0s 210us/sample - loss: 0.1177 - mean_absolute_error: 0.1177
# Epoch 50/100
# 131/131 [==============================] - ETA: 0s - loss: 0.1206 - mean_absolute_error: 0.120 - 0s 129us/sample - loss: 0.1129 - mean_absolute_error: 0.1129
# Epoch 51/100
# 131/131 [==============================] - 0s 100us/sample - loss: 0.1134 - mean_absolute_error: 0.1134
# Epoch 52/100
# 131/131 [==============================] - ETA: 0s - loss: 0.1052 - mean_absolute_error: 0.105 - 0s 166us/sample - loss: 0.1153 - mean_absolute_error: 0.1153
# Epoch 53/100
# 131/131 [==============================] - 0s 194us/sample - loss: 0.1158 - mean_absolute_error: 0.1158
# Epoch 54/100
# 131/131 [==============================] - 0s 175us/sample - loss: 0.1104 - mean_absolute_error: 0.1104
# Epoch 55/100
# 131/131 [==============================] - 0s 238us/sample - loss: 0.1143 - mean_absolute_error: 0.1143
# Epoch 56/100
# 131/131 [==============================] - 0s 149us/sample - loss: 0.1141 - mean_absolute_error: 0.1141
# Epoch 57/100
# 131/131 [==============================] - 0s 179us/sample - loss: 0.1138 - mean_absolute_error: 0.1138
# Epoch 58/100
# 131/131 [==============================] - 0s 184us/sample - loss: 0.1115 - mean_absolute_error: 0.1115
# Epoch 59/100
# 131/131 [==============================] - 0s 133us/sample - loss: 0.1117 - mean_absolute_error: 0.1117
# Epoch 60/100
# 131/131 [==============================] - 0s 197us/sample - loss: 0.1103 - mean_absolute_error: 0.1103
# Epoch 61/100
# 131/131 [==============================] - 0s 170us/sample - loss: 0.1104 - mean_absolute_error: 0.1104
# Epoch 62/100
# 131/131 [==============================] - 0s 153us/sample - loss: 0.1102 - mean_absolute_error: 0.1102
# Epoch 63/100
# 131/131 [==============================] - 0s 158us/sample - loss: 0.1091 - mean_absolute_error: 0.1091
# Epoch 64/100
# 131/131 [==============================] - 0s 148us/sample - loss: 0.1109 - mean_absolute_error: 0.1109
# Epoch 65/100
# 131/131 [==============================] - 0s 179us/sample - loss: 0.1093 - mean_absolute_error: 0.1093
# Epoch 66/100
# 131/131 [==============================] - 0s 194us/sample - loss: 0.1137 - mean_absolute_error: 0.1137
# Epoch 67/100
# 131/131 [==============================] - 0s 172us/sample - loss: 0.1110 - mean_absolute_error: 0.1110
# Epoch 68/100
# 131/131 [==============================] - 0s 194us/sample - loss: 0.1099 - mean_absolute_error: 0.1099
# Epoch 69/100
# 131/131 [==============================] - 0s 181us/sample - loss: 0.1086 - mean_absolute_error: 0.1086
# Epoch 70/100
# 131/131 [==============================] - 0s 190us/sample - loss: 0.1084 - mean_absolute_error: 0.1084
# Epoch 71/100
# 131/131 [==============================] - 0s 134us/sample - loss: 0.1089 - mean_absolute_error: 0.1089
# Epoch 72/100
# 131/131 [==============================] - 0s 195us/sample - loss: 0.1069 - mean_absolute_error: 0.1069
# Epoch 73/100
# 131/131 [==============================] - 0s 124us/sample - loss: 0.1090 - mean_absolute_error: 0.1090
# Epoch 74/100
# 131/131 [==============================] - 0s 176us/sample - loss: 0.1063 - mean_absolute_error: 0.1063
# Epoch 75/100
# 131/131 [==============================] - 0s 216us/sample - loss: 0.1100 - mean_absolute_error: 0.1100
# Epoch 76/100
# 131/131 [==============================] - 0s 97us/sample - loss: 0.1085 - mean_absolute_error: 0.1085
# Epoch 77/100
# 131/131 [==============================] - 0s 132us/sample - loss: 0.1093 - mean_absolute_error: 0.1093
# Epoch 78/100
# 131/131 [==============================] - 0s 135us/sample - loss: 0.1111 - mean_absolute_error: 0.1111
# Epoch 79/100
# 131/131 [==============================] - 0s 156us/sample - loss: 0.1074 - mean_absolute_error: 0.1074
# Epoch 80/100
# 131/131 [==============================] - 0s 148us/sample - loss: 0.1083 - mean_absolute_error: 0.1083
# Epoch 81/100
# 131/131 [==============================] - 0s 109us/sample - loss: 0.1078 - mean_absolute_error: 0.1078
# Epoch 82/100
# 131/131 [==============================] - 0s 152us/sample - loss: 0.1092 - mean_absolute_error: 0.1092
# Epoch 83/100
# 131/131 [==============================] - 0s 149us/sample - loss: 0.1069 - mean_absolute_error: 0.1069
# Epoch 84/100
# 131/131 [==============================] - 0s 131us/sample - loss: 0.1060 - mean_absolute_error: 0.1060
# Epoch 85/100
# 131/131 [==============================] - 0s 162us/sample - loss: 0.1060 - mean_absolute_error: 0.1060
# Epoch 86/100
# 131/131 [==============================] - 0s 87us/sample - loss: 0.1060 - mean_absolute_error: 0.1060
# Epoch 87/100
# 131/131 [==============================] - 0s 142us/sample - loss: 0.1051 - mean_absolute_error: 0.1051
# Epoch 88/100
# 131/131 [==============================] - 0s 143us/sample - loss: 0.1075 - mean_absolute_error: 0.1075
# Epoch 89/100
# 131/131 [==============================] - 0s 106us/sample - loss: 0.1078 - mean_absolute_error: 0.1078
# Epoch 90/100
# 131/131 [==============================] - 0s 157us/sample - loss: 0.1072 - mean_absolute_error: 0.1072
# Epoch 91/100
# 131/131 [==============================] - 0s 133us/sample - loss: 0.1068 - mean_absolute_error: 0.1068
# Epoch 92/100
# 131/131 [==============================] - 0s 172us/sample - loss: 0.1046 - mean_absolute_error: 0.1046
# Epoch 93/100
# 131/131 [==============================] - 0s 120us/sample - loss: 0.1043 - mean_absolute_error: 0.1043
# Epoch 94/100
# 131/131 [==============================] - 0s 139us/sample - loss: 0.1038 - mean_absolute_error: 0.1038
# Epoch 95/100
# 131/131 [==============================] - 0s 129us/sample - loss: 0.1050 - mean_absolute_error: 0.1050
# Epoch 96/100
# 131/131 [==============================] - 0s 159us/sample - loss: 0.1042 - mean_absolute_error: 0.1042
# Epoch 97/100
# 131/131 [==============================] - 0s 156us/sample - loss: 0.1070 - mean_absolute_error: 0.1070
# Epoch 98/100
# 131/131 [==============================] - 0s 124us/sample - loss: 0.1026 - mean_absolute_error: 0.1026
# Epoch 99/100
# 131/131 [==============================] - 0s 64us/sample - loss: 0.1042 - mean_absolute_error: 0.1042
# Epoch 100/100
# 131/131 [==============================] - 0s 142us/sample - loss: 0.1040 - mean_absolute_error: 0.1040

# %%
y_pred10t = model.predict(X_train10)
y_pred10t = y_pred10t.reshape(-1, 1)
y_pred10t = sc.inverse_transform(y_pred10t)

# %%
y_train10 = y_train10.reshape(-1, 1)
treino = sc.inverse_transform(y_train10)
#y_train10.shape

# %%
test06 = sc.inverse_transform(test06)

#Plotagem do gráfico
plt.plot(y_pred10, color = 'green', label = 'Observado UGRHI06')
plt.plot(test06, color = '#ff0066', label = 'Previsão UGRHI10')
plt.title('Predição do pH com lag = 10%')
plt.xlabel('Bimestre')
plt.ylabel('Valor pH')
plt.legend()
plt.grid()
plt.show()

# %%
def mape(y_pred,y_true):
    mape_sum = 0
    for real,prediction in zip(y_true,y_pred):
        mape_sum += (abs((real - prediction))/real)
        mape = mape_sum/len(real)
    return mape

def rmse(y_pred,y_true):
    mse = mean_squared_error(y_true, y_pred)
    rmse = math.sqrt(mse)
    return rmse

def r2(y_pred,y_true):
    rscore = r2_score(y_true,y_pred)
    return rscore

# %%
print('Resultados com lag', lags)
print('\n')
print('MAPE TREINO:',round(mape(y_pred10t,treino)[0],2),'%')
print('RMSE TREINO:',round(rmse(y_pred10t,treino),2))
print('R TREINO:',round(r2(y_pred10t,treino),2))
print('\n')
print('MAPE TESTE:',round(mape(y_pred10,test06)[0],2),'%')
print('RMSE TESTE:',round(rmse(y_pred10,test06),2))
print('R TESTE:',round(r2(y_pred10,test06),2))
print('\n')
# Out:
# Resultados com lag 43
#
#
# MAPE TREINO: 1.63 %
# RMSE TREINO: 0.12
# R TREINO: 0.4
#
#
# MAPE TESTE: 1.17 %
# RMSE TESTE: 0.14
# R TESTE: 0.22

# %%
#train_y = train_y.reshape(-1, 1)
#observado_treino = sc.inverse_transform(train_y)

#Plotagem do gráfico
#plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(treino, color = '#006699', alpha=0.5, label = 'Observado UGRHI10')
plt.plot(y_pred10t, color = 'red',linestyle = '--', label = 'Previsão UGRHI10')
#plt.title('Predição do pH com lag = 10%')
plt.xlabel('Tempo (Bimestre)')
plt.ylabel('Valor pH')
plt.legend()
#plt.grid()
plt.show()

observado_test = test06

#Plotagem do gráfico
#plt.plot(data, color = '#006699',alpha=0.5, label = 'Observado')
plt.plot(observado_test, color = '#006699', alpha=0.5, label = 'Observado UGRHI06')
plt.plot(y_pred10, color = 'red',linestyle = '--', label = 'Previsão UGRHI06')
#plt.title('Predição do pH com lag = 10%')
plt.xlabel('Tempo (Bimestre)')
plt.ylabel('Valor pH')
plt.legend()
#plt.grid()
plt.show()
